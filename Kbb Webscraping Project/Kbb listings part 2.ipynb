# %% [markdown]
# # Kelly Blue Book Part 2 Cleaning:

# %%
from bs4 import BeautifulSoup
import requests
import json
import time
import pandas as pd 
import re 

pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
pd.reset_option('display.width')

#had to restart on a new notebook from an error on the original. This is a continution of the cleaning.

# %%
kbb = pd.read_csv("kbb.csv")
kbb_cleaned = pd.read_csv("kbb_cleaned.csv")

kbb_cleaned
# Out:
#                                                     name  price mileage  \
# 0          Used 2019 Acura RDX FWD w/ Technology Package  29999  30,288
# 1      Certified 2021 Acura TLX SH-AWD w/ Technology ...  33983  18,121
# 2                                    Used 2020 Acura RDX  34997  41,174
# 3           Used 2019 Acura MDX SH-AWD w/ A-SPEC Package  31993  39,008
# 4             Used 2017 Acura RDX FWD w/ Advance Package  23923  56,546
# ...                                                  ...    ...     ...
# 35566         Certified 2022 Volkswagen Tiguan SE R-Line      0  25,210
# 35567  Certified 2023 Volkswagen Taos SE w/ Panoramic...  28778   7,637
# 35568  Certified 2019 Volkswagen Tiguan S w/ 3rd Row ...  17768  67,724
# 35569  Certified 2023 Volkswagen Taos SE w/ Panoramic...  27936   8,522
# 35570                 Certified 2021 Volkswagen Atlas SE  25866  61,997
#
#             engine_type transmission_type   color drivewheel_configuration
# 0      4-Cylinder Turbo         Automatic   Black    2 Wheel Drive - Front
# 1      4-Cylinder Turbo         Automatic  Purple          All Wheel Drive
# 2      4-Cylinder Turbo         Automatic    Gray          All wheel drive
# 3            6-Cylinder         Automatic    Blue          All wheel drive
# 4            6-Cylinder         Automatic   Black    2 wheel drive - front
# ...                 ...               ...     ...                      ...
# 35566  4-Cylinder Turbo         Automatic   White    2 wheel drive - front
# 35567  4-Cylinder Turbo         Automatic   White          All wheel drive
# 35568  4-Cylinder Turbo         Automatic   Black          All wheel drive
# 35569  4-Cylinder Turbo         Automatic    Gray    2 wheel drive - front
# 35570        6-Cylinder         Automatic   Black    2 wheel drive - front
#
# [35571 rows x 7 columns]

# %% [markdown]
# ### Cleaning Mileage column:

# %%
#stripping comma from mileage column
kbb_cleaned["mileage"] = kbb_cleaned["mileage"].str.replace(",","")

kbb_cleaned["mileage"]
# Out:
# 0        30288
# 1        18121
# 2        41174
# 3        39008
# 4        56546
#          ...
# 35566    25210
# 35567     7637
# 35568    67724
# 35569     8522
# 35570    61997
# Name: mileage, Length: 35571, dtype: object

# %%
#searching for none numbers in mileage column
pd.set_option('display.max_rows', None)

column_name = 'mileage'

# Use boolean indexing to locate non-numeric values in the specified column
non_numeric_values = kbb_cleaned[~kbb_cleaned[column_name].apply(lambda x: str(x).isnumeric())]

# Print the rows with non-numeric values in the specified column
print(non_numeric_values)
# Out:
#                                                     name   price mileage  \
# 19419  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19446  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19473  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19500  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19527  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19554  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19581  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19608  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19635  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19662  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19689  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19716  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19743  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19770  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19797  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19824  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19851  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19878  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19905  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19932  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19959  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 19986  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 20040  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 20067  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 20094  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 20121  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 20175  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 20202  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 20229  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 20283  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 20310  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 20337  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 20364  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 20391  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 20418  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 20445  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
# 20472  Certified 2023 Land Rover Range Rover Sport SE...  112937     NaN
#
#       engine_type transmission_type  color drivewheel_configuration
# 19419      Hybrid         Automatic  Black            4 wheel drive
# 19446      Hybrid         Automatic  Black            4 wheel drive
# 19473      Hybrid         Automatic  Black            4 wheel drive
# 19500      Hybrid         Automatic  Black            4 wheel drive
# 19527      Hybrid         Automatic  Black            4 wheel drive
# 19554      Hybrid         Automatic  Black            4 wheel drive
# 19581      Hybrid         Automatic  Black            4 wheel drive
# 19608      Hybrid         Automatic  Black            4 wheel drive
# 19635      Hybrid         Automatic  Black            4 wheel drive
# 19662      Hybrid         Automatic  Black            4 wheel drive
# 19689      Hybrid         Automatic  Black            4 wheel drive
# 19716      Hybrid         Automatic  Black            4 wheel drive
# 19743      Hybrid         Automatic  Black            4 wheel drive
# 19770      Hybrid         Automatic  Black            4 wheel drive
# 19797      Hybrid         Automatic  Black            4 wheel drive
# 19824      Hybrid         Automatic  Black            4 wheel drive
# 19851      Hybrid         Automatic  Black            4 wheel drive
# 19878      Hybrid         Automatic  Black            4 wheel drive
# 19905      Hybrid         Automatic  Black            4 wheel drive
# 19932      Hybrid         Automatic  Black            4 wheel drive
# 19959      Hybrid         Automatic  Black            4 wheel drive
# 19986      Hybrid         Automatic  Black            4 wheel drive
# 20040      Hybrid         Automatic  Black            4 wheel drive
# 20067      Hybrid         Automatic  Black            4 wheel drive
# 20094      Hybrid         Automatic  Black            4 wheel drive
# 20121      Hybrid         Automatic  Black            4 wheel drive
# 20175      Hybrid         Automatic  Black            4 wheel drive
# 20202      Hybrid         Automatic  Black            4 wheel drive
# 20229      Hybrid         Automatic  Black            4 wheel drive
# 20283      Hybrid         Automatic  Black            4 wheel drive
# 20310      Hybrid         Automatic  Black            4 wheel drive
# 20337      Hybrid         Automatic  Black            4 wheel drive
# 20364      Hybrid         Automatic  Black            4 wheel drive
# 20391      Hybrid         Automatic  Black            4 wheel drive
# 20418      Hybrid         Automatic  Black            4 wheel drive
# 20445      Hybrid         Automatic  Black            4 wheel drive
# 20472      Hybrid         Automatic  Black            4 wheel drive

# %%
# filling nan value with 0 and converting the column to int. the mileage is unknown on these listings and not 
# provided by the dealership

kbb_cleaned["mileage"] = kbb_cleaned["mileage"].fillna(0)

kbb_cleaned["mileage"] = kbb_cleaned["mileage"].astype(int)
kbb_cleaned["mileage"].dtype
# Out:
# dtype('int32')

# %% [markdown]
# ### Converting price column to integer:

# %%
# converting price column to integer type. 
kbb_cleaned["price"] = kbb_cleaned["price"].astype(int)

kbb_cleaned["price"].dtype
# Out:
# dtype('int32')

# %% [markdown]
# ### Cleaning color column:

# %%
#before tackling the name column I will look at the last columns to clean color and drivewheel. 
# looking below we can combine the 2 off whites and combine the unavailable and unknown
kbb_cleaned['color'].value_counts()
# Out:
# White        8012
# Black        7869
# Gray         5765
# Blue         4245
# Silver       3659
# Red          2950
# Off White     596
# Green         398
# Brown         318
# Orange        261
# Beige         251
# Burgundy      185
# Gold          122
# Offwhite       95
# Unavail        58
# Yellow         48
# Unknown         6
# Charcoal        2
# Tan             2
# Purple          1
# Turquoise       1
# Name: color, dtype: int64

# %%
kbb_cleaned["color"] = kbb_cleaned["color"].str.replace("Offwhite", "Off White")
kbb_cleaned["color"] = kbb_cleaned["color"].str.replace("Unavail", "Unknown")

kbb_cleaned['color'].value_counts()
# Out:
# White        8012
# Black        7869
# Gray         5765
# Blue         4245
# Silver       3659
# Red          2950
# Off White     691
# Green         398
# Brown         318
# Orange        261
# Beige         251
# Burgundy      185
# Gold          122
# Unknown        64
# Yellow         48
# Charcoal        2
# Tan             2
# Purple          1
# Turquoise       1
# Name: color, dtype: int64

# %%
kbb_cleaned['color'] = kbb_cleaned['color'].fillna('Unknown')

kbb_cleaned['color'].unique()

# %% [markdown]
# ### Converting drivertrain column:

# %%
#simplfying column name
kbb_cleaned["drivetrain"] = kbb_cleaned["drivewheel_configuration"]

kbb_cleaned["drivetrain"].value_counts()
# Out:
# All wheel drive                       10381
# 2 wheel drive - front                 10258
# 2 wheel drive - rear                   5644
# 4 wheel drive                          4343
# All Wheel Drive                        1904
# 2 Wheel Drive - Front                  1417
# 4 Wheel Drive                           826
# 2 Wheel Drive - Rear                    793
# 4 Wheel Drive - Rear Wheel Default        3
# Name: drivetrain, dtype: int64

# %% [markdown]
# Note: consolidating drivetrain types to simple format.
#
# |            drivetrain | acroynm |      meaning     |
# |-----------------------|---------|------------------|
# | 2 wheel drive - front |   FWD   | front wheel drive|
# | 2 Wheel Drive - Front |   FWD   | front wheel drive|
# | 2 Wheel Drive - Rear  |   RWD   | rear wheel drive |
# | 2 wheel drive - rear  |   RWD   | rear wheel drive |
# | All Wheel Drive       |   AWD   | all wheel drive  |
# | All wheel drive       |   AWD   | all wheel drive  |
# | 4 wheel drive         |   4WD   | four wheel drive |
# | 4 Wheel Drive         |   4WD   | four wheel drive |
# | 4 Wheel Drive - Rear Wheel Default     |   4WD_RWB   | this is a 4wd with a rear wheel default bias which can be changed  |

# %%
#consolidating drivetrain types down to 5. 

kbb_cleaned["drivetrain"] = kbb_cleaned["drivetrain"].str.replace("All wheel drive", "AWD")
kbb_cleaned["drivetrain"] = kbb_cleaned["drivetrain"].str.replace("All Wheel Drive", "AWD")
kbb_cleaned["drivetrain"] = kbb_cleaned["drivetrain"].str.replace("2 wheel drive - front", "FWD")
kbb_cleaned["drivetrain"] = kbb_cleaned["drivetrain"].str.replace("2 Wheel Drive - Front", "FWD")
kbb_cleaned["drivetrain"] = kbb_cleaned["drivetrain"].str.replace("2 wheel drive - rear", "RWD")
kbb_cleaned["drivetrain"] = kbb_cleaned["drivetrain"].str.replace("2 Wheel Drive - Rear", "RWD")
kbb_cleaned["drivetrain"] = kbb_cleaned["drivetrain"].str.replace("4 wheel drive", "4WD")
kbb_cleaned["drivetrain"] = kbb_cleaned["drivetrain"].str.replace("4 Wheel Drive", "4WD")
kbb_cleaned["drivetrain"] = kbb_cleaned["drivetrain"].str.replace("4 Wheel Drive - Rear Wheel Default", "4WD_RWD")
kbb_cleaned["drivetrain"] = kbb_cleaned["drivetrain"].str.replace(" - Rear Wheel Default", "_RWB")


kbb_cleaned["drivetrain"].value_counts()
# Out:
# AWD        12285
# FWD        11675
# RWD         6437
# 4WD         5169
# 4WD_RWB        3
# Name: drivetrain, dtype: int64

# %%
kbb_cleaned.head(15)
# Out:
#                                                  name  price  mileage  \
# 0       Used 2019 Acura RDX FWD w/ Technology Package  29999    30288
# 1   Certified 2021 Acura TLX SH-AWD w/ Technology ...  33983    18121
# 2                                 Used 2020 Acura RDX  34997    41174
# 3        Used 2019 Acura MDX SH-AWD w/ A-SPEC Package  31993    39008
# 4          Used 2017 Acura RDX FWD w/ Advance Package  23923    56546
# 5           Used 2023 Acura RDX FWD w/ A-Spec Package  44895     2148
# 6          Used 2019 Acura RDX FWD w/ Advance Package  29550    43275
# 7         Certified 2020 Acura ILX w/ Premium Package  23989    38101
# 8          Used 2019 Acura RDX FWD w/ Advance Package  30987    39761
# 9       Used 2019 Acura RDX FWD w/ Technology Package  26999    58664
# 10      Used 2022 Acura MDX FWD w/ Technology Package  43515    25476
# 11  Used 2019 Acura RDX FWD w/ A-Spec & Technology...  25999    74182
# 12         Used 2017 Acura RDX AWD w/ Advance Package  23493    71996
# 13         Used 2020 Acura RDX FWD w/ Advance Package  33000    25745
# 14             Used 2021 Acura TLX w/ Advance Package  39568     9151
#
#          engine_type transmission_type      color drivewheel_configuration  \
# 0   4-Cylinder Turbo         Automatic      Black    2 Wheel Drive - Front
# 1   4-Cylinder Turbo         Automatic     Purple          All Wheel Drive
# 2   4-Cylinder Turbo         Automatic       Gray          All wheel drive
# 3         6-Cylinder         Automatic       Blue          All wheel drive
# 4         6-Cylinder         Automatic      Black    2 wheel drive - front
# 5   4-Cylinder Turbo         Automatic        Red    2 wheel drive - front
# 6   4-Cylinder Turbo         Automatic      White    2 wheel drive - front
# 7         4-Cylinder         Automatic      Black    2 Wheel Drive - Front
# 8   4-Cylinder Turbo         Automatic       Blue    2 wheel drive - front
# 9   4-Cylinder Turbo         Automatic       Gray    2 wheel drive - front
# 10        6-Cylinder         Automatic     Silver    2 wheel drive - front
# 11  4-Cylinder Turbo         Automatic       Blue    2 wheel drive - front
# 12        6-Cylinder         Automatic      Black          All wheel drive
# 13  4-Cylinder Turbo         Automatic      Black    2 wheel drive - front
# 14  4-Cylinder Turbo         Automatic  Off White    2 wheel drive - front
#
#    drivetrain
# 0         FWD
# 1         AWD
# 2         AWD
# 3         AWD
# 4         FWD
# 5         FWD
# 6         FWD
# 7         FWD
# 8         FWD
# 9         FWD
# 10        FWD
# 11        FWD
# 12        AWD
# 13        FWD
# 14        FWD

# %% [markdown]
# ### Cleaning the name column:
#
# #### The name column I will split the columns into the following:
# ##### Used Vehicle Classification, Year, Make, Model, Packages.

# %%
#stripped and extracted certified and used. 

kbb_cleaned["Used Vehicle Classification"] = kbb_cleaned["name"].str.extract('(Used|Certified)', expand=False)
kbb_cleaned["name"] = kbb_cleaned["name"].str.strip('(Used|Certified)')
kbb_cleaned.head(15)
# Out:
#                                               name  price  mileage  \
# 0          2019 Acura RDX FWD w/ Technology Packag  29999    30288
# 1       2021 Acura TLX SH-AWD w/ Technology Packag  33983    18121
# 2                                   2020 Acura RDX  34997    41174
# 3           2019 Acura MDX SH-AWD w/ A-SPEC Packag  31993    39008
# 4             2017 Acura RDX FWD w/ Advance Packag  23923    56546
# 5              2023 Acura RDX FWD w/ A-Spec Packag  44895     2148
# 6             2019 Acura RDX FWD w/ Advance Packag  29550    43275
# 7                 2020 Acura ILX w/ Premium Packag  23989    38101
# 8             2019 Acura RDX FWD w/ Advance Packag  30987    39761
# 9          2019 Acura RDX FWD w/ Technology Packag  26999    58664
# 10         2022 Acura MDX FWD w/ Technology Packag  43515    25476
# 11   2019 Acura RDX FWD w/ A-Spec & Technology Pkg  25999    74182
# 12            2017 Acura RDX AWD w/ Advance Packag  23493    71996
# 13            2020 Acura RDX FWD w/ Advance Packag  33000    25745
# 14                2021 Acura TLX w/ Advance Packag  39568     9151
#
#          engine_type transmission_type      color drivewheel_configuration  \
# 0   4-Cylinder Turbo         Automatic      Black    2 Wheel Drive - Front
# 1   4-Cylinder Turbo         Automatic     Purple          All Wheel Drive
# 2   4-Cylinder Turbo         Automatic       Gray          All wheel drive
# 3         6-Cylinder         Automatic       Blue          All wheel drive
# 4         6-Cylinder         Automatic      Black    2 wheel drive - front
# 5   4-Cylinder Turbo         Automatic        Red    2 wheel drive - front
# 6   4-Cylinder Turbo         Automatic      White    2 wheel drive - front
# 7         4-Cylinder         Automatic      Black    2 Wheel Drive - Front
# 8   4-Cylinder Turbo         Automatic       Blue    2 wheel drive - front
# 9   4-Cylinder Turbo         Automatic       Gray    2 wheel drive - front
# 10        6-Cylinder         Automatic     Silver    2 wheel drive - front
# 11  4-Cylinder Turbo         Automatic       Blue    2 wheel drive - front
# 12        6-Cylinder         Automatic      Black          All wheel drive
# 13  4-Cylinder Turbo         Automatic      Black    2 wheel drive - front
# 14  4-Cylinder Turbo         Automatic  Off White    2 wheel drive - front
#
#    drivetrain Used Vehicle Classification
# 0         FWD                        Used
# 1         AWD                   Certified
# 2         AWD                        Used
# 3         AWD                        Used
# 4         FWD                        Used
# 5         FWD                        Used
# 6         FWD                        Used
# 7         FWD                   Certified
# 8         FWD                        Used
# 9         FWD                        Used
# 10        FWD                        Used
# 11        FWD                        Used
# 12        AWD                        Used
# 13        FWD                        Used
# 14        FWD                        Used

# %%
#extracting year and stripping blank white space 
kbb_cleaned['year'] = kbb_cleaned['name'].str.extract(r'(\d{4})')
kbb_cleaned['name'] = kbb_cleaned['name'].str.strip("")
kbb_cleaned.head()
# Out:
#                                           name  price  mileage  \
# 0      2019 Acura RDX FWD w/ Technology Packag  29999    30288
# 1   2021 Acura TLX SH-AWD w/ Technology Packag  33983    18121
# 2                               2020 Acura RDX  34997    41174
# 3       2019 Acura MDX SH-AWD w/ A-SPEC Packag  31993    39008
# 4         2017 Acura RDX FWD w/ Advance Packag  23923    56546
#
#         engine_type transmission_type   color drivewheel_configuration  \
# 0  4-Cylinder Turbo         Automatic   Black    2 Wheel Drive - Front
# 1  4-Cylinder Turbo         Automatic  Purple          All Wheel Drive
# 2  4-Cylinder Turbo         Automatic    Gray          All wheel drive
# 3        6-Cylinder         Automatic    Blue          All wheel drive
# 4        6-Cylinder         Automatic   Black    2 wheel drive - front
#
#   drivetrain Used Vehicle Classification  year
# 0        FWD                        Used  2019
# 1        AWD                   Certified  2021
# 2        AWD                        Used  2020
# 3        AWD                        Used  2019
# 4        FWD                        Used  2017

# %%
# removing year and any possible white space

kbb_cleaned['name'] = kbb_cleaned['name'].str.replace(r'(\d{4})', "")
kbb_cleaned['name'] = kbb_cleaned['name'].str.strip()
kbb_cleaned.head()
# Out:
# C:\Users\marko\AppData\Local\Temp\ipykernel_44628\342029031.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   kbb_cleaned['name'] = kbb_cleaned['name'].str.replace(r'(\d{4})', "")
#                                     name  price  mileage       engine_type  \
# 0     Acura RDX FWD w/ Technology Packag  29999    30288  4-Cylinder Turbo
# 1  Acura TLX SH-AWD w/ Technology Packag  33983    18121  4-Cylinder Turbo
# 2                              Acura RDX  34997    41174  4-Cylinder Turbo
# 3      Acura MDX SH-AWD w/ A-SPEC Packag  31993    39008        6-Cylinder
# 4        Acura RDX FWD w/ Advance Packag  23923    56546        6-Cylinder
#
#   transmission_type   color drivewheel_configuration drivetrain  \
# 0         Automatic   Black    2 Wheel Drive - Front        FWD
# 1         Automatic  Purple          All Wheel Drive        AWD
# 2         Automatic    Gray          All wheel drive        AWD
# 3         Automatic    Blue          All wheel drive        AWD
# 4         Automatic   Black    2 wheel drive - front        FWD
#
#   Used Vehicle Classification  year
# 0                        Used  2019
# 1                   Certified  2021
# 2                        Used  2020
# 3                        Used  2019
# 4                        Used  2017

# %%
# removing Romeo from Alfa Romeo and removing Rover from Land Rover so i can properly clean the name column 
kbb_cleaned['name'] = kbb_cleaned['name'].str.replace('Romeo','')
kbb_cleaned['name'] = kbb_cleaned['name'].str.replace('Rover', '')

# %%
#creating make and model column 
kbb_cleaned['make'] = kbb_cleaned['name'].str.split().str[0]
kbb_cleaned['model'] = kbb_cleaned['name'].str.split().str[1]

kbb_cleaned.head(15)
kbb_cleaned.tail(15)
# Out:
#                                                  name  price  mileage  \
# 35556                       Volkswagen Passat 2.0T SE  17551    60043
# 35557                      Volkswagen Tiguan SE R-Lin  21810    70394
# 35558                             Volkswagen Atlas SE  24923    62110
# 35559                      Volkswagen Tiguan SE R-Lin  22883    65594
# 35560                            Volkswagen Tiguan SE  21715    35007
# 35561                       Volkswagen Passat 2.0T SE  17923    62815
# 35562                             Volkswagen Tiguan S  21056    21551
# 35563                    Volkswagen Atlas SEL Premium  34166    24730
# 35564                             Volkswagen Tiguan S  22345    24208
# 35565                           Volkswagen Arteon SEL  42517     4837
# 35566                      Volkswagen Tiguan SE R-Lin      0    25210
# 35567  Volkswagen Taos SE w/ Panoramic Sunroof Packag  28778     7637
# 35568      Volkswagen Tiguan S w/ 3rd Row Seat Packag  17768    67724
# 35569  Volkswagen Taos SE w/ Panoramic Sunroof Packag  27936     8522
# 35570                             Volkswagen Atlas SE  25866    61997
#
#             engine_type transmission_type  color drivewheel_configuration  \
# 35556  4-Cylinder Turbo         Automatic   Gray    2 wheel drive - front
# 35557  4-Cylinder Turbo         Automatic   Gray    2 wheel drive - front
# 35558        6-Cylinder         Automatic   Blue          All wheel drive
# 35559  4-Cylinder Turbo         Automatic  Black    2 wheel drive - front
# 35560  4-Cylinder Turbo         Automatic  White    2 wheel drive - front
# 35561  4-Cylinder Turbo         Automatic  Black    2 wheel drive - front
# 35562  4-Cylinder Turbo         Automatic   Blue    2 wheel drive - front
# 35563        6-Cylinder         Automatic  Black          All wheel drive
# 35564  4-Cylinder Turbo         Automatic  Black    2 wheel drive - front
# 35565  4-Cylinder Turbo         Automatic  Black          All wheel drive
# 35566  4-Cylinder Turbo         Automatic  White    2 wheel drive - front
# 35567  4-Cylinder Turbo         Automatic  White          All wheel drive
# 35568  4-Cylinder Turbo         Automatic  Black          All wheel drive
# 35569  4-Cylinder Turbo         Automatic   Gray    2 wheel drive - front
# 35570        6-Cylinder         Automatic  Black    2 wheel drive - front
#
#       drivetrain Used Vehicle Classification  year        make   model
# 35556        FWD                   Certified  2021  Volkswagen  Passat
# 35557        FWD                   Certified  2020  Volkswagen  Tiguan
# 35558        AWD                   Certified  2021  Volkswagen   Atlas
# 35559        FWD                   Certified  2020  Volkswagen  Tiguan
# 35560        FWD                   Certified  2020  Volkswagen  Tiguan
# 35561        FWD                   Certified  2021  Volkswagen  Passat
# 35562        FWD                   Certified  2020  Volkswagen  Tiguan
# 35563        AWD                   Certified  2020  Volkswagen   Atlas
# 35564        FWD                   Certified  2022  Volkswagen  Tiguan
# 35565        AWD                   Certified  2023  Volkswagen  Arteon
# 35566        FWD                   Certified  2022  Volkswagen  Tiguan
# 35567        AWD                   Certified  2023  Volkswagen    Taos
# 35568        AWD                   Certified  2019  Volkswagen  Tiguan
# 35569        FWD                   Certified  2023  Volkswagen    Taos
# 35570        FWD                   Certified  2021  Volkswagen   Atlas

# %%
#stripping make and model and renaming column 
kbb_cleaned['name'] = kbb_cleaned['name'].str.split(n=2).str[2:].str.join(' ')

kbb_cleaned = kbb_cleaned.rename(columns={'name': 'packages'})

# adding back correct names 
kbb_cleaned['make'] = kbb_cleaned['make'].str.replace('Alfa', 'Alfa Romeo')
kbb_cleaned['make'] = kbb_cleaned['make'].str.replace('Land', 'Land Rover')


kbb_cleaned.head(10)
# Out:
#                       packages  price  mileage       engine_type  \
# 0     FWD w/ Technology Packag  29999    30288  4-Cylinder Turbo
# 1  SH-AWD w/ Technology Packag  33983    18121  4-Cylinder Turbo
# 2                               34997    41174  4-Cylinder Turbo
# 3      SH-AWD w/ A-SPEC Packag  31993    39008        6-Cylinder
# 4        FWD w/ Advance Packag  23923    56546        6-Cylinder
# 5         FWD w/ A-Spec Packag  44895     2148  4-Cylinder Turbo
# 6        FWD w/ Advance Packag  29550    43275  4-Cylinder Turbo
# 7            w/ Premium Packag  23989    38101        4-Cylinder
# 8        FWD w/ Advance Packag  30987    39761  4-Cylinder Turbo
# 9     FWD w/ Technology Packag  26999    58664  4-Cylinder Turbo
#
#   transmission_type   color drivewheel_configuration drivetrain  \
# 0         Automatic   Black    2 Wheel Drive - Front        FWD
# 1         Automatic  Purple          All Wheel Drive        AWD
# 2         Automatic    Gray          All wheel drive        AWD
# 3         Automatic    Blue          All wheel drive        AWD
# 4         Automatic   Black    2 wheel drive - front        FWD
# 5         Automatic     Red    2 wheel drive - front        FWD
# 6         Automatic   White    2 wheel drive - front        FWD
# 7         Automatic   Black    2 Wheel Drive - Front        FWD
# 8         Automatic    Blue    2 wheel drive - front        FWD
# 9         Automatic    Gray    2 wheel drive - front        FWD
#
#   Used Vehicle Classification  year   make model
# 0                        Used  2019  Acura   RDX
# 1                   Certified  2021  Acura   TLX
# 2                        Used  2020  Acura   RDX
# 3                        Used  2019  Acura   MDX
# 4                        Used  2017  Acura   RDX
# 5                        Used  2023  Acura   RDX
# 6                        Used  2019  Acura   RDX
# 7                   Certified  2020  Acura   ILX
# 8                        Used  2019  Acura   RDX
# 9                        Used  2019  Acura   RDX

# %%
#reorganizing the dataframe
kbb_cleaned = kbb_cleaned[['Used Vehicle Classification', 'year','make','model','packages', 'price', 'mileage', 'engine_type', 'transmission_type','drivetrain', 'color']]

kbb_cleaned.head(15)
# Out:
#    Used Vehicle Classification  year   make model  \
# 0                         Used  2019  Acura   RDX
# 1                    Certified  2021  Acura   TLX
# 2                         Used  2020  Acura   RDX
# 3                         Used  2019  Acura   MDX
# 4                         Used  2017  Acura   RDX
# 5                         Used  2023  Acura   RDX
# 6                         Used  2019  Acura   RDX
# 7                    Certified  2020  Acura   ILX
# 8                         Used  2019  Acura   RDX
# 9                         Used  2019  Acura   RDX
# 10                        Used  2022  Acura   MDX
# 11                        Used  2019  Acura   RDX
# 12                        Used  2017  Acura   RDX
# 13                        Used  2020  Acura   RDX
# 14                        Used  2021  Acura   TLX
#
#                           packages  price  mileage       engine_type  \
# 0         FWD w/ Technology Packag  29999    30288  4-Cylinder Turbo
# 1      SH-AWD w/ Technology Packag  33983    18121  4-Cylinder Turbo
# 2                                   34997    41174  4-Cylinder Turbo
# 3          SH-AWD w/ A-SPEC Packag  31993    39008        6-Cylinder
# 4            FWD w/ Advance Packag  23923    56546        6-Cylinder
# 5             FWD w/ A-Spec Packag  44895     2148  4-Cylinder Turbo
# 6            FWD w/ Advance Packag  29550    43275  4-Cylinder Turbo
# 7                w/ Premium Packag  23989    38101        4-Cylinder
# 8            FWD w/ Advance Packag  30987    39761  4-Cylinder Turbo
# 9         FWD w/ Technology Packag  26999    58664  4-Cylinder Turbo
# 10        FWD w/ Technology Packag  43515    25476        6-Cylinder
# 11  FWD w/ A-Spec & Technology Pkg  25999    74182  4-Cylinder Turbo
# 12           AWD w/ Advance Packag  23493    71996        6-Cylinder
# 13           FWD w/ Advance Packag  33000    25745  4-Cylinder Turbo
# 14               w/ Advance Packag  39568     9151  4-Cylinder Turbo
#
#    transmission_type drivetrain      color
# 0          Automatic        FWD      Black
# 1          Automatic        AWD     Purple
# 2          Automatic        AWD       Gray
# 3          Automatic        AWD       Blue
# 4          Automatic        FWD      Black
# 5          Automatic        FWD        Red
# 6          Automatic        FWD      White
# 7          Automatic        FWD      Black
# 8          Automatic        FWD       Blue
# 9          Automatic        FWD       Gray
# 10         Automatic        FWD     Silver
# 11         Automatic        FWD       Blue
# 12         Automatic        AWD      Black
# 13         Automatic        FWD      Black
# 14         Automatic        FWD  Off White

# %% [markdown]
# ### Creating vehicle type column:

# %%
#viewing car models to create vehicle type column. 
kbb_cleaned['model'].unique()
# Out:
# array(['RDX', 'TLX', 'MDX', 'ILX', 'Integra', 'RLX', 'Stelvio', 'Giulia',
#        '4C', 'A5', 'A4', 'Q8', 'A7', 'Q5', 'Q3', 'e-tron', 'Q7', 'S4',
#        'Q4', 'SQ5', 'SQ8', 'RS', 'A3', 'A8', 'A6', 'R8', 'SQ7', 'S7',
#        'X5', 'M2', 'M4', 'X2', 'X3', '430', '530', '330i', '440i', 'X1',
#        '530i', '430i', '740', '540i', '740i', 'X4', 'X7', '750i', 'i3',
#        '530e', 'i8', 'M550i', '228i', '320i', 'iX', '330e', 'X6', '228',
#        'M5', 'M340i', 'M850i', '230i', '745e', '540', 'M8', 'Regal',
#        'Encore', 'Envision', 'Enclave', 'LaCrosse', 'Cascada', 'CT5',
#        'XT5', 'Escalade', 'CT4', 'XT6', 'XT4', 'CTS', 'CT6', 'ATS',
#        'Silverado', 'Malibu', 'Equinox', 'Corvette', 'Camaro', 'Tahoe',
#        'Blazer', 'TrailBlazer', 'Trax', 'Traverse', 'Colorado', 'Express',
#        'Cruze', 'Impala', 'Pacifica', '300', 'Voyager', '200', 'Charger',
#        'Challenger', 'Durango', 'Grand', 'Journey', 'Escape', 'Fusion',
#        'Mustang', 'F150', 'F250', 'E-450', 'Expedition', 'Transit',
#        'Maverick', 'F350', 'Ranger', 'Explorer', 'Edge', 'Bronco',
#        'Focus', 'Fiesta', 'EcoSport', 'Taurus', 'GV80', 'G80', 'G70',
#        'GV60', 'GV70', 'G90', 'Acadia', 'Yukon', 'Canyon', 'Sierra',
#        'Terrain', 'Savana', 'Civic', 'HR-V', 'Odyssey', 'CR-V',
#        'Ridgeline', 'Pilot', 'Insight', 'Accord', 'Passport', 'Fit',
#        'Tucson', 'Palisade', 'Ioniq', 'Elantra', 'Sonata', 'Santa',
#        'Kona', 'Venue', 'Accent', 'Veloster', 'Velo', 'QX60', 'QX50',
#        'QX80', 'Q60', 'QX55', 'QX70', 'Q50', 'QX30', 'F-TYPE', 'XJ',
#        'F-PACE', 'I-PACE', 'E-PACE', 'XE', 'XF', 'Wrangler', 'Gladiator',
#        'Compass', 'Cherokee', 'Patriot', 'Renegade', 'Wagoneer', 'Soul',
#        'Optima', 'Sorento', 'K5', 'Sportage', 'Stinger', 'Forte', 'EV6',
#        'Seltos', 'Carnival', 'Telluride', 'Rio', 'K900', 'Cadenza',
#        'Niro', 'Range', 'Defender', 'Discovery', 'RX', 'GS', 'NX', 'ES',
#        'LC', 'GX', 'IS', 'UX', 'LX', 'LS', 'RC', 'Navigator', 'MKX',
#        'Corsair', 'Nautilus', 'Aviator', 'MKZ', 'Continental', 'MKC',
#        'MKT', 'Quattroporte', 'Levante', 'Ghibli', 'GranTurismo',
#        'Grecale', 'MC20', 'Ghibl', 'Levan', 'MAZDA3', 'CX-9', 'CX-5',
#        'MAZDA6', 'CX-30', 'CX-90', 'CX-3', 'CX-50', 'MX-5', 'GLB', 'E',
#        'GLC', 'GLA', 'GLS', 'GLE', 'C', 'A', 'CLA', 'G', 'Maybach', 'SLC',
#        'Sprinter', 'S', 'CLS', 'AMG', 'SL', 'Cooper', 'Outlander',
#        'Lancer', 'Eclipse', 'Mirage', 'Mirag', 'Rogue', 'Murano',
#        'Armada', 'Ariya', 'Maxima', '370Z', 'Sentra', 'Leaf', 'Titan',
#        'Versa', 'Pathfinder', 'Kicks', 'Altima', 'Frontier', 'NV',
#        'NV200', 'Macan', 'Cayenne', 'Cayenn', 'Taycan', '911', '718',
#        'Panamera', 'Big', 'Rebel', 'TRX', 'Classic', 'Laramie',
#        'Tradesman', 'Longhorn', 'Laram', 'Lone', 'Lim', 'ProMaster',
#        'Power', 'Limited', 'SLT', 'Ascent', 'Outback', 'Legacy',
#        'Impreza', 'Crosstrek', 'BRZ', 'Forester', 'WRX', 'Solterra',
#        'Model', 'Tundra', 'Tacoma', 'Camry', '4Runner', 'Supra', 'RAV4',
#        'Highlander', 'Corolla', 'Sienna', 'C-HR', 'Mira', 'Venza', 'Land',
#        'Priu', 'Prius', 'GTI', 'Atlas', 'Tiguan', 'Passat', 'Jetta',
#        'Arteon', 'Taos', 'Golf', 'ID.4'], dtype=object)

# %%
#creating mapping for vehicle type and car model 
car_type_mapping = {
    'RDX': 'SUV', 
    'TLX': 'Sedan',
    'MDX': 'SUV',
    'ILX': 'Sedan', 
    'Integra': 'Sedan', 
    'RLX': 'Sedan', 
    'Stelvio': 'SUV',
    'Giulia': 'Sedan',
    '4C': 'Coupe',
    'A5': 'Coupe', 
    'A4': 'Sedan',
    'Q8': 'SUV', 
    'A7': 'Sedan', 
    'Q5': 'SUV', 
    'Q3': 'SUV', 
    'e-tron': 'Sedan', 
    'Q7': 'SUV', 
    'S4': 'Sedan', 
    'Q4': 'SUV', 
    'SQ5': 'SUV', 
    'SQ8': 'SUV',
    'RS': 'Coupe', 
    'A3': 'Sedan', 
    'A8': 'Sedan', 
    'A6': 'Sedan', 
    'R8': 'Coupe', 
    'SQ7': 'SUV', 
    'S7': 'Sedan', 
    'X5': 'SUV', 
    'M2': 'Coupe', 
    'M4': 'Coupe', 
    'X2': 'SUV',
    'X3': 'SUV', 
    '430': 'Coupe', 
    '530': 'Sedan', 
    '330i': 'Sedan', 
    '440i': 'Coupe', 
    'X1': 'SUV', 
    '530i': 'Sedan', 
    '430i': 'Coupe', 
    '740': 'Sedan',
    '540i': 'Sedan', 
    '740i': 'Sedan', 
    'X4': 'SUV', 
    'X7': 'SUV', 
    '750i': 'Sedan', 
    'i3': 'Coupe', 
    '530e': 'Sedan', 
    'i8': 'Coupe', 
    'M550i': 'Sedan',
    '228i': 'Coupe', 
    '320i': 'Sedan', 
    'iX': 'SUV', 
    '330e': 'Sedan', 
    'X6': 'SUV', 
    '228': 'Coupe', 
    'M5': 'Sedan', 
    'M340i': 'Sedan', 
    'M850i': 'Sedan',
    '230i': 'Coupe', 
    '745e': 'Sedan', 
    '540': 'Sedan', 
    'M8': 'Coupe', 
    'Regal': 'Sedan', 
    'Encore': 'SUV', 
    'Envision': 'SUV',
    'Enclave': 'SUV', 
    'LaCrosse': 'Sedan', 
    'Cascada': 'Coupe', 
    'CT5': 'Sedan', 
    'XT5': 'SUV', 
    'Escalade': 'SUV', 
    'CT4': 'Sedan',
    'XT6': 'SUV', 
    'XT4': 'SUV', 
    'CTS': 'Sedan', 
    'CT6': 'Sedan', 
    'ATS': 'Sedan', 
    'Silverado':'Pick up',
    'Malibu': 'Sedan',
    'Equinox': 'SUV', 
    'Corvette': 'Coupe', 
    'Camaro': 'Coupe', 
    'Tahoe': 'SUV', 
    'Blazer': 'SUV', 
    'TrailBlazer': 'SUV',
    'Trax': 'SUV', 
    'Traverse': 'SUV', 
    'Colorado':'Pick up', 
    'Express': 'Van', 
    'Cruze': 'Sedan', 
    'Impala': 'Sedan',
    'Pacifica':'Mini van', 
    '300': 'Sedan', 
    'Voyager': 'Mini van', 
    '200': 'Sedan', 
    'Charger': 'Sedan', 
    'Challenger': 'Coupe',
    'Durango': 'SUV', 
    'Grand': 'Mini van', 
    'Journey': 'Mini van', 
    'Escape': 'SUV', 
    'Fusion': 'Sedan', 
    'Mustang': 'Coupe',
    'F150':'Pick up', 
    'F250':'Pick up', 
    'E-450': 'Van', 
    'Expedition': 'SUV', 
    'Transit': 'Van', 
    'Maverick':'Pick up',
    'F350':'Pick up', 
    'Ranger':'Pick up', 
    'Explorer': 'SUV', 
    'Edge': 'SUV', 
    'Bronco': 'SUV', 
    'Focus': 'Sedan', 
    'Fiesta': 'Sedan',
    'EcoSport': 'SUV', 
    'Taurus': 'Sedan', 
    'GV80': 'SUV', 
    'G80': 'Sedan', 
    'G70': 'Sedan', 
    'GV60': 'SUV', 
    'GV70': 'SUV', 
    'G90': 'Sedan',
    'Acadia': 'SUV', 
    'Yukon': 'SUV', 
    'Canyon':'Pick up', 
    'Sierra':'Pick up', 
    'Terrain': 'SUV', 
    'Savana': 'Van',
    'Civic': 'Sedan', 
    'HR-V': 'SUV', 
    'Odyssey':'Mini van', 
    'CR-V': 'SUV', 
    'Ridgeline':'Pick up', 
    'Pilot': 'SUV',
    'Insight': 'Sedan', 
    'Accord': 'Coupe', 
    'Passport': 'SUV', 
    'Fit': 'Sedan', 
    'Tucson': 'SUV', 
    'Palisade': 'SUV',
    'Ioniq': 'SUV', 
    'Elantra': 'Sedan', 
    'Sonata': 'Sedan', 
    'Santa': 'SUV', 
    'Kona': 'SUV', 
    'Venue': 'SUV', 
    'Accent': 'Sedan',
    'Veloster': 'Coupe', 
    'Velo': 'Coupe', 
    'QX60': 'SUV', 
    'QX50': 'SUV', 
    'QX80': 'SUV', 
    'Q60': 'Coupe', 
    'QX55': 'SUV', 
    'QX70': 'SUV', 
    'Q50': 'Sedan', 
    'QX30': 'SUV', 
    'F-TYPE': 'Coupe', 
    'XJ': 'Sedan',
    'F-PACE': 'SUV', 
    'I-PACE': 'SUV', 
    'E-PACE': 'SUV', 
    'XE': 'Sedan', 
    'XF': 'Sedan', 
    'Wrangler': 'SUV', 
    'Gladiator': 'SUV',
    'Compass': 'SUV', 
    'Cherokee': 'SUV', 
    'Patriot': 'SUV', 
    'Renegade': 'SUV', 
    'Wagoneer': 'SUV', 
    'Soul': 'SUV',
    'Optima': 'Sedan', 
    'Sorento': 'SUV', 
    'K5': 'Sedan', 
    'Sportage': 'SUV', 
    'Stinger': 'Sedan', 
    'Forte': 'Sedan', 
    'EV6': 'SUV',
    'Seltos': 'SUV', 
    'Carnival': 'Mini van', 
    'Telluride': 'SUV', 
    'Rio': 'Sedan', 
    'K900': 'Sedan', 
    'Cadenza': 'Sedan',
    'Niro': 'SUV', 
    'Range': 'SUV', 
    'Defender': 'SUV', 
    'Discovery': 'SUV', 
    'RX': 'SUV', 
    'GS': 'Sedan', 
    'NX': 'SUV', 
    'ES': 'Sedan',
    'LC': 'Coupe', 
    'GX': 'SUV', 
    'IS': 'Sedan', 
    'UX': 'SUV', 
    'LX': 'SUV', 
    'LS': 'Sedan', 
    'RC': 'Coupe', 
    'Navigator': 'SUV', 
    'MKX': 'Sedan',
    'Corsair': 'Coupe', 
    'Nautilus': 'SUV', 
    'Aviator': 'SUV', 
    'MKZ': 'Sedan', 
    'Continental': 'Sedan', 
    'MKC': 'SUV',
    'MKT': 'SUV', 
    'Quattroporte': 'Sedan', 
    'Levante': 'SUV', 
    'Ghibli': 'Sedan', 
    'GranTurismo': 'Coupe',
    'Grecale': 'SUV', 
    'MC20': 'Coupe', 
    'Ghibl': 'Sedan', 
    'Levan': 'SUV', 
    'MAZDA3': 'Sedan', 
    'CX-9': 'SUV', 
    'CX-5': 'SUV',
    'MAZDA6': 'Sedan', 
    'CX-30': 'SUV', 
    'CX-90': 'SUV', 
    'CX-3': 'SUV', 
    'CX-50': 'SUV', 
    'MX-5': 'Coupe', 
    'GLB': 'SUV', 
    'E': 'Sedan',
    'GLC': 'SUV', 
    'GLA': 'SUV', 
    'GLS': 'SUV', 
    'GLE': 'SUV', 
    'C': 'Sedan', 
    'A': 'Sedan', 
    'CLA': 'Coupe', 
    'G': 'SUV', 
    'Maybach': 'Sedan', 
    'SLC': 'Coupe',
    'Sprinter': 'Van', 
    'S': 'Sedan', 
    'CLS': 'Sedan', 
    'AMG': 'Coupe', 
    'SL': 'Coupe', 
    'Cooper': 'Coupe', 
    'Outlander': 'SUV',
    'Lancer': 'Sedan', 
    'Eclipse':'SUV', 
    'Mirage': 'Sedan', 
    'Mirag': 'Sedan', 
    'Rogue': 'SUV', 
    'Murano': 'SUV',
    'Armada': 'SUV', 
    'Ariya': 'SUV', 
    'Maxima': 'Sedan', 
    '370Z': 'Coupe',
    'Sentra': 'Sedan', 
    'Leaf': 'SUV', 
    'Titan':'Pick up',
    'Versa': 'Sedan', 
    'Pathfinder': 'SUV', 
    'Kicks': 'SUV', 
    'Altima': 'Sedan', 
    'Frontier':'Pick up', 
    'NV': 'Van',
    'NV200': 'Van', 
    'Macan': 'SUV', 
    'Cayenne': 'SUV', 
    'Cayenn': 'SUV', 
    'Taycan': 'Sedan', 
    '911': 'Coupe', 
    '718': 'Coupe',
    'Panamera': 'Sedan', 
    'Big':'Pick up', 
    'Rebel':'Pick up', 
    'TRX':'Pick up', 
    'Classic':'Pick up', 
    'Laramie':'Pick up',
    'Tradesman':'Pick up', 
    'Longhorn':'Pick up', 
    'Laram':'Pick up', 
    'Lone':'Pick up', 
    'Lim':'Pick up', 
    'ProMaster': 'Van' ,
    'Power':'Pick up', 
    'Limited':'Pick up', 
    'SLT':'Pick up', 
    'Ascent': 'SUV', 
    'Outback': 'SUV', 
    'Legacy': 'Sedan',
    'Impreza': 'Sedan', 
    'Crosstrek': 'SUV', 
    'BRZ': 'Coupe', 
    'Forester': 'SUV', 
    'WRX': 'Sedan', 
    'Solterra': 'SUV',
    'Model': 'Sedan', 
    'Tundra':'Pick up', 
    'Tacoma':'Pick up', 
    'Camry': 'Sedan', 
    '4Runner': 'SUV', 
    'Supra': 'Coupe', 
    'RAV4': 'SUV',
    'Highlander': 'SUV', 
    'Corolla': 'Sedan', 
    'Sienna': 'Mini van', 
    'C-HR': 'SUV', 
    'Mira': 'Sedan', 
    'Venza': 'SUV', 
    'Land':'SUV',
    'Priu': 'Sedan', 
    'Prius': 'Sedan', 
    'GTI': 'Sedan', 
    'Atlas': 'SUV', 
    'Tiguan': 'SUV', 
    'Passat': 'Sedan', 
    'Jetta': 'Sedan',
    'Arteon': 'Sedan', 
    'Taos': 'SUV', 
    'Golf': 'Sedan', 
    'ID.4': 'SUV'

}

# %%
#mapping and checking vehicle type 
kbb_cleaned['vehicle_type'] = kbb_cleaned['model'].map(car_type_mapping)

kbb_cleaned['vehicle_type'].value_counts()
# Out:
# SUV         20388
# Sedan        7838
# Pick up      3040
# Coupe        2852
# Mini van     1353
# Van           100
# Name: vehicle_type, dtype: int64

# %%
#saving file checkpoint due to inclement weather incase I lose power. 
kbb_cleaned.to_csv('kbb_cleaned.csv')

# %% [markdown]
# ### Fixing car model names:
#
# The car models with 2 words were split betwen model and package columns. For example Land Cruiser was split into make = Land and packages starts with Cruiser. I noticed this while mapping for the new vehicle type column.

# %%
# pulling Audi model name that is incorrect 
audi_rs = kbb_cleaned[kbb_cleaned['model'] == 'RS']

print(audi_rs)
# Out:
# Empty DataFrame
# Columns: [Used Vehicle Classification, year, make, model, packages, price, mileage, engine_type, transmission_type, drivetrain, color, vehicle_type]
# Index: []

# %%
#fixing model name and removing it from packages

kbb_cleaned.loc[2431, 'model'] = kbb_cleaned.loc[2431, 'model'] = "RS7"
kbb_cleaned.loc[2484, 'model'] = kbb_cleaned.loc[2484, 'model'] = "RSQ8"
kbb_cleaned.loc[2734, 'model'] = kbb_cleaned.loc[2734, 'model'] = "RS7"

kbb_cleaned.at[2431, 'packages'] = kbb_cleaned.at[2431, 'packages'].replace("7","")
kbb_cleaned.at[2484, 'packages'] = kbb_cleaned.at[2484, 'packages'].replace("Q8","")
kbb_cleaned.at[2734, 'packages'] = kbb_cleaned.at[2734, 'packages'].replace("7","")
print(kbb_cleaned.loc[2431])
# Out:
# Used Vehicle Classification                                Used
# year                                                       2021
# make                                                       Audi
# model                                                       RS7
# packages                        Sportback w/ Black Optic Packag
# price                                                     99950
# mileage                                                   10031
# engine_type                                    8-Cylinder Turbo
# transmission_type                                     Automatic
# drivetrain                                                  AWD
# color                                                    Silver
# vehicle_type                                              Coupe
# Name: 2431, dtype: object

# %%
#fixing toyota land cruiser
toyo_land = kbb_cleaned[kbb_cleaned['model'] == 'Land']
print(toyo_land)

kbb_cleaned.loc[34033, 'model'] = kbb_cleaned.loc[34033, 'model'] = 'Land Cruiser'
kbb_cleaned.loc[34033]
# Out:
# Empty DataFrame
# Columns: [Used Vehicle Classification, year, make, model, packages, price, mileage, engine_type, transmission_type, drivetrain, color, vehicle_type]
# Index: []
# Used Vehicle Classification            Used
# year                                   2018
# make                                 Toyota
# model                          Land Cruiser
# packages                                Cru
# price                                 65495
# mileage                               68511
# engine_type                      8-Cylinder
# transmission_type                 Automatic
# drivetrain                              4WD
# color                                 White
# vehicle_type                            SUV
# Name: 34033, dtype: object

# %%
kbb_cleaned['model'] = kbb_cleaned['model'].replace("Range", "Range Rover")

for index, row in kbb_cleaned.iterrows():
    
    if not pd.isna(row['packages']) and row['packages'].strip():
    # Split the "packages" column to get the first word
        first_word = row['packages'].split()[0]
    
    # Check if the first word is "Velar"
    if first_word == 'Velar':
        # Update the "model" column by adding "Velar"
        kbb_cleaned.at[index, 'model'] += ' Velar'

for index, row in kbb_cleaned.iterrows():
    
    if not pd.isna(row['packages']) and row['packages'].strip():
    # Split the "packages" column to get the first word
        first_word = row['packages'].split()[0]
    
    # Check if the first word is "Evoque"
        if first_word == 'Evoque':
        # Update the "model" column by adding "Evoque"
            kbb_cleaned.at[index, 'model'] += ' Evoque'
    
for index, row in kbb_cleaned.iterrows():
    
    if not pd.isna(row['packages']) and row['packages'].strip():
    # Split the "packages" column to get the first word
        first_word = row['packages'].split()[0]
    
    # Check if the first word is "Evoqu"
    if first_word == 'Evoqu':
        # Update the "model" column by adding "Evoque"
        kbb_cleaned.at[index, 'model'] += ' Evoque'

# %%
# fixed mitsubishi mirag to mitsubishi mirage
kbb_cleaned.loc[27776, 'model'] = kbb_cleaned.loc[27776, 'model'].replace('Mirag', 'Mirage')

kbb_cleaned.loc[27776]
# Out:
# Used Vehicle Classification          Used
# year                                 2021
# make                           Mitsubishi
# model                              Mirage
# packages
# price                               14900
# mileage                             54025
# engine_type                    3-Cylinder
# transmission_type               Automatic
# drivetrain                            FWD
# color                                Gray
# vehicle_type                        Sedan
# Name: 27776, dtype: object

# %%
# fixed porsche cayenn to porsche cayenne 

kbb_cleaned[kbb_cleaned['model'] == "Cayenn"]

kbb_cleaned['model'] = kbb_cleaned['model'].str.replace('Cayenn', 'Cayenne')

# %%
# corrected model names for Ram trucks 
kbb_cleaned['model'] = kbb_cleaned['model'].replace("Big", "Big Horn")
kbb_cleaned['model'] = kbb_cleaned['model'].replace("Lone", "Lone Star")
kbb_cleaned['model'] = kbb_cleaned['model'].replace("Lim", "Limited")

# corrected toyota prius typo
kbb_cleaned['model'] = kbb_cleaned['model'].replace("Priu", "Prius")

# %%
for index, row in kbb_cleaned.iterrows():
    
    if not pd.isna(row['packages']) and row['packages'].strip():
    # Split the "packages" column to get the first word
        first_word = row['packages'].split()[0]
    
        if first_word == '3':
            # Check if the make is "Tesla" and the model is "Model"
            if row['make'] == 'Tesla' and row['model'] == 'Model':
                # Update the "model" column by adding " 3"
                kbb_cleaned.at[index, 'model'] += ' 3'

for index, row in kbb_cleaned.iterrows():
    
    if not pd.isna(row['packages']) and row['packages'].strip():
    # Split the "packages" column to get the first word
        first_word = row['packages'].split()[0]
    
        if first_word == 'S':
            # Check if the make is "Tesla" and the model is "Model"
            if row['make'] == 'Tesla' and row['model'] == 'Model':
                # Update the "model" column by adding "S"
                kbb_cleaned.at[index, 'model'] += ' S'

    
for index, row in kbb_cleaned.iterrows():
    
    if not pd.isna(row['packages']) and row['packages'].strip():
    # Split the "packages" column to get the first word
        first_word = row['packages'].split()[0]
    
        if first_word == 'X':
            # Check if the make is "Tesla" and the model is "Model"
            if row['make'] == 'Tesla' and row['model'] == 'Model':
                # Update the "model" column by adding " X"
                kbb_cleaned.at[index, 'model'] += ' X'


for index, row in kbb_cleaned.iterrows():
    
    if not pd.isna(row['packages']) and row['packages'].strip():
    # Split the "packages" column to get the first word
        first_word = row['packages'].split()[0]
    
        if first_word == 'Y':
            # Check if the make is "Tesla" and the model is "Model"
            if row['make'] == 'Tesla' and row['model'] == 'Model':
                # Update the "model" column by adding " Y"
                kbb_cleaned.at[index, 'model'] += ' Y'

# %%
# checking model names for accuracy 
kbb_cleaned['model'].unique()
# Out:
# array(['RDX', 'TLX', 'MDX', 'ILX', 'Integra', 'RLX', 'Stelvio', 'Giulia',
#        '4C', 'A5', 'A4', 'Q8', 'A7', 'Q5', 'Q3', 'e-tron', 'Q7', 'S4',
#        'Q4', 'SQ5', 'SQ8', 'RS7', 'A3', 'RSQ8', 'A8', 'A6', 'R8', 'SQ7',
#        'S7', 'X5', 'M2', 'M4', 'X2', 'X3', '430', '530', '330i', '440i',
#        'X1', '530i', '430i', '740', '540i', '740i', 'X4', 'X7', '750i',
#        'i3', '530e', 'i8', 'M550i', '228i', '320i', 'iX', '330e', 'X6',
#        '228', 'M5', 'M340i', 'M850i', '230i', '745e', '540', 'M8',
#        'Regal', 'Encore', 'Envision', 'Enclave', 'LaCrosse', 'Cascada',
#        'CT5', 'XT5', 'Escalade', 'CT4', 'XT6', 'XT4', 'CTS', 'CT6', 'ATS',
#        'Silverado', 'Malibu', 'Equinox', 'Corvette', 'Camaro', 'Tahoe',
#        'Blazer', 'TrailBlazer', 'Trax', 'Traverse', 'Colorado', 'Express',
#        'Cruze', 'Impala', 'Pacifica', '300', 'Voyager', '200', 'Charger',
#        'Challenger', 'Durango', 'Grand', 'Journey', 'Escape', 'Fusion',
#        'Mustang', 'F150', 'F250', 'E-450', 'Expedition', 'Transit',
#        'Maverick', 'F350', 'Ranger', 'Explorer', 'Edge', 'Bronco',
#        'Focus', 'Fiesta', 'EcoSport', 'Taurus', 'GV80', 'G80', 'G70',
#        'GV60', 'GV70', 'G90', 'Acadia', 'Yukon', 'Canyon', 'Sierra',
#        'Terrain', 'Savana', 'Civic', 'HR-V', 'Odyssey', 'CR-V',
#        'Ridgeline', 'Pilot', 'Insight', 'Accord', 'Passport', 'Fit',
#        'Tucson', 'Palisade', 'Ioniq', 'Elantra', 'Sonata', 'Santa',
#        'Kona', 'Venue', 'Accent', 'Veloster', 'Velo', 'QX60', 'QX50',
#        'QX80', 'Q60', 'QX55', 'QX70', 'Q50', 'QX30', 'F-TYPE', 'XJ',
#        'F-PACE', 'I-PACE', 'E-PACE', 'XE', 'XF', 'Wrangler', 'Gladiator',
#        'Compass', 'Cherokee', 'Patriot', 'Renegade', 'Wagoneer', 'Soul',
#        'Optima', 'Sorento', 'K5', 'Sportage', 'Stinger', 'Forte', 'EV6',
#        'Seltos', 'Carnival', 'Telluride', 'Rio', 'K900', 'Cadenza',
#        'Niro', 'Range Rover', 'Range Rover Evoque Evoque Evoque',
#        'Defender', 'Discovery', 'Range Rover Velar Velar Velar', 'RX',
#        'GS', 'NX', 'ES', 'LC', 'GX', 'IS', 'UX', 'LX', 'LS', 'RC',
#        'Navigator', 'MKX', 'Corsair', 'Nautilus', 'Aviator', 'MKZ',
#        'Continental', 'MKC', 'MKT', 'Quattroporte', 'Levante', 'Ghibli',
#        'GranTurismo', 'Grecale', 'MC20', 'Ghibl', 'Levan', 'MAZDA3',
#        'CX-9', 'CX-5', 'MAZDA6', 'CX-30', 'CX-90', 'CX-3', 'CX-50',
#        'MX-5', 'GLB', 'E', 'GLC', 'GLA', 'GLS', 'GLE', 'C', 'A', 'CLA',
#        'G', 'Maybach', 'SLC', 'Sprinter', 'S', 'CLS', 'AMG', 'SL',
#        'Cooper', 'Outlander', 'Lancer', 'Eclipse', 'Mirage', 'Rogue',
#        'Murano', 'Armada', 'Ariya', 'Maxima', '370Z', 'Sentra', 'Leaf',
#        'Titan', 'Versa', 'Pathfinder', 'Kicks', 'Altima', 'Frontier',
#        'NV', 'NV200', 'Macan', 'Cayennee', 'Cayenne', 'Taycan', '911',
#        '718', 'Panamera', 'Big Horn', 'Rebel', 'TRX', 'Classic',
#        'Laramie', 'Tradesman', 'Longhorn', 'Laram', 'Lone Star',
#        'Limited', 'ProMaster', 'Power', 'SLT', 'Ascent', 'Outback',
#        'Legacy', 'Impreza', 'Crosstrek', 'BRZ', 'Forester', 'WRX',
#        'Solterra', 'Model3', 'ModelY', 'ModelX', 'ModelS', 'Tundra',
#        'Tacoma', 'Camry', '4Runner', 'Supra', 'RAV4', 'Highlander',
#        'Corolla', 'Sienna', 'C-HR', 'Mira', 'Venza', 'Land Cruiser',
#        'Prius', 'GTI', 'Atlas', 'Tiguan', 'Passat', 'Jetta', 'Arteon',
#        'Taos', 'Golf', 'ID.4'], dtype=object)

# %% [markdown]
# ### Handling 0 values in the price column:

# %%
# exploring price at 0 by manufacturer
kbb_cleaned[kbb_cleaned['price'] == 0].groupby('make').count()
# Out:
#                Used Vehicle Classification  year  model  packages  price  \
# make
# Acura                                    1     1      1         1      1
# Audi                                     1     1      1         1      1
# BMW                                      1     1      1         1      1
# Buick                                    1     1      1         1      1
# Chrysler                                80    80     80        80     80
# Dodge                                   40    40     40        40     40
# Ford                                   321   321    321       321    321
# GMC                                     41    41     41        41     41
# Honda                                    2     2      2         2      2
# Hyundai                                  1     1      1         1      1
# INFINITI                                 1     1      1         1      1
# Jeep                                    41    41     41        41     41
# Kia                                      1     1      1         1      1
# Lexus                                    1     1      1         1      1
# Lincoln                                 40    40     40        40     40
# MAZDA                                    1     1      1         1      1
# MINI                                     3     3      3         3      3
# Maserati                                 1     1      1         1      1
# Mercedes-Benz                            1     1      1         1      1
# Mitsubishi                               4     4      4         4      4
# Nissan                                   2     2      2         2      2
# Porsche                                 81    81     81        81     81
# RAM                                     80    80     80        80     80
# Tesla                                   41    41     41        41     41
# Volkswagen                              81    81     81        81     81
#
#                mileage  engine_type  transmission_type  drivetrain  color  \
# make
# Acura                1            1                  1           1      1
# Audi                 1            1                  1           1      1
# BMW                  1            1                  1           1      1
# Buick                1            1                  1           1      1
# Chrysler            80           80                 80          80     80
# Dodge               40           40                 40          40     40
# Ford               321          321                321         321    321
# GMC                 41           41                 41          41     41
# Honda                2            2                  2           2      2
# Hyundai              1            1                  1           1      1
# INFINITI             1            1                  1           1      1
# Jeep                41           41                 41          41     41
# Kia                  1            1                  1           1      1
# Lexus                1            1                  1           1      1
# Lincoln             40           40                 40          40     40
# MAZDA                1            1                  1           1      1
# MINI                 3            3                  3           3      3
# Maserati             1            1                  1           1      1
# Mercedes-Benz        1            1                  1           1      1
# Mitsubishi           4            4                  4           4      4
# Nissan               2            2                  2           2      2
# Porsche             81           81                 81          81     81
# RAM                 80           80                 80          80     80
# Tesla               41           41                 41          41     41
# Volkswagen          81           81                 81          81     81
#
#                vehicle_type
# make
# Acura                     1
# Audi                      1
# BMW                       1
# Buick                     1
# Chrysler                 80
# Dodge                    40
# Ford                    321
# GMC                      41
# Honda                     2
# Hyundai                   1
# INFINITI                  1
# Jeep                     41
# Kia                       1
# Lexus                     1
# Lincoln                  40
# MAZDA                     1
# MINI                      3
# Maserati                  1
# Mercedes-Benz             1
# Mitsubishi                4
# Nissan                    2
# Porsche                  81
# RAM                      80
# Tesla                    41
# Volkswagen               81

# %% [markdown]
# The 0 values will pull down the average of each vehicle. 40 missing values account for about 3.7% of the data.
# Ford being the largest at 321 accounts for roughly 30% of the ford dataset. The reason the cars dont have a value is generally because they are not listed by the dealership on kelly blue book. To handle this lets explore and see what I can do with the Ford brand first as this is a large portion.

# %%
#extracting just ford 
ford_cars = kbb_cleaned[kbb_cleaned['make']== 'Ford']

#seperating out the 0 values
ford_cars_zero = ford_cars[ford_cars['price'] == 0]

#viewing the missing amounts in each type
ford_cars_zero['model'].value_counts()
# Out:
# F150          120
# Expedition     80
# Transit        40
# Maverick       40
# Edge           40
# F350            1
# Name: model, dtype: int64

# %%
#extracting F150 models
f150 = ford_cars[ford_cars['model'] == 'F150'] 

#extracting all above 0 
f1500 = f150[f150['price'] > 0]

#looking at mean median mode 
f150_average = f1500['price'].mean()
f150_median = f1500['price'].median()
f150_mode = f1500['price'].mode()

print('median:', f150_median, 'average:', f150_average)
print ()
print('mode')
print(f150_mode)
# Out:
# median: 34800.0 average: 35867.87242798354
#
# mode
# 0    20931
# 1    32995
# 2    34800
# 3    35859
# 4    46995
# Name: price, dtype: int32

# %%
# looking at the the range and standard deviation ill replace the 0's with the median value of 34,800
f1500['price'].describe()
# Out:
# count      243.000000
# mean     35867.872428
# std      10795.622289
# min       8995.000000
# 25%      32995.000000
# 50%      34800.000000
# 75%      37888.500000
# max      74977.000000
# Name: price, dtype: float64

# %%
kbb_cleaned['price'] = kbb_cleaned['price'].astype(int)

# %%
#updating with median 
kbb_cleaned.loc[(kbb_cleaned['make'] == 'Ford') & (kbb_cleaned['model'] == 'F-150') & (kbb_cleaned['price'] == 0), 'price'] = 34800

#checking to make sure it updated. 
kbb_cleaned[(kbb_cleaned['model'] == 'F150') & (kbb_cleaned['price'] > 0)].count()
# Out:
# Used Vehicle Classification    363
# year                           363
# make                           363
# model                          363
# packages                       363
# price                          363
# mileage                        363
# engine_type                    363
# transmission_type              363
# drivetrain                     363
# color                          363
# vehicle_type                   363
# dtype: int64

# %%
#extracting Expedition models
fe = ford_cars[ford_cars['model'] == 'Expedition'] 

#extracting all above 0 
fe_exp = fe[fe['price'] > 0]

print(fe_exp.count())

#looking at mean median mode std and quartile ranges
fe_exp_average = fe_exp['price'].mean()
fe_exp_median = fe_exp['price'].median()
fe_exp_mode = fe_exp['price'].mode()

print('median:', fe_exp_median, 'average:', fe_exp_average)
print ()
print('mode')
print(fe_exp_mode)
print()
print(fe_exp.describe())
# Out:
# Used Vehicle Classification    86
# year                           86
# make                           86
# model                          86
# packages                       86
# price                          86
# mileage                        86
# engine_type                    86
# transmission_type              86
# drivetrain                     86
# color                          86
# vehicle_type                   86
# dtype: int64
# median: 53310.0 average: 60209.232558139534
#
# mode
# 0    53310
# 1    69995
# Name: price, dtype: int32
#
#               price        mileage
# count     86.000000      86.000000
# mean   60209.232558   19841.058140
# std     9830.530164   19622.521644
# min    33447.000000    3042.000000
# 25%    53310.000000    3042.000000
# 50%    53310.000000   29207.000000
# 75%    69995.000000   29207.000000
# max    69995.000000  107719.000000

# %%
#updating expedtion with the median 

#updating with median 
kbb_cleaned.loc[(kbb_cleaned['model'] == 'Expedition') & (kbb_cleaned['price'] == 0), 'price'] = 53310 

#checking to make sure it updated. 
kbb_cleaned[(kbb_cleaned['model'] == 'Expedition') & (kbb_cleaned['price'] > 0)].count()
# Out:
# Used Vehicle Classification    166
# year                           166
# make                           166
# model                          166
# packages                       166
# price                          166
# mileage                        166
# engine_type                    166
# transmission_type              166
# drivetrain                     166
# color                          166
# vehicle_type                   166
# dtype: int64

# %%
#extracting Expedition models
transit = ford_cars[ford_cars['model'] == 'Transit'] 

print(transit.count())

#extracting all above 0 
transit_greater = transit[transit['price'] > 0]

print(transit_greater.count())

#looking at mean median mode std and quartile ranges
transit_average = transit_greater['price'].mean()
transit_median = transit_greater['price'].median()
transit_mode = transit_greater['price'].mode()

print('median:', fe_exp_median, 'average:', fe_exp_average)
print ()
print('mode')
print(fe_exp_mode)
print()
print(fe_exp.describe())
# Out:
# Used Vehicle Classification    42
# year                           42
# make                           42
# model                          42
# packages                       42
# price                          42
# mileage                        42
# engine_type                    42
# transmission_type              42
# drivetrain                     42
# color                          42
# vehicle_type                   42
# dtype: int64
# Used Vehicle Classification    2
# year                           2
# make                           2
# model                          2
# packages                       2
# price                          2
# mileage                        2
# engine_type                    2
# transmission_type              2
# drivetrain                     2
# color                          2
# vehicle_type                   2
# dtype: int64
# median: 53310.0 average: 60209.232558139534
#
# mode
# 0    53310
# 1    69995
# Name: price, dtype: int32
#
#               price        mileage
# count     86.000000      86.000000
# mean   60209.232558   19841.058140
# std     9830.530164   19622.521644
# min    33447.000000    3042.000000
# 25%    53310.000000    3042.000000
# 50%    53310.000000   29207.000000
# 75%    69995.000000   29207.000000
# max    69995.000000  107719.000000

# %% [markdown]
# #### Notes:
#
# This is not a good outcome. The transit van has 42 for sale and only 2 have a price. This is not a good sample size to use. I think the best choice for this one is to completely drop the transit van from the dataset. Since pricing is not available originally  using only 2 will not be a good representation. I am okay with dropping this vehicle because it is a utility van and not a common vehicle and my purpose is mostly for regular vehicles and not commercial use.

# %%
#dropping transit 
kbb_cleaned = kbb_cleaned[kbb_cleaned['model'] != 'Transit']

#checking to make sure it dropped
kbb_cleaned[kbb_cleaned['model'] == "Transit"]
# Out:
# Empty DataFrame
# Columns: [Used Vehicle Classification, year, make, model, packages, price, mileage, engine_type, transmission_type, drivetrain, color, vehicle_type]
# Index: []

# %%
ford_cars
# Out:
#       Used Vehicle Classification  year  make       model  \
# 9690                         Used  2020  Ford      Escape
# 9691                         Used  2020  Ford      Fusion
# 9692                         Used  2022  Ford     Mustang
# 9693                         Used  2021  Ford        F150
# 9694                         Used  2019  Ford        F150
# 9695                         Used  2021  Ford     Mustang
# 9696                         Used  2019  Ford        F250
# 9697                         Used  2019  Ford       E-450
# 9698                         Used  2020  Ford  Expedition
# 9699                         Used  2017  Ford        F150
# 9700                         Used  2017  Ford        F250
# 9701                         Used  2022  Ford        F150
# 9702                         Used  2018  Ford     Mustang
# 9703                         Used  2022  Ford  Expedition
# 9704                         Used  2019  Ford        F150
# 9705                         Used  2019  Ford     Transit
# 9706                    Certified  2020  Ford        F150
# 9707                         Used  2023  Ford  Expedition
# 9708                         Used  2022  Ford    Maverick
# 9709                         Used  2023  Ford        F150
# 9710                         Used  2017  Ford        F150
# 9711                    Certified  2022  Ford        F350
# 9712                    Certified  2022  Ford      Ranger
# 9713                    Certified  2018  Ford      Fusion
# 9714                    Certified  2018  Ford    Explorer
# 9715                         Used  2019  Ford        Edge
# 9716                         Used  2020  Ford  Expedition
# 9717                         Used  2019  Ford      Ranger
# 9718                         Used  2022  Ford      Escape
# 9719                         Used  2022  Ford     Mustang
# 9720                         Used  2021  Ford        F150
# 9721                         Used  2019  Ford        F150
# 9722                         Used  2021  Ford     Mustang
# 9723                         Used  2019  Ford        F250
# 9724                         Used  2022  Ford        Edge
# 9725                         Used  2020  Ford  Expedition
# 9726                         Used  2017  Ford        F150
# 9727                         Used  2017  Ford        F250
# 9728                         Used  2022  Ford        F150
# 9729                         Used  2018  Ford     Mustang
# 9730                         Used  2022  Ford  Expedition
# 9731                         Used  2019  Ford        F150
# 9732                         Used  2019  Ford     Transit
# 9733                    Certified  2020  Ford        F150
# 9734                         Used  2023  Ford  Expedition
# 9735                         Used  2022  Ford    Maverick
# 9736                         Used  2023  Ford        F150
# 9737                         Used  2017  Ford        F150
# 9738                    Certified  2022  Ford        F350
# 9739                    Certified  2022  Ford      Ranger
# 9740                    Certified  2018  Ford      Fusion
# 9741                    Certified  2018  Ford    Explorer
# 9742                         Used  2019  Ford        Edge
# 9743                         Used  2020  Ford  Expedition
# 9744                         Used  2017  Ford        F150
# 9745                         Used  2021  Ford      Bronco
# 9746                         Used  2022  Ford     Mustang
# 9747                         Used  2021  Ford        F150
# 9748                         Used  2019  Ford        F150
# 9749                         Used  2021  Ford     Mustang
# 9750                         Used  2019  Ford        F250
# 9751                         Used  2021  Ford    Explorer
# 9752                         Used  2020  Ford  Expedition
# 9753                         Used  2017  Ford        F150
# 9754                         Used  2017  Ford        F250
# 9755                         Used  2022  Ford        F150
# 9756                         Used  2018  Ford     Mustang
# 9757                         Used  2022  Ford  Expedition
# 9758                         Used  2019  Ford        F150
# 9759                         Used  2019  Ford     Transit
# 9760                    Certified  2020  Ford        F150
# 9761                         Used  2023  Ford  Expedition
# 9762                         Used  2022  Ford    Maverick
# 9763                         Used  2023  Ford        F150
# 9764                         Used  2017  Ford        F150
# 9765                    Certified  2022  Ford        F350
# 9766                    Certified  2022  Ford      Ranger
# 9767                    Certified  2018  Ford      Fusion
# 9768                    Certified  2018  Ford    Explorer
# 9769                         Used  2019  Ford        Edge
# 9770                         Used  2020  Ford  Expedition
# 9771                    Certified  2023  Ford      Escape
# 9772                         Used  2022  Ford        F150
# 9773                         Used  2022  Ford     Mustang
# 9774                         Used  2021  Ford        F150
# 9775                         Used  2019  Ford        F150
# 9776                         Used  2021  Ford     Mustang
# 9777                         Used  2019  Ford        F250
# 9778                         Used  2020  Ford        Edge
# 9779                         Used  2020  Ford  Expedition
# 9780                         Used  2017  Ford        F150
# 9781                         Used  2017  Ford        F250
# 9782                         Used  2022  Ford        F150
# 9783                         Used  2018  Ford     Mustang
# 9784                         Used  2022  Ford  Expedition
# 9785                         Used  2019  Ford        F150
# 9786                         Used  2019  Ford     Transit
# 9787                    Certified  2020  Ford        F150
# 9788                         Used  2023  Ford  Expedition
# 9789                         Used  2022  Ford    Maverick
# 9790                         Used  2023  Ford        F150
# 9791                         Used  2017  Ford        F150
# 9792                    Certified  2022  Ford        F350
# 9793                    Certified  2022  Ford      Ranger
# 9794                    Certified  2018  Ford      Fusion
# 9795                    Certified  2018  Ford    Explorer
# 9796                         Used  2019  Ford        Edge
# 9797                         Used  2020  Ford  Expedition
# 9798                         Used  2017  Ford        F150
# 9799                         Used  2017  Ford        F150
# 9800                         Used  2022  Ford     Mustang
# 9801                         Used  2021  Ford        F150
# 9802                         Used  2019  Ford        F150
# 9803                         Used  2021  Ford     Mustang
# 9804                         Used  2019  Ford        F250
# 9805                    Certified  2018  Ford        F150
# 9806                         Used  2020  Ford  Expedition
# 9807                         Used  2017  Ford        F150
# 9808                         Used  2017  Ford        F250
# 9809                         Used  2022  Ford        F150
# 9810                         Used  2018  Ford     Mustang
# 9811                         Used  2022  Ford  Expedition
# 9812                         Used  2019  Ford        F150
# 9813                         Used  2019  Ford     Transit
# 9814                    Certified  2020  Ford        F150
# 9815                         Used  2023  Ford  Expedition
# 9816                         Used  2022  Ford    Maverick
# 9817                         Used  2023  Ford        F150
# 9818                         Used  2017  Ford        F150
# 9819                    Certified  2022  Ford        F350
# 9820                    Certified  2022  Ford      Ranger
# 9821                    Certified  2018  Ford      Fusion
# 9822                    Certified  2018  Ford    Explorer
# 9823                         Used  2019  Ford        Edge
# 9824                         Used  2020  Ford  Expedition
# 9825                         Used  2019  Ford      Escape
# 9826                         Used  2017  Ford        F150
# 9827                         Used  2022  Ford     Mustang
# 9828                         Used  2021  Ford        F150
# 9829                         Used  2019  Ford        F150
# 9830                         Used  2021  Ford     Mustang
# 9831                         Used  2019  Ford        F250
# 9832                         Used  2020  Ford        F150
# 9833                         Used  2020  Ford  Expedition
# 9834                         Used  2017  Ford        F150
# 9835                         Used  2017  Ford        F250
# 9836                         Used  2022  Ford        F150
# 9837                         Used  2018  Ford     Mustang
# 9838                         Used  2022  Ford  Expedition
# 9839                         Used  2019  Ford        F150
# 9840                         Used  2019  Ford     Transit
# 9841                    Certified  2020  Ford        F150
# 9842                         Used  2023  Ford  Expedition
# 9843                         Used  2022  Ford    Maverick
# 9844                         Used  2023  Ford        F150
# 9845                         Used  2017  Ford        F150
# 9846                    Certified  2022  Ford        F350
# 9847                    Certified  2022  Ford      Ranger
# 9848                    Certified  2018  Ford      Fusion
# 9849                    Certified  2018  Ford    Explorer
# 9850                         Used  2019  Ford        Edge
# 9851                         Used  2020  Ford  Expedition
# 9852                         Used  2021  Ford        F250
# 9853                         Used  2019  Ford        F150
# 9854                         Used  2022  Ford     Mustang
# 9855                         Used  2021  Ford        F150
# 9856                         Used  2019  Ford        F150
# 9857                         Used  2021  Ford     Mustang
# 9858                         Used  2019  Ford        F250
# 9859                    Certified  2020  Ford        F150
# 9860                         Used  2020  Ford  Expedition
# 9861                         Used  2017  Ford        F150
# 9862                         Used  2017  Ford        F250
# 9863                         Used  2022  Ford        F150
# 9864                         Used  2018  Ford     Mustang
# 9865                         Used  2022  Ford  Expedition
# 9866                         Used  2019  Ford        F150
# 9867                         Used  2019  Ford     Transit
# 9868                    Certified  2020  Ford        F150
# 9869                         Used  2023  Ford  Expedition
# 9870                         Used  2022  Ford    Maverick
# 9871                         Used  2023  Ford        F150
# 9872                         Used  2017  Ford        F150
# 9873                    Certified  2022  Ford        F350
# 9874                    Certified  2022  Ford      Ranger
# 9875                    Certified  2018  Ford      Fusion
# 9876                    Certified  2018  Ford    Explorer
# 9877                         Used  2019  Ford        Edge
# 9878                         Used  2020  Ford  Expedition
# 9879                         Used  2020  Ford  Expedition
# 9880                         Used  2019  Ford    Explorer
# 9881                         Used  2022  Ford     Mustang
# 9882                         Used  2021  Ford        F150
# 9883                         Used  2019  Ford        F150
# 9884                         Used  2021  Ford     Mustang
# 9885                         Used  2019  Ford        F250
# 9886                         Used  2019  Ford        F150
# 9887                         Used  2020  Ford  Expedition
# 9888                         Used  2017  Ford        F150
# 9889                         Used  2017  Ford        F250
# 9890                         Used  2022  Ford        F150
# 9891                         Used  2018  Ford     Mustang
# 9892                         Used  2022  Ford  Expedition
# 9893                         Used  2019  Ford        F150
# 9894                         Used  2019  Ford     Transit
# 9895                    Certified  2020  Ford        F150
# 9896                         Used  2023  Ford  Expedition
# 9897                         Used  2022  Ford    Maverick
# 9898                         Used  2023  Ford        F150
# 9899                         Used  2017  Ford        F150
# 9900                    Certified  2022  Ford        F350
# 9901                    Certified  2022  Ford      Ranger
# 9902                    Certified  2018  Ford      Fusion
# 9903                    Certified  2018  Ford    Explorer
# 9904                         Used  2019  Ford        Edge
# 9905                         Used  2020  Ford  Expedition
# 9906                         Used  2018  Ford        F150
# 9907                         Used  2018  Ford        F150
# 9908                         Used  2022  Ford     Mustang
# 9909                         Used  2021  Ford        F150
# 9910                         Used  2019  Ford        F150
# 9911                         Used  2021  Ford     Mustang
# 9912                         Used  2019  Ford        F250
# 9913                    Certified  2020  Ford    Explorer
# 9914                         Used  2020  Ford  Expedition
# 9915                         Used  2017  Ford        F150
# 9916                         Used  2017  Ford        F250
# 9917                         Used  2022  Ford        F150
# 9918                         Used  2018  Ford     Mustang
# 9919                         Used  2022  Ford  Expedition
# 9920                         Used  2019  Ford        F150
# 9921                         Used  2019  Ford     Transit
# 9922                    Certified  2020  Ford        F150
# 9923                         Used  2023  Ford  Expedition
# 9924                         Used  2022  Ford    Maverick
# 9925                         Used  2023  Ford        F150
# 9926                         Used  2017  Ford        F150
# 9927                    Certified  2022  Ford        F350
# 9928                    Certified  2022  Ford      Ranger
# 9929                    Certified  2018  Ford      Fusion
# 9930                    Certified  2018  Ford    Explorer
# 9931                         Used  2019  Ford        Edge
# 9932                         Used  2020  Ford  Expedition
# 9933                         Used  2019  Ford        F150
# 9934                         Used  2020  Ford      Escape
# 9935                         Used  2022  Ford     Mustang
# 9936                         Used  2021  Ford        F150
# 9937                         Used  2019  Ford        F150
# 9938                         Used  2021  Ford     Mustang
# 9939                         Used  2019  Ford        F250
# 9940                         Used  2017  Ford        F150
# 9941                         Used  2020  Ford  Expedition
# 9942                         Used  2017  Ford        F150
# 9943                         Used  2017  Ford        F250
# 9944                         Used  2022  Ford        F150
# 9945                         Used  2018  Ford     Mustang
# 9946                         Used  2022  Ford  Expedition
# 9947                         Used  2019  Ford        F150
# 9948                         Used  2019  Ford     Transit
# 9949                    Certified  2020  Ford        F150
# 9950                         Used  2023  Ford  Expedition
# 9951                         Used  2022  Ford    Maverick
# 9952                         Used  2023  Ford        F150
# 9953                         Used  2017  Ford        F150
# 9954                    Certified  2022  Ford        F350
# 9955                    Certified  2022  Ford      Ranger
# 9956                    Certified  2018  Ford      Fusion
# 9957                    Certified  2018  Ford    Explorer
# 9958                         Used  2019  Ford        Edge
# 9959                         Used  2020  Ford  Expedition
# 9960                         Used  2020  Ford        F150
# 9961                         Used  2020  Ford      Escape
# 9962                         Used  2022  Ford     Mustang
# 9963                         Used  2021  Ford        F150
# 9964                         Used  2019  Ford        F150
# 9965                         Used  2021  Ford     Mustang
# 9966                         Used  2019  Ford        F250
# 9967                         Used  2019  Ford     Mustang
# 9968                         Used  2020  Ford  Expedition
# 9969                         Used  2017  Ford        F150
# 9970                         Used  2017  Ford        F250
# 9971                         Used  2022  Ford        F150
# 9972                         Used  2018  Ford     Mustang
# 9973                         Used  2022  Ford  Expedition
# 9974                         Used  2019  Ford        F150
# 9975                         Used  2019  Ford     Transit
# 9976                    Certified  2020  Ford        F150
# 9977                         Used  2023  Ford  Expedition
# 9978                         Used  2022  Ford    Maverick
# 9979                         Used  2023  Ford        F150
# 9980                         Used  2017  Ford        F150
# 9981                    Certified  2022  Ford        F350
# 9982                    Certified  2022  Ford      Ranger
# 9983                    Certified  2018  Ford      Fusion
# 9984                    Certified  2018  Ford    Explorer
# 9985                         Used  2019  Ford        Edge
# 9986                         Used  2020  Ford  Expedition
# 9987                         Used  2020  Ford        F150
# 9988                         Used  2019  Ford        Edge
# 9989                         Used  2022  Ford     Mustang
# 9990                         Used  2021  Ford        F150
# 9991                         Used  2019  Ford        F150
# 9992                         Used  2021  Ford     Mustang
# 9993                         Used  2019  Ford        F250
# 9994                    Certified  2022  Ford      Bronco
# 9995                         Used  2020  Ford  Expedition
# 9996                         Used  2017  Ford        F150
# 9997                         Used  2017  Ford        F250
# 9998                         Used  2022  Ford        F150
# 9999                         Used  2018  Ford     Mustang
# 10000                        Used  2022  Ford  Expedition
# 10001                        Used  2019  Ford        F150
# 10002                        Used  2019  Ford     Transit
# 10003                   Certified  2020  Ford        F150
# 10004                        Used  2023  Ford  Expedition
# 10005                        Used  2022  Ford    Maverick
# 10006                        Used  2023  Ford        F150
# 10007                        Used  2017  Ford        F150
# 10008                   Certified  2022  Ford        F350
# 10009                   Certified  2022  Ford      Ranger
# 10010                   Certified  2018  Ford      Fusion
# 10011                   Certified  2018  Ford    Explorer
# 10012                        Used  2019  Ford        Edge
# 10013                        Used  2020  Ford  Expedition
# 10014                        Used  2020  Ford        F150
# 10015                        Used  2018  Ford       Focus
# 10016                        Used  2022  Ford     Mustang
# 10017                        Used  2021  Ford        F150
# 10018                        Used  2019  Ford        F150
# 10019                        Used  2021  Ford     Mustang
# 10020                        Used  2019  Ford        F250
# 10021                   Certified  2023  Ford      Bronco
# 10022                        Used  2020  Ford  Expedition
# 10023                        Used  2017  Ford        F150
# 10024                        Used  2017  Ford        F250
# 10025                        Used  2022  Ford        F150
# 10026                        Used  2018  Ford     Mustang
# 10027                        Used  2022  Ford  Expedition
# 10028                        Used  2019  Ford        F150
# 10029                        Used  2019  Ford     Transit
# 10030                   Certified  2020  Ford        F150
# 10031                        Used  2023  Ford  Expedition
# 10032                        Used  2022  Ford    Maverick
# 10033                        Used  2023  Ford        F150
# 10034                        Used  2017  Ford        F150
# 10035                   Certified  2022  Ford        F350
# 10036                   Certified  2022  Ford      Ranger
# 10037                   Certified  2018  Ford      Fusion
# 10038                   Certified  2018  Ford    Explorer
# 10039                        Used  2019  Ford        Edge
# 10040                        Used  2020  Ford  Expedition
# 10041                        Used  2021  Ford    Explorer
# 10042                        Used  2023  Ford      Bronco
# 10043                        Used  2022  Ford     Mustang
# 10044                        Used  2021  Ford        F150
# 10045                        Used  2019  Ford        F150
# 10046                        Used  2021  Ford     Mustang
# 10047                        Used  2019  Ford        F250
# 10048                        Used  2017  Ford      Fusion
# 10049                        Used  2020  Ford  Expedition
# 10050                        Used  2017  Ford        F150
# 10051                        Used  2017  Ford        F250
# 10052                        Used  2022  Ford        F150
# 10053                        Used  2018  Ford     Mustang
# 10054                        Used  2022  Ford  Expedition
# 10055                        Used  2019  Ford        F150
# 10056                        Used  2019  Ford     Transit
# 10057                   Certified  2020  Ford        F150
# 10058                        Used  2023  Ford  Expedition
# 10059                        Used  2022  Ford    Maverick
# 10060                        Used  2023  Ford        F150
# 10061                        Used  2017  Ford        F150
# 10062                   Certified  2022  Ford        F350
# 10063                   Certified  2022  Ford      Ranger
# 10064                   Certified  2018  Ford      Fusion
# 10065                   Certified  2018  Ford    Explorer
# 10066                        Used  2019  Ford        Edge
# 10067                        Used  2020  Ford  Expedition
# 10068                        Used  2021  Ford     Mustang
# 10069                        Used  2020  Ford        Edge
# 10070                        Used  2022  Ford     Mustang
# 10071                        Used  2021  Ford        F150
# 10072                        Used  2019  Ford        F150
# 10073                        Used  2021  Ford     Mustang
# 10074                        Used  2019  Ford        F250
# 10075                        Used  2021  Ford      Escape
# 10076                        Used  2020  Ford  Expedition
# 10077                        Used  2017  Ford        F150
# 10078                        Used  2017  Ford        F250
# 10079                        Used  2022  Ford        F150
# 10080                        Used  2018  Ford     Mustang
# 10081                        Used  2022  Ford  Expedition
# 10082                        Used  2019  Ford        F150
# 10083                        Used  2019  Ford     Transit
# 10084                   Certified  2020  Ford        F150
# 10085                        Used  2023  Ford  Expedition
# 10086                        Used  2022  Ford    Maverick
# 10087                        Used  2023  Ford        F150
# 10088                        Used  2017  Ford        F150
# 10089                   Certified  2022  Ford        F350
# 10090                   Certified  2022  Ford      Ranger
# 10091                   Certified  2018  Ford      Fusion
# 10092                   Certified  2018  Ford    Explorer
# 10093                        Used  2019  Ford        Edge
# 10094                        Used  2020  Ford  Expedition
# 10095                        Used  2017  Ford        F150
# 10096                        Used  2023  Ford      Bronco
# 10097                        Used  2022  Ford     Mustang
# 10098                        Used  2021  Ford        F150
# 10099                        Used  2019  Ford        F150
# 10100                        Used  2021  Ford     Mustang
# 10101                        Used  2019  Ford        F250
# 10102                   Certified  2019  Ford        F150
# 10103                        Used  2020  Ford  Expedition
# 10104                        Used  2017  Ford        F150
# 10105                        Used  2017  Ford        F250
# 10106                        Used  2022  Ford        F150
# 10107                        Used  2018  Ford     Mustang
# 10108                        Used  2022  Ford  Expedition
# 10109                        Used  2019  Ford        F150
# 10110                        Used  2019  Ford     Transit
# 10111                   Certified  2020  Ford        F150
# 10112                        Used  2023  Ford  Expedition
# 10113                        Used  2022  Ford    Maverick
# 10114                        Used  2023  Ford        F150
# 10115                        Used  2017  Ford        F150
# 10116                   Certified  2022  Ford        F350
# 10117                   Certified  2022  Ford      Ranger
# 10118                   Certified  2018  Ford      Fusion
# 10119                   Certified  2018  Ford    Explorer
# 10120                        Used  2019  Ford        Edge
# 10121                        Used  2020  Ford  Expedition
# 10122                        Used  2019  Ford      Escape
# 10123                        Used  2019  Ford        F150
# 10124                        Used  2022  Ford     Mustang
# 10125                        Used  2021  Ford        F150
# 10126                        Used  2019  Ford        F150
# 10127                        Used  2021  Ford     Mustang
# 10128                        Used  2019  Ford        F250
# 10129                        Used  2020  Ford      Escape
# 10130                        Used  2020  Ford  Expedition
# 10131                        Used  2017  Ford        F150
# 10132                        Used  2017  Ford        F250
# 10133                        Used  2022  Ford        F150
# 10134                        Used  2018  Ford     Mustang
# 10135                        Used  2022  Ford  Expedition
# 10136                        Used  2019  Ford        F150
# 10137                        Used  2019  Ford     Transit
# 10138                   Certified  2020  Ford        F150
# 10139                        Used  2023  Ford  Expedition
# 10140                        Used  2022  Ford    Maverick
# 10141                        Used  2023  Ford        F150
# 10142                        Used  2017  Ford        F150
# 10143                   Certified  2022  Ford        F350
# 10144                   Certified  2022  Ford      Ranger
# 10145                   Certified  2018  Ford      Fusion
# 10146                   Certified  2018  Ford    Explorer
# 10147                        Used  2019  Ford        Edge
# 10148                        Used  2020  Ford  Expedition
# 10149                        Used  2019  Ford        Edge
# 10150                        Used  2021  Ford    Explorer
# 10151                        Used  2022  Ford     Mustang
# 10152                        Used  2021  Ford        F150
# 10153                        Used  2019  Ford        F150
# 10154                        Used  2021  Ford     Mustang
# 10155                        Used  2019  Ford        F250
# 10156                        Used  2022  Ford        F150
# 10157                        Used  2020  Ford  Expedition
# 10158                        Used  2017  Ford        F150
# 10159                        Used  2017  Ford        F250
# 10160                        Used  2022  Ford        F150
# 10161                        Used  2018  Ford     Mustang
# 10162                        Used  2022  Ford  Expedition
# 10163                        Used  2019  Ford        F150
# 10164                        Used  2019  Ford     Transit
# 10165                   Certified  2020  Ford        F150
# 10166                        Used  2023  Ford  Expedition
# 10167                        Used  2022  Ford    Maverick
# 10168                        Used  2023  Ford        F150
# 10169                        Used  2017  Ford        F150
# 10170                   Certified  2022  Ford        F350
# 10171                   Certified  2022  Ford      Ranger
# 10172                   Certified  2018  Ford      Fusion
# 10173                   Certified  2018  Ford    Explorer
# 10174                        Used  2019  Ford        Edge
# 10175                        Used  2020  Ford  Expedition
# 10176                        Used  2020  Ford        F150
# 10177                        Used  2017  Ford        F150
# 10178                        Used  2022  Ford     Mustang
# 10179                        Used  2021  Ford        F150
# 10180                        Used  2019  Ford        F150
# 10181                        Used  2021  Ford     Mustang
# 10182                        Used  2019  Ford        F250
# 10183                        Used  2021  Ford  Expedition
# 10184                        Used  2020  Ford  Expedition
# 10185                        Used  2017  Ford        F150
# 10186                        Used  2017  Ford        F250
# 10187                        Used  2022  Ford        F150
# 10188                        Used  2018  Ford     Mustang
# 10189                        Used  2022  Ford  Expedition
# 10190                        Used  2019  Ford        F150
# 10191                        Used  2019  Ford     Transit
# 10192                   Certified  2020  Ford        F150
# 10193                        Used  2023  Ford  Expedition
# 10194                        Used  2022  Ford    Maverick
# 10195                        Used  2023  Ford        F150
# 10196                        Used  2017  Ford        F150
# 10197                   Certified  2022  Ford        F350
# 10198                   Certified  2022  Ford      Ranger
# 10199                   Certified  2018  Ford      Fusion
# 10200                   Certified  2018  Ford    Explorer
# 10201                        Used  2019  Ford        Edge
# 10202                        Used  2020  Ford  Expedition
# 10203                        Used  2019  Ford  Expedition
# 10204                        Used  2019  Ford        F250
# 10205                        Used  2022  Ford     Mustang
# 10206                        Used  2021  Ford        F150
# 10207                        Used  2019  Ford        F150
# 10208                        Used  2021  Ford     Mustang
# 10209                        Used  2019  Ford        F250
# 10210                        Used  2020  Ford      Ranger
# 10211                        Used  2020  Ford  Expedition
# 10212                        Used  2017  Ford        F150
# 10213                        Used  2017  Ford        F250
# 10214                        Used  2022  Ford        F150
# 10215                        Used  2018  Ford     Mustang
# 10216                        Used  2022  Ford  Expedition
# 10217                        Used  2019  Ford        F150
# 10218                        Used  2019  Ford     Transit
# 10219                   Certified  2020  Ford        F150
# 10220                        Used  2023  Ford  Expedition
# 10221                        Used  2022  Ford    Maverick
# 10222                        Used  2023  Ford        F150
# 10223                        Used  2017  Ford        F150
# 10224                   Certified  2022  Ford        F350
# 10225                   Certified  2022  Ford      Ranger
# 10226                   Certified  2018  Ford      Fusion
# 10227                   Certified  2018  Ford    Explorer
# 10228                        Used  2019  Ford        Edge
# 10229                        Used  2020  Ford  Expedition
# 10230                        Used  2022  Ford      Bronco
# 10231                        Used  2022  Ford      Ranger
# 10232                        Used  2022  Ford     Mustang
# 10233                        Used  2021  Ford        F150
# 10234                        Used  2019  Ford        F150
# 10235                        Used  2021  Ford     Mustang
# 10236                        Used  2019  Ford        F250
# 10237                        Used  2017  Ford      Fiesta
# 10238                        Used  2020  Ford  Expedition
# 10239                        Used  2017  Ford        F150
# 10240                        Used  2017  Ford        F250
# 10241                        Used  2022  Ford        F150
# 10242                        Used  2018  Ford     Mustang
# 10243                        Used  2022  Ford  Expedition
# 10244                        Used  2019  Ford        F150
# 10245                        Used  2019  Ford     Transit
# 10246                   Certified  2020  Ford        F150
# 10247                        Used  2023  Ford  Expedition
# 10248                        Used  2022  Ford    Maverick
# 10249                        Used  2023  Ford        F150
# 10250                        Used  2017  Ford        F150
# 10251                   Certified  2022  Ford        F350
# 10252                   Certified  2022  Ford      Ranger
# 10253                   Certified  2018  Ford      Fusion
# 10254                   Certified  2018  Ford    Explorer
# 10255                        Used  2019  Ford        Edge
# 10256                        Used  2020  Ford  Expedition
# 10257                        Used  2019  Ford        F150
# 10258                        Used  2020  Ford    EcoSport
# 10259                        Used  2022  Ford     Mustang
# 10260                        Used  2021  Ford        F150
# 10261                        Used  2019  Ford        F150
# 10262                        Used  2021  Ford     Mustang
# 10263                        Used  2019  Ford        F250
# 10264                        Used  2020  Ford        F150
# 10265                        Used  2020  Ford  Expedition
# 10266                        Used  2017  Ford        F150
# 10267                        Used  2017  Ford        F250
# 10268                        Used  2022  Ford        F150
# 10269                        Used  2018  Ford     Mustang
# 10270                        Used  2022  Ford  Expedition
# 10271                        Used  2019  Ford        F150
# 10272                        Used  2019  Ford     Transit
# 10273                   Certified  2020  Ford        F150
# 10274                        Used  2023  Ford  Expedition
# 10275                        Used  2022  Ford    Maverick
# 10276                        Used  2023  Ford        F150
# 10277                        Used  2017  Ford        F150
# 10278                   Certified  2022  Ford        F350
# 10279                   Certified  2022  Ford      Ranger
# 10280                   Certified  2018  Ford      Fusion
# 10281                   Certified  2018  Ford    Explorer
# 10282                        Used  2019  Ford        Edge
# 10283                        Used  2020  Ford  Expedition
# 10284                   Certified  2021  Ford     Transit
# 10285                        Used  2022  Ford        F350
# 10286                        Used  2022  Ford     Mustang
# 10287                        Used  2021  Ford        F150
# 10288                        Used  2019  Ford        F150
# 10289                        Used  2021  Ford     Mustang
# 10290                        Used  2019  Ford        F250
# 10291                        Used  2022  Ford     Mustang
# 10292                        Used  2020  Ford  Expedition
# 10293                        Used  2017  Ford        F150
# 10294                        Used  2017  Ford        F250
# 10295                        Used  2022  Ford        F150
# 10296                        Used  2018  Ford     Mustang
# 10297                        Used  2022  Ford  Expedition
# 10298                        Used  2019  Ford        F150
# 10299                        Used  2019  Ford     Transit
# 10300                   Certified  2020  Ford        F150
# 10301                        Used  2023  Ford  Expedition
# 10302                        Used  2022  Ford    Maverick
# 10303                        Used  2023  Ford        F150
# 10304                        Used  2017  Ford        F150
# 10305                   Certified  2022  Ford        F350
# 10306                   Certified  2022  Ford      Ranger
# 10307                   Certified  2018  Ford      Fusion
# 10308                   Certified  2018  Ford    Explorer
# 10309                        Used  2019  Ford        Edge
# 10310                        Used  2020  Ford  Expedition
# 10311                        Used  2022  Ford        Edge
# 10312                        Used  2021  Ford     Transit
# 10313                        Used  2022  Ford     Mustang
# 10314                        Used  2021  Ford        F150
# 10315                        Used  2019  Ford        F150
# 10316                        Used  2021  Ford     Mustang
# 10317                        Used  2019  Ford        F250
# 10318                   Certified  2022  Ford      Escape
# 10319                        Used  2020  Ford  Expedition
# 10320                        Used  2017  Ford        F150
# 10321                        Used  2017  Ford        F250
# 10322                        Used  2022  Ford        F150
# 10323                        Used  2018  Ford     Mustang
# 10324                        Used  2022  Ford  Expedition
# 10325                        Used  2019  Ford        F150
# 10326                        Used  2019  Ford     Transit
# 10327                   Certified  2020  Ford        F150
# 10328                        Used  2023  Ford  Expedition
# 10329                        Used  2022  Ford    Maverick
# 10330                        Used  2023  Ford        F150
# 10331                        Used  2017  Ford        F150
# 10332                   Certified  2022  Ford        F350
# 10333                   Certified  2022  Ford      Ranger
# 10334                   Certified  2018  Ford      Fusion
# 10335                   Certified  2018  Ford    Explorer
# 10336                        Used  2019  Ford        Edge
# 10337                        Used  2020  Ford  Expedition
# 10338                   Certified  2018  Ford  Expedition
# 10339                        Used  2022  Ford      Escape
# 10340                        Used  2022  Ford     Mustang
# 10341                        Used  2021  Ford        F150
# 10342                        Used  2019  Ford        F150
# 10343                        Used  2021  Ford     Mustang
# 10344                        Used  2019  Ford        F250
# 10345                        Used  2019  Ford        F150
# 10346                        Used  2020  Ford  Expedition
# 10347                        Used  2017  Ford        F150
# 10348                        Used  2017  Ford        F250
# 10349                        Used  2022  Ford        F150
# 10350                        Used  2018  Ford     Mustang
# 10351                        Used  2022  Ford  Expedition
# 10352                        Used  2019  Ford        F150
# 10353                        Used  2019  Ford     Transit
# 10354                   Certified  2020  Ford        F150
# 10355                        Used  2023  Ford  Expedition
# 10356                        Used  2022  Ford    Maverick
# 10357                        Used  2023  Ford        F150
# 10358                        Used  2017  Ford        F150
# 10359                   Certified  2022  Ford        F350
# 10360                   Certified  2022  Ford      Ranger
# 10361                   Certified  2018  Ford      Fusion
# 10362                   Certified  2018  Ford    Explorer
# 10363                        Used  2019  Ford        Edge
# 10364                        Used  2020  Ford  Expedition
# 10365                        Used  2020  Ford        Edge
# 10366                        Used  2019  Ford  Expedition
# 10367                        Used  2022  Ford     Mustang
# 10368                        Used  2021  Ford        F150
# 10369                        Used  2019  Ford        F150
# 10370                        Used  2021  Ford     Mustang
# 10371                        Used  2019  Ford        F250
# 10372                        Used  2019  Ford        Edge
# 10373                        Used  2020  Ford  Expedition
# 10374                        Used  2017  Ford        F150
# 10375                        Used  2017  Ford        F250
# 10376                        Used  2022  Ford        F150
# 10377                        Used  2018  Ford     Mustang
# 10378                        Used  2022  Ford  Expedition
# 10379                        Used  2019  Ford        F150
# 10380                        Used  2019  Ford     Transit
# 10381                   Certified  2020  Ford        F150
# 10382                        Used  2023  Ford  Expedition
# 10383                        Used  2022  Ford    Maverick
# 10384                        Used  2023  Ford        F150
# 10385                        Used  2017  Ford        F150
# 10386                   Certified  2022  Ford        F350
# 10387                   Certified  2022  Ford      Ranger
# 10388                   Certified  2018  Ford      Fusion
# 10389                   Certified  2018  Ford    Explorer
# 10390                        Used  2019  Ford        Edge
# 10391                        Used  2020  Ford  Expedition
# 10392                        Used  2021  Ford        F150
# 10393                        Used  2019  Ford        F150
# 10394                        Used  2022  Ford     Mustang
# 10395                        Used  2021  Ford        F150
# 10396                        Used  2019  Ford        F150
# 10397                        Used  2021  Ford     Mustang
# 10398                        Used  2019  Ford        F250
# 10399                        Used  2020  Ford        F150
# 10400                        Used  2020  Ford  Expedition
# 10401                        Used  2017  Ford        F150
# 10402                        Used  2017  Ford        F250
# 10403                        Used  2022  Ford        F150
# 10404                        Used  2018  Ford     Mustang
# 10405                        Used  2022  Ford  Expedition
# 10406                        Used  2019  Ford        F150
# 10407                        Used  2019  Ford     Transit
# 10408                   Certified  2020  Ford        F150
# 10409                        Used  2023  Ford  Expedition
# 10410                        Used  2022  Ford    Maverick
# 10411                        Used  2023  Ford        F150
# 10412                        Used  2017  Ford        F150
# 10413                   Certified  2022  Ford        F350
# 10414                   Certified  2022  Ford      Ranger
# 10415                   Certified  2018  Ford      Fusion
# 10416                   Certified  2018  Ford    Explorer
# 10417                        Used  2019  Ford        Edge
# 10418                        Used  2020  Ford  Expedition
# 10419                        Used  2018  Ford        F250
# 10420                        Used  2021  Ford        F150
# 10421                        Used  2022  Ford     Mustang
# 10422                        Used  2021  Ford        F150
# 10423                        Used  2019  Ford        F150
# 10424                        Used  2021  Ford     Mustang
# 10425                        Used  2019  Ford        F250
# 10426                        Used  2022  Ford        F150
# 10427                        Used  2020  Ford  Expedition
# 10428                        Used  2017  Ford        F150
# 10429                        Used  2017  Ford        F250
# 10430                        Used  2022  Ford        F150
# 10431                        Used  2018  Ford     Mustang
# 10432                        Used  2022  Ford  Expedition
# 10433                        Used  2019  Ford        F150
# 10434                        Used  2019  Ford     Transit
# 10435                   Certified  2020  Ford        F150
# 10436                        Used  2023  Ford  Expedition
# 10437                        Used  2022  Ford    Maverick
# 10438                        Used  2023  Ford        F150
# 10439                        Used  2017  Ford        F150
# 10440                   Certified  2022  Ford        F350
# 10441                   Certified  2022  Ford      Ranger
# 10442                   Certified  2018  Ford      Fusion
# 10443                   Certified  2018  Ford    Explorer
# 10444                        Used  2019  Ford        Edge
# 10445                        Used  2020  Ford  Expedition
# 10446                        Used  2022  Ford        F150
# 10447                        Used  2020  Ford        F150
# 10448                        Used  2022  Ford     Mustang
# 10449                        Used  2021  Ford        F150
# 10450                        Used  2019  Ford        F150
# 10451                        Used  2021  Ford     Mustang
# 10452                        Used  2019  Ford        F250
# 10453                        Used  2018  Ford    EcoSport
# 10454                        Used  2020  Ford  Expedition
# 10455                        Used  2017  Ford        F150
# 10456                        Used  2017  Ford        F250
# 10457                        Used  2022  Ford        F150
# 10458                        Used  2018  Ford     Mustang
# 10459                        Used  2022  Ford  Expedition
# 10460                        Used  2019  Ford        F150
# 10461                        Used  2019  Ford     Transit
# 10462                   Certified  2020  Ford        F150
# 10463                        Used  2023  Ford  Expedition
# 10464                        Used  2022  Ford    Maverick
# 10465                        Used  2023  Ford        F150
# 10466                        Used  2017  Ford        F150
# 10467                   Certified  2022  Ford        F350
# 10468                   Certified  2022  Ford      Ranger
# 10469                   Certified  2018  Ford      Fusion
# 10470                   Certified  2018  Ford    Explorer
# 10471                        Used  2019  Ford        Edge
# 10472                        Used  2020  Ford  Expedition
# 10473                        Used  2019  Ford        F150
# 10474                        Used  2023  Ford        F150
# ...
# 10008      Pick up
# 10009      Pick up
# 10010        Sedan
# 10011          SUV
# 10012          SUV
# 10013          SUV
# 10014      Pick up
# 10015        Sedan
# 10016        Coupe
# 10017      Pick up
# 10018      Pick up
# 10019        Coupe
# 10020      Pick up
# 10021          SUV
# 10022          SUV
# 10023      Pick up
# 10024      Pick up
# 10025      Pick up
# 10026        Coupe
# 10027          SUV
# 10028      Pick up
# 10029          Van
# 10030      Pick up
# 10031          SUV
# 10032      Pick up
# 10033      Pick up
# 10034      Pick up
# 10035      Pick up
# 10036      Pick up
# 10037        Sedan
# 10038          SUV
# 10039          SUV
# 10040          SUV
# 10041          SUV
# 10042          SUV
# 10043        Coupe
# 10044      Pick up
# 10045      Pick up
# 10046        Coupe
# 10047      Pick up
# 10048        Sedan
# 10049          SUV
# 10050      Pick up
# 10051      Pick up
# 10052      Pick up
# 10053        Coupe
# 10054          SUV
# 10055      Pick up
# 10056          Van
# 10057      Pick up
# 10058          SUV
# 10059      Pick up
# 10060      Pick up
# 10061      Pick up
# 10062      Pick up
# 10063      Pick up
# 10064        Sedan
# 10065          SUV
# 10066          SUV
# 10067          SUV
# 10068        Coupe
# 10069          SUV
# 10070        Coupe
# 10071      Pick up
# 10072      Pick up
# 10073        Coupe
# 10074      Pick up
# 10075          SUV
# 10076          SUV
# 10077      Pick up
# 10078      Pick up
# 10079      Pick up
# 10080        Coupe
# 10081          SUV
# 10082      Pick up
# 10083          Van
# 10084      Pick up
# 10085          SUV
# 10086      Pick up
# 10087      Pick up
# 10088      Pick up
# 10089      Pick up
# 10090      Pick up
# 10091        Sedan
# 10092          SUV
# 10093          SUV
# 10094          SUV
# 10095      Pick up
# 10096          SUV
# 10097        Coupe
# 10098      Pick up
# 10099      Pick up
# 10100        Coupe
# 10101      Pick up
# 10102      Pick up
# 10103          SUV
# 10104      Pick up
# 10105      Pick up
# 10106      Pick up
# 10107        Coupe
# 10108          SUV
# 10109      Pick up
# 10110          Van
# 10111      Pick up
# 10112          SUV
# 10113      Pick up
# 10114      Pick up
# 10115      Pick up
# 10116      Pick up
# 10117      Pick up
# 10118        Sedan
# 10119          SUV
# 10120          SUV
# 10121          SUV
# 10122          SUV
# 10123      Pick up
# 10124        Coupe
# 10125      Pick up
# 10126      Pick up
# 10127        Coupe
# 10128      Pick up
# 10129          SUV
# 10130          SUV
# 10131      Pick up
# 10132      Pick up
# 10133      Pick up
# 10134        Coupe
# 10135          SUV
# 10136      Pick up
# 10137          Van
# 10138      Pick up
# 10139          SUV
# 10140      Pick up
# 10141      Pick up
# 10142      Pick up
# 10143      Pick up
# 10144      Pick up
# 10145        Sedan
# 10146          SUV
# 10147          SUV
# 10148          SUV
# 10149          SUV
# 10150          SUV
# 10151        Coupe
# 10152      Pick up
# 10153      Pick up
# 10154        Coupe
# 10155      Pick up
# 10156      Pick up
# 10157          SUV
# 10158      Pick up
# 10159      Pick up
# 10160      Pick up
# 10161        Coupe
# 10162          SUV
# 10163      Pick up
# 10164          Van
# 10165      Pick up
# 10166          SUV
# 10167      Pick up
# 10168      Pick up
# 10169      Pick up
# 10170      Pick up
# 10171      Pick up
# 10172        Sedan
# 10173          SUV
# 10174          SUV
# 10175          SUV
# 10176      Pick up
# 10177      Pick up
# 10178        Coupe
# 10179      Pick up
# 10180      Pick up
# 10181        Coupe
# 10182      Pick up
# 10183          SUV
# 10184          SUV
# 10185      Pick up
# 10186      Pick up
# 10187      Pick up
# 10188        Coupe
# 10189          SUV
# 10190      Pick up
# 10191          Van
# 10192      Pick up
# 10193          SUV
# 10194      Pick up
# 10195      Pick up
# 10196      Pick up
# 10197      Pick up
# 10198      Pick up
# 10199        Sedan
# 10200          SUV
# 10201          SUV
# 10202          SUV
# 10203          SUV
# 10204      Pick up
# 10205        Coupe
# 10206      Pick up
# 10207      Pick up
# 10208        Coupe
# 10209      Pick up
# 10210      Pick up
# 10211          SUV
# 10212      Pick up
# 10213      Pick up
# 10214      Pick up
# 10215        Coupe
# 10216          SUV
# 10217      Pick up
# 10218          Van
# 10219      Pick up
# 10220          SUV
# 10221      Pick up
# 10222      Pick up
# 10223      Pick up
# 10224      Pick up
# 10225      Pick up
# 10226        Sedan
# 10227          SUV
# 10228          SUV
# 10229          SUV
# 10230          SUV
# 10231      Pick up
# 10232        Coupe
# 10233      Pick up
# 10234      Pick up
# 10235        Coupe
# 10236      Pick up
# 10237        Sedan
# 10238          SUV
# 10239      Pick up
# 10240      Pick up
# 10241      Pick up
# 10242        Coupe
# 10243          SUV
# 10244      Pick up
# 10245          Van
# 10246      Pick up
# 10247          SUV
# 10248      Pick up
# 10249      Pick up
# 10250      Pick up
# 10251      Pick up
# 10252      Pick up
# 10253        Sedan
# 10254          SUV
# 10255          SUV
# 10256          SUV
# 10257      Pick up
# 10258          SUV
# 10259        Coupe
# 10260      Pick up
# 10261      Pick up
# 10262        Coupe
# 10263      Pick up
# 10264      Pick up
# 10265          SUV
# 10266      Pick up
# 10267      Pick up
# 10268      Pick up
# 10269        Coupe
# 10270          SUV
# 10271      Pick up
# 10272          Van
# 10273      Pick up
# 10274          SUV
# 10275      Pick up
# 10276      Pick up
# 10277      Pick up
# 10278      Pick up
# 10279      Pick up
# 10280        Sedan
# 10281          SUV
# 10282          SUV
# 10283          SUV
# 10284          Van
# 10285      Pick up
# 10286        Coupe
# 10287      Pick up
# 10288      Pick up
# 10289        Coupe
# 10290      Pick up
# 10291        Coupe
# 10292          SUV
# 10293      Pick up
# 10294      Pick up
# 10295      Pick up
# 10296        Coupe
# 10297          SUV
# 10298      Pick up
# 10299          Van
# 10300      Pick up
# 10301          SUV
# 10302      Pick up
# 10303      Pick up
# 10304      Pick up
# 10305      Pick up
# 10306      Pick up
# 10307        Sedan
# 10308          SUV
# 10309          SUV
# 10310          SUV
# 10311          SUV
# 10312          Van
# 10313        Coupe
# 10314      Pick up
# 10315      Pick up
# 10316        Coupe
# 10317      Pick up
# 10318          SUV
# 10319          SUV
# 10320      Pick up
# 10321      Pick up
# 10322      Pick up
# 10323        Coupe
# 10324          SUV
# 10325      Pick up
# 10326          Van
# 10327      Pick up
# 10328          SUV
# 10329      Pick up
# 10330      Pick up
# 10331      Pick up
# 10332      Pick up
# 10333      Pick up
# 10334        Sedan
# 10335          SUV
# 10336          SUV
# 10337          SUV
# 10338          SUV
# 10339          SUV
# 10340        Coupe
# 10341      Pick up
# 10342      Pick up
# 10343        Coupe
# 10344      Pick up
# 10345      Pick up
# 10346          SUV
# 10347      Pick up
# 10348      Pick up
# 10349      Pick up
# 10350        Coupe
# 10351          SUV
# 10352      Pick up
# 10353          Van
# 10354      Pick up
# 10355          SUV
# 10356      Pick up
# 10357      Pick up
# 10358      Pick up
# 10359      Pick up
# 10360      Pick up
# 10361        Sedan
# 10362          SUV
# 10363          SUV
# 10364          SUV
# 10365          SUV
# 10366          SUV
# 10367        Coupe
# 10368      Pick up
# 10369      Pick up
# 10370        Coupe
# 10371      Pick up
# 10372          SUV
# 10373          SUV
# 10374      Pick up
# 10375      Pick up
# 10376      Pick up
# 10377        Coupe
# 10378          SUV
# 10379      Pick up
# 10380          Van
# 10381      Pick up
# 10382          SUV
# 10383      Pick up
# 10384      Pick up
# 10385      Pick up
# 10386      Pick up
# 10387      Pick up
# 10388        Sedan
# 10389          SUV
# 10390          SUV
# 10391          SUV
# 10392      Pick up
# 10393      Pick up
# 10394        Coupe
# 10395      Pick up
# 10396      Pick up
# 10397        Coupe
# 10398      Pick up
# 10399      Pick up
# 10400          SUV
# 10401      Pick up
# 10402      Pick up
# 10403      Pick up
# 10404        Coupe
# 10405          SUV
# 10406      Pick up
# 10407          Van
# 10408      Pick up
# 10409          SUV
# 10410      Pick up
# 10411      Pick up
# 10412      Pick up
# 10413      Pick up
# 10414      Pick up
# 10415        Sedan
# 10416          SUV
# 10417          SUV
# 10418          SUV
# 10419      Pick up
# 10420      Pick up
# 10421        Coupe
# 10422      Pick up
# 10423      Pick up
# 10424        Coupe
# 10425      Pick up
# 10426      Pick up
# 10427          SUV
# 10428      Pick up
# 10429      Pick up
# 10430      Pick up
# 10431        Coupe
# 10432          SUV
# 10433      Pick up
# 10434          Van
# 10435      Pick up
# 10436          SUV
# 10437      Pick up
# 10438      Pick up
# 10439      Pick up
# 10440      Pick up
# 10441      Pick up
# 10442        Sedan
# 10443          SUV
# 10444          SUV
# 10445          SUV
# 10446      Pick up
# 10447      Pick up
# 10448        Coupe
# 10449      Pick up
# 10450      Pick up
# 10451        Coupe
# 10452      Pick up
# 10453          SUV
# 10454          SUV
# 10455      Pick up
# 10456      Pick up
# 10457      Pick up
# 10458        Coupe
# 10459          SUV
# 10460      Pick up
# 10461          Van
# 10462      Pick up
# 10463          SUV
# 10464      Pick up
# 10465      Pick up
# 10466      Pick up
# 10467      Pick up
# 10468      Pick up
# 10469        Sedan
# 10470          SUV
# 10471          SUV
# 10472          SUV
# 10473      Pick up
# 10474      Pick up
# 10475        Coupe
# 10476      Pick up
# 10477      Pick up
# 10478        Coupe
# 10479      Pick up
# 10480          SUV
# 10481          SUV
# 10482      Pick up
# 10483      Pick up
# 10484      Pick up
# 10485        Coupe
# 10486          SUV
# 10487      Pick up
# 10488          Van
# 10489      Pick up
# 10490          SUV
# 10491      Pick up
# 10492      Pick up
# 10493      Pick up
# 10494      Pick up
# 10495      Pick up
# 10496        Sedan
# 10497          SUV
# 10498          SUV
# 10499          SUV
# 10500          SUV
# 10501      Pick up
# 10502        Coupe
# 10503      Pick up
# 10504      Pick up
# 10505        Coupe
# 10506      Pick up
# 10507      Pick up
# 10508          SUV
# 10509      Pick up
# 10510      Pick up
# 10511      Pick up
# 10512        Coupe
# 10513          SUV
# 10514      Pick up
# 10515          Van
# 10516      Pick up
# 10517          SUV
# 10518      Pick up
# 10519      Pick up
# 10520      Pick up
# 10521      Pick up
# 10522      Pick up
# 10523        Sedan
# 10524          SUV
# 10525          SUV
# 10526          SUV
# 10527        Sedan
# 10528          SUV
# 10529        Coupe
# 10530      Pick up
# 10531      Pick up
# 10532        Coupe
# 10533      Pick up
# 10534      Pick up
# 10535          SUV
# 10536      Pick up
# 10537      Pick up
# 10538      Pick up
# 10539        Coupe
# 10540          SUV
# 10541      Pick up
# 10542          Van
# 10543      Pick up
# 10544          SUV
# 10545      Pick up
# 10546      Pick up
# 10547      Pick up
# 10548      Pick up
# 10549      Pick up
# 10550        Sedan
# 10551          SUV
# 10552          SUV
# 10553          SUV
# 10554          SUV
# 10555          SUV
# 10556        Coupe
# 10557      Pick up
# 10558      Pick up
# 10559        Coupe
# 10560      Pick up
# 10561      Pick up
# 10562          SUV
# 10563      Pick up
# 10564      Pick up
# 10565      Pick up
# 10566        Coupe
# 10567          SUV
# 10568      Pick up
# 10569          Van
# 10570      Pick up
# 10571          SUV
# 10572      Pick up
# 10573      Pick up
# 10574      Pick up
# 10575      Pick up
# 10576      Pick up
# 10577        Sedan
# 10578          SUV
# 10579          SUV
# 10580          SUV
# 10581      Pick up
# 10582          SUV
# 10583        Coupe
# 10584      Pick up
# 10585      Pick up
# 10586        Coupe
# 10587      Pick up
# 10588          SUV
# 10589          SUV
# 10590      Pick up
# 10591      Pick up
# 10592      Pick up
# 10593        Coupe
# 10594          SUV
# 10595      Pick up
# 10596          Van
# 10597      Pick up
# 10598          SUV
# 10599      Pick up
# 10600      Pick up
# 10601      Pick up
# 10602      Pick up
# 10603      Pick up
# 10604        Sedan
# 10605          SUV
# 10606          SUV
# 10607          SUV
# 10608          SUV
# 10609      Pick up
# 10610        Coupe
# 10611      Pick up
# 10612      Pick up
# 10613        Coupe
# 10614      Pick up
# 10615        Sedan
# 10616          SUV
# 10617      Pick up
# 10618      Pick up
# 10619      Pick up
# 10620        Coupe
# 10621          SUV
# 10622      Pick up
# 10623          Van
# 10624      Pick up
# 10625          SUV
# 10626      Pick up
# 10627      Pick up
# 10628      Pick up
# 10629      Pick up
# 10630      Pick up
# 10631        Sedan
# 10632          SUV
# 10633          SUV
# 10634          SUV
# 10635      Pick up
# 10636        Sedan
# 10637        Coupe
# 10638      Pick up
# 10639      Pick up
# 10640        Coupe
# 10641      Pick up
# 10642      Pick up
# 10643          SUV
# 10644      Pick up
# 10645      Pick up
# 10646      Pick up
# 10647        Coupe
# 10648          SUV
# 10649      Pick up
# 10650          Van
# 10651      Pick up
# 10652          SUV
# 10653      Pick up
# 10654      Pick up
# 10655      Pick up
# 10656      Pick up
# 10657      Pick up
# 10658        Sedan
# 10659          SUV
# 10660          SUV
# 10661          SUV
# 10662      Pick up
# 10663          SUV
# 10664        Coupe
# 10665      Pick up
# 10666      Pick up
# 10667        Coupe
# 10668      Pick up
# 10669      Pick up
# 10670          SUV
# 10671      Pick up
# 10672      Pick up
# 10673      Pick up
# 10674        Coupe
# 10675          SUV
# 10676      Pick up
# 10677          Van
# 10678      Pick up
# 10679          SUV
# 10680      Pick up
# 10681      Pick up
# 10682      Pick up
# 10683      Pick up
# 10684      Pick up
# 10685        Sedan
# 10686          SUV
# 10687          SUV
# 10688          SUV
# 10689      Pick up
# 10690      Pick up
# 10691        Coupe
# 10692      Pick up
# 10693      Pick up
# 10694        Coupe
# 10695      Pick up
# 10696          SUV
# 10697          SUV
# 10698      Pick up
# 10699      Pick up
# 10700      Pick up
# 10701        Coupe
# 10702          SUV
# 10703      Pick up
# 10704          Van
# 10705      Pick up
# 10706          SUV
# 10707      Pick up
# 10708      Pick up
# 10709      Pick up
# 10710      Pick up
# 10711      Pick up
# 10712        Sedan
# 10713          SUV
# 10714          SUV
# 10715          SUV
# 10716          SUV
# 10717      Pick up
# 10718        Coupe
# 10719      Pick up
# 10720      Pick up
# 10721        Coupe
# 10722      Pick up
# 10723          SUV
# 10724          SUV
# 10725      Pick up
# 10726      Pick up
# 10727      Pick up
# 10728        Coupe
# 10729          SUV
# 10730      Pick up
# 10731          Van
# 10732      Pick up
# 10733          SUV
# 10734      Pick up
# 10735      Pick up
# 10736      Pick up
# 10737      Pick up
# 10738      Pick up
# 10739        Sedan
# 10740          SUV
# 10741          SUV
# 10742          SUV
# 10743          SUV
# 10744        Sedan
# 10745        Coupe
# 10746      Pick up
# 10747      Pick up
# 10748        Coupe
# 10749      Pick up
# 10750      Pick up
# 10751          SUV
# 10752      Pick up
# 10753      Pick up
# 10754      Pick up
# 10755        Coupe
# 10756          SUV
# 10757      Pick up
# 10758          Van
# 10759      Pick up
# 10760          SUV
# 10761      Pick up
# 10762      Pick up
# 10763      Pick up
# 10764      Pick up
# 10765      Pick up
# 10766        Sedan
# 10767          SUV
# 10768          SUV
# 10769          SUV

# %%
#extracting Maverick models
maverick = ford_cars[ford_cars['model'] == 'Maverick'] 

print(maverick.count())

#extracting all above 0 
maverick_greater = maverick[maverick['price'] > 0]

print(maverick_greater.count())

#looking at mean median mode std and quartile ranges
maverick_average = maverick_greater['price'].mean()
maverick_median = maverick_greater['price'].median()
maverick_mode = maverick_greater['price'].mode()

print('median:', maverick_median, 'average:', maverick_average)
print ()
print('mode')
print(maverick_mode)
print()
print(maverick_greater.describe())
# Out:
# Used Vehicle Classification    40
# year                           40
# make                           40
# model                          40
# packages                       40
# price                          40
# mileage                        40
# engine_type                    40
# transmission_type              40
# drivetrain                     40
# color                          40
# vehicle_type                   40
# dtype: int64
# Used Vehicle Classification    0
# year                           0
# make                           0
# model                          0
# packages                       0
# price                          0
# mileage                        0
# engine_type                    0
# transmission_type              0
# drivetrain                     0
# color                          0
# vehicle_type                   0
# dtype: int64
# median: nan average: nan
#
# mode
# Series([], Name: price, dtype: int32)
#
#        price  mileage
# count    0.0      0.0
# mean     NaN      NaN
# std      NaN      NaN
# min      NaN      NaN
# 25%      NaN      NaN
# 50%      NaN      NaN
# 75%      NaN      NaN
# max      NaN      NaN

# %% [markdown]
# #### Note:
#
# It seems the webscrape picked up the same model Maverick 40 times with no value. This also will be dropped.

# %%
kbb_cleaned = kbb_cleaned[kbb_cleaned['model'] != 'Maverick']

kbb_cleaned[kbb_cleaned['model'] == "Maverick"]
# Out:
# Empty DataFrame
# Columns: [Used Vehicle Classification, year, make, model, packages, price, mileage, engine_type, transmission_type, drivetrain, color, vehicle_type]
# Index: []

# %%
#extracting Expedition models
edge = ford_cars[ford_cars['model'] == 'Edge'] 

print(edge.count())
print(edge)

#extracting all above 0 
edge_greater = edge[edge['price'] > 0].count()

print(edge_greater)
# Out:
# Used Vehicle Classification    49
# year                           49
# make                           49
# model                          49
# packages                       49
# price                          49
# mileage                        49
# engine_type                    49
# transmission_type              49
# drivetrain                     49
# color                          49
# vehicle_type                   49
# dtype: int64
#       Used Vehicle Classification  year  make model  \
# 9715                         Used  2019  Ford  Edge
# 9724                         Used  2022  Ford  Edge
# 9742                         Used  2019  Ford  Edge
# 9769                         Used  2019  Ford  Edge
# 9778                         Used  2020  Ford  Edge
# 9796                         Used  2019  Ford  Edge
# 9823                         Used  2019  Ford  Edge
# 9850                         Used  2019  Ford  Edge
# 9877                         Used  2019  Ford  Edge
# 9904                         Used  2019  Ford  Edge
# 9931                         Used  2019  Ford  Edge
# 9958                         Used  2019  Ford  Edge
# 9985                         Used  2019  Ford  Edge
# 9988                         Used  2019  Ford  Edge
# 10012                        Used  2019  Ford  Edge
# 10039                        Used  2019  Ford  Edge
# 10066                        Used  2019  Ford  Edge
# 10069                        Used  2020  Ford  Edge
# 10093                        Used  2019  Ford  Edge
# 10120                        Used  2019  Ford  Edge
# 10147                        Used  2019  Ford  Edge
# 10149                        Used  2019  Ford  Edge
# 10174                        Used  2019  Ford  Edge
# 10201                        Used  2019  Ford  Edge
# 10228                        Used  2019  Ford  Edge
# 10255                        Used  2019  Ford  Edge
# 10282                        Used  2019  Ford  Edge
# 10309                        Used  2019  Ford  Edge
# 10311                        Used  2022  Ford  Edge
# 10336                        Used  2019  Ford  Edge
# 10363                        Used  2019  Ford  Edge
# 10365                        Used  2020  Ford  Edge
# 10372                        Used  2019  Ford  Edge
# 10390                        Used  2019  Ford  Edge
# 10417                        Used  2019  Ford  Edge
# 10444                        Used  2019  Ford  Edge
# 10471                        Used  2019  Ford  Edge
# 10498                        Used  2019  Ford  Edge
# 10525                        Used  2019  Ford  Edge
# 10552                        Used  2019  Ford  Edge
# 10579                        Used  2019  Ford  Edge
# 10606                        Used  2019  Ford  Edge
# 10608                        Used  2018  Ford  Edge
# 10633                        Used  2019  Ford  Edge
# 10660                        Used  2019  Ford  Edge
# 10687                        Used  2019  Ford  Edge
# 10714                        Used  2019  Ford  Edge
# 10741                        Used  2019  Ford  Edge
# 10768                        Used  2019  Ford  Edge
#
#                               packages  price  mileage       engine_type  \
# 9715       SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 9724                                ST  38911    22690  6-Cylinder Turbo
# 9742       SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 9769       SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 9778                          Titanium  26990    67765  4-Cylinder Turbo
# 9796       SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 9823       SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 9850       SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 9877       SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 9904       SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 9931       SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 9958       SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 9985       SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 9988                               SEL  19659    97476  4-Cylinder Turbo
# 10012      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10039      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10066      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10069        SEL w/ Convenience Packag  24045    34245  4-Cylinder Turbo
# 10093      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10120      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10147      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10149       ST w/ Equipment Group 401A  27995    70817  6-Cylinder Turbo
# 10174      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10201      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10228      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10255      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10282      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10309      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10311        SEL w/ Convenience Packag  36212     2028  4-Cylinder Turbo
# 10336      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10363      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10365                              SEL  24490    35557  4-Cylinder Turbo
# 10372       ST w/ Equipment Group 401A  25996    74267  6-Cylinder Turbo
# 10390      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10417      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10444      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10471      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10498      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10525      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10552      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10579      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10606      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10608  SEL w/ Ford Safe & Smart Packag  19899    54026  4-Cylinder Turbo
# 10633      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10660      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10687      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10714      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10741      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
# 10768      SEL w/ Equipment Group 201A      0    58253  4-Cylinder Turbo
#
#       transmission_type drivetrain  color vehicle_type
# 9715          Automatic        FWD    Red          SUV
# 9724          Automatic        AWD    Red          SUV
# 9742          Automatic        FWD    Red          SUV
# 9769          Automatic        FWD    Red          SUV
# 9778          Automatic        FWD   Gold          SUV
# 9796          Automatic        FWD    Red          SUV
# 9823          Automatic        FWD    Red          SUV
# 9850          Automatic        FWD    Red          SUV
# 9877          Automatic        FWD    Red          SUV
# 9904          Automatic        FWD    Red          SUV
# 9931          Automatic        FWD    Red          SUV
# 9958          Automatic        FWD    Red          SUV
# 9985          Automatic        FWD    Red          SUV
# 9988          Automatic        AWD  Black          SUV
# 10012         Automatic        FWD    Red          SUV
# 10039         Automatic        FWD    Red          SUV
# 10066         Automatic        FWD    Red          SUV
# 10069         Automatic        AWD  Black          SUV
# 10093         Automatic        FWD    Red          SUV
# 10120         Automatic        FWD    Red          SUV
# 10147         Automatic        FWD    Red          SUV
# 10149         Automatic        AWD   Blue          SUV
# 10174         Automatic        FWD    Red          SUV
# 10201         Automatic        FWD    Red          SUV
# 10228         Automatic        FWD    Red          SUV
# 10255         Automatic        FWD    Red          SUV
# 10282         Automatic        FWD    Red          SUV
# 10309         Automatic        FWD    Red          SUV
# 10311         Automatic        AWD  White          SUV
# 10336         Automatic        FWD    Red          SUV
# 10363         Automatic        FWD    Red          SUV
# 10365         Automatic        AWD   Gray          SUV
# 10372         Automatic        AWD    Red          SUV
# 10390         Automatic        FWD    Red          SUV
# 10417         Automatic        FWD    Red          SUV
# 10444         Automatic        FWD    Red          SUV
# 10471         Automatic        FWD    Red          SUV
# 10498         Automatic        FWD    Red          SUV
# 10525         Automatic        FWD    Red          SUV
# 10552         Automatic        FWD    Red          SUV
# 10579         Automatic        FWD    Red          SUV
# 10606         Automatic        FWD    Red          SUV
# 10608         Automatic        FWD   Blue          SUV
# 10633         Automatic        FWD    Red          SUV
# 10660         Automatic        FWD    Red          SUV
# 10687         Automatic        FWD    Red          SUV
# 10714         Automatic        FWD    Red          SUV
# 10741         Automatic        FWD    Red          SUV
# 10768         Automatic        FWD    Red          SUV
# Used Vehicle Classification    9
# year                           9
# make                           9
# model                          9
# packages                       9
# price                          9
# mileage                        9
# engine_type                    9
# transmission_type              9
# drivetrain                     9
# color                          9
# vehicle_type                   9
# dtype: int64

# %% [markdown]
# #### Notes:
#
# I have 49 Ford Edges and 9 only with a value the other 40 again are duplicates.
# Going to drop the duplicates and pull the estimated value for the 10th edge. With the mileage and trim it looks like it averages around 22,000 dollars. Ill update the 0 models with the value of 22,000 and than drop the duplicates. It will limit my size to 10 vehicles but its better than having 49 with 40 of them being 22,000.

# %%
#changing price 
kbb_cleaned.loc[(kbb_cleaned['model'] == 'Edge') & (kbb_cleaned['price'] == 0), 'price'] = 22000

#dropping duplicates
kbb_cleaned.loc[(kbb_cleaned['model'] == 'Edge') & (kbb_cleaned['price'] == 22000)] = kbb_cleaned.loc[(kbb_cleaned['model'] == 'Edge') & (kbb_cleaned['price'] == 22000)].drop_duplicates()

# %%
kbb_cleaned.loc[(kbb_cleaned['model'] == 'Edge')].count()
# Out:
# Used Vehicle Classification    10
# year                           10
# make                           10
# model                          10
# packages                       10
# price                          10
# mileage                        10
# engine_type                    10
# transmission_type              10
# drivetrain                     10
# color                          10
# vehicle_type                   10
# dtype: int64

# %%
#checking duplicates again 

# exploring price at 0 by manufacturer
kbb_cleaned[kbb_cleaned['price'] == 0].groupby('make').count()
# Out:
#                Used Vehicle Classification  year  model  packages  price  \
# make
# Acura                                    1     1      1         1      1
# Audi                                     1     1      1         1      1
# BMW                                      1     1      1         1      1
# Buick                                    1     1      1         1      1
# Chrysler                                40    40     40        40     40
# Dodge                                   40    40     40        40     40
# Ford                                     1     1      1         1      1
# GMC                                     41    41     41        41     41
# Honda                                    2     2      2         2      2
# Hyundai                                  1     1      1         1      1
# INFINITI                                 1     1      1         1      1
# Jeep                                    41    41     41        41     41
# Kia                                      1     1      1         1      1
# Lexus                                    1     1      1         1      1
# Lincoln                                 40    40     40        40     40
# MAZDA                                    1     1      1         1      1
# MINI                                     3     3      3         3      3
# Maserati                                 1     1      1         1      1
# Mercedes-Benz                            1     1      1         1      1
# Mitsubishi                               4     4      4         4      4
# Nissan                                   2     2      2         2      2
# Porsche                                 81    81     81        81     81
# RAM                                     80    80     80        80     80
# Tesla                                   41    41     41        41     41
# Volkswagen                              81    81     81        81     81
#
#                mileage  engine_type  transmission_type  drivetrain  color  \
# make
# Acura                1            1                  1           1      1
# Audi                 1            1                  1           1      1
# BMW                  1            1                  1           1      1
# Buick                1            1                  1           1      1
# Chrysler            40           40                 40          40     40
# Dodge               40           40                 40          40     40
# Ford                 1            1                  1           1      1
# GMC                 41           41                 41          41     41
# Honda                2            2                  2           2      2
# Hyundai              1            1                  1           1      1
# INFINITI             1            1                  1           1      1
# Jeep                41           41                 41          41     41
# Kia                  1            1                  1           1      1
# Lexus                1            1                  1           1      1
# Lincoln             40           40                 40          40     40
# MAZDA                1            1                  1           1      1
# MINI                 3            3                  3           3      3
# Maserati             1            1                  1           1      1
# Mercedes-Benz        1            1                  1           1      1
# Mitsubishi           4            4                  4           4      4
# Nissan               2            2                  2           2      2
# Porsche             81           81                 81          81     81
# RAM                 80           80                 80          80     80
# Tesla               41           41                 41          41     41
# Volkswagen          81           81                 81          81     81
#
#                vehicle_type
# make
# Acura                     1
# Audi                      1
# BMW                       1
# Buick                     1
# Chrysler                 40
# Dodge                    40
# Ford                      1
# GMC                      41
# Honda                     2
# Hyundai                   1
# INFINITI                  1
# Jeep                     41
# Kia                       1
# Lexus                     1
# Lincoln                  40
# MAZDA                     1
# MINI                      3
# Maserati                  1
# Mercedes-Benz             1
# Mitsubishi                4
# Nissan                    2
# Porsche                  81
# RAM                      80
# Tesla                    41
# Volkswagen               81

# %%
#extracting just chrysler
chry_cars = kbb_cleaned[kbb_cleaned['make']== 'Chrysler']

print(chry_cars.count())
#seperating out the 0 values
chry_cars_zero = chry_cars[chry_cars['price'] == 0]

#viewing the missing amounts in each type
chry_cars_zero['model'].value_counts()
# Out:
# Used Vehicle Classification    1080
# year                           1080
# make                           1080
# model                          1080
# packages                       1080
# price                          1080
# mileage                        1080
# engine_type                    1080
# transmission_type              1080
# drivetrain                     1080
# color                          1080
# vehicle_type                   1080
# dtype: int64
# Pacifica    40
# Name: model, dtype: int64

# %% [markdown]
# #### Notes:
#
# Im going to continue to go through the ones with 40+ missing values to clean the dataset further

# %%
#extracting chrysler 300 models with 0 price 
threehundred = chry_cars_zero[chry_cars_zero['model'] == '300'] 

print(threehundred.count())

#extracting all above 0 
threehundred_greater = chry_cars[(chry_cars['model'] == '300') & (chry_cars['price'] > 0)]

print(threehundred_greater.count())

#looking at mean median mode std and quartile ranges
threehundred_average = threehundred_greater['price'].mean()
threehundred_median = threehundred_greater['price'].median()
threehundred_mode = threehundred_greater['price'].mode()

print('median:', threehundred_median)
print ()
print('mode')
print(threehundred_mode)
print()
print(threehundred_greater.describe())
# Out:
# Used Vehicle Classification    0
# year                           0
# make                           0
# model                          0
# packages                       0
# price                          0
# mileage                        0
# engine_type                    0
# transmission_type              0
# drivetrain                     0
# color                          0
# vehicle_type                   0
# dtype: int64
# Used Vehicle Classification    270
# year                           270
# make                           270
# model                          270
# packages                       270
# price                          270
# mileage                        270
# engine_type                    270
# transmission_type              270
# drivetrain                     270
# color                          270
# vehicle_type                   270
# dtype: int64
# median: 25523.5
#
# mode
# 0    17899.0
# 1    21863.0
# 2    23772.0
# 3    25732.0
# 4    27993.0
# 5    53310.0
# Name: price, dtype: float64
#
#               price        mileage
# count    270.000000     270.000000
# mean   28119.962963   67431.681481
# std    11084.330438   37687.598142
# min    14997.000000    1267.000000
# 25%    21863.000000   50546.000000
# 50%    25523.500000   59557.000000
# 75%    27993.000000   84430.000000
# max    53310.000000  142562.000000

# %%
#updating chrysler 300 with the median 

#updating with median 
kbb_cleaned.loc[(kbb_cleaned['make'] == 'Chrysler') & (kbb_cleaned['model'] == '300') & (kbb_cleaned['price'] == 0), 'price'] = 53310 

#checking to make sure it updated. 
kbb_cleaned[(kbb_cleaned['make'] == 'Chrysler') & (kbb_cleaned['model'] == '300') & (kbb_cleaned['price'] > 0)].count()
# Out:
# Used Vehicle Classification    270
# year                           270
# make                           270
# model                          270
# packages                       270
# price                          270
# mileage                        270
# engine_type                    270
# transmission_type              270
# drivetrain                     270
# color                          270
# vehicle_type                   270
# dtype: int64

# %%
#extracting chrysler pacifica models with 0 price 
threehundred = chry_cars_zero[chry_cars_zero['model'] == 'Pacifica'] 

print(threehundred.count())

#extracting all above 0 
threehundred_greater = chry_cars[(chry_cars['model'] == 'Pacifica') & (chry_cars['price'] > 0)]

print(threehundred_greater.count())

#looking at mean median mode std and quartile ranges
threehundred_average = threehundred_greater['price'].mean()
threehundred_median = threehundred_greater['price'].median()
threehundred_mode = threehundred_greater['price'].mode()

print('median:', threehundred_median)
print ()
print('mode')
print(threehundred_mode)
print()
print(threehundred_greater.describe())
# Out:
# Used Vehicle Classification    40
# year                           40
# make                           40
# model                          40
# packages                       40
# price                          40
# mileage                        40
# engine_type                    40
# transmission_type              40
# drivetrain                     40
# color                          40
# vehicle_type                   40
# dtype: int64
# Used Vehicle Classification    673
# year                           673
# make                           673
# model                          673
# packages                       673
# price                          673
# mileage                        673
# engine_type                    673
# transmission_type              673
# drivetrain                     673
# color                          673
# vehicle_type                   673
# dtype: int64
# median: 24868.0
#
# mode
# 0     16565.0
# 1     17878.0
# 2     18352.0
# 3     19800.0
# 4     19998.0
# 5     20525.0
# 6     21990.0
# 7     24498.0
# 8     24868.0
# 9     25194.0
# 10    25234.0
# 11    27100.0
# 12    27447.0
# 13    27717.0
# 14    32516.0
# Name: price, dtype: float64
#
#               price        mileage
# count    673.000000     673.000000
# mean   24024.786033   63758.038633
# std     5153.180087   20282.094706
# min    15748.000000    1128.000000
# 25%    19998.000000   49958.000000
# 50%    24868.000000   63761.000000
# 75%    27447.000000   81850.000000
# max    47422.000000  142355.000000

# %%
#updating chrysler Pacifica with the median 

#updating with median 
kbb_cleaned.loc[(kbb_cleaned['make'] == 'Chrysler') & (kbb_cleaned['model'] == 'Pacifica') & (kbb_cleaned['price'] == 0), 'price'] = 24868 

#checking to make sure it updated. 
kbb_cleaned[(kbb_cleaned['make'] == 'Chrysler') & (kbb_cleaned['model'] == 'Pacifica') & (kbb_cleaned['price'] > 0)].count()
# Out:
# Used Vehicle Classification    713
# year                           713
# make                           713
# model                          713
# packages                       713
# price                          713
# mileage                        713
# engine_type                    713
# transmission_type              713
# drivetrain                     713
# color                          713
# vehicle_type                   713
# dtype: int64

# %%
#extracting just Dodge
dodge_cars = kbb_cleaned[kbb_cleaned['make']== 'Dodge']

print(dodge_cars.count())
#seperating out the 0 values
dodge_cars_zero = dodge_cars[dodge_cars['price'] == 0]

#viewing the missing amounts in each type
dodge_cars_zero['model'].value_counts()
# Out:
# Used Vehicle Classification    1080
# year                           1080
# make                           1080
# model                          1080
# packages                       1080
# price                          1080
# mileage                        1080
# engine_type                    1080
# transmission_type              1080
# drivetrain                     1080
# color                          1080
# vehicle_type                   1080
# dtype: int64
# Charger    40
# Name: model, dtype: int64

# %%
#extracting all above 0 
dodge_greater = dodge_cars[(dodge_cars['model'] == 'Charger') & (dodge_cars['price'] > 0)]

print(dodge_greater.count())

#looking at mean median mode std and quartile ranges
dodge_median = dodge_greater['price'].median()
dodge_mode = dodge_greater['price'].mode()

print()
print('Median:', dodge_median)
print ()
print('Mode')
print(dodge_mode)
print()
print(dodge_greater.describe())
# Out:
# Used Vehicle Classification    365
# year                           365
# make                           365
# model                          365
# packages                       365
# price                          365
# mileage                        365
# engine_type                    365
# transmission_type              365
# drivetrain                     365
# color                          365
# vehicle_type                   365
# dtype: int64
#
# Median: 34594.0
#
# Mode
# 0    23995.0
# Name: price, dtype: float64
#
#               price       mileage
# count    365.000000    365.000000
# mean   37927.635616  11777.915068
# std    13059.938825  12552.136766
# min    21627.000000    120.000000
# 25%    28793.000000   4871.000000
# 50%    34594.000000   7499.000000
# 75%    52895.000000  16853.000000
# max    98990.000000  85290.000000

# %%
#updating dodge charger with the median 

kbb_cleaned.loc[(kbb_cleaned['make'] == 'Dodge') & (kbb_cleaned['model'] == 'Charger') & (kbb_cleaned['price'] == 0), 'price'] = 34594 

#checking to make sure it updated. 
kbb_cleaned[(kbb_cleaned['make'] == 'Dodge') & (kbb_cleaned['model'] == 'Charger') & (kbb_cleaned['price'] > 0)].count()
# Out:
# Used Vehicle Classification    405
# year                           405
# make                           405
# model                          405
# packages                       405
# price                          405
# mileage                        405
# engine_type                    405
# transmission_type              405
# drivetrain                     405
# color                          405
# vehicle_type                   405
# dtype: int64

# %%
#extracting just GMC
gmc_cars = kbb_cleaned[kbb_cleaned['make']== 'GMC']

print(gmc_cars.count())

#seperating out the 0 values
gmc_cars_zero = gmc_cars[gmc_cars['price'] == 0]

#viewing the missing amounts in each type
gmc_cars_zero['model'].value_counts()
# Out:
# Used Vehicle Classification    1080
# year                           1080
# make                           1080
# model                          1080
# packages                       1080
# price                          1080
# mileage                        1080
# engine_type                    1080
# transmission_type              1080
# drivetrain                     1080
# color                          1080
# vehicle_type                   1080
# dtype: int64
# Sierra    41
# Name: model, dtype: int64

# %%
#extracting all Sierra above 0 
gmc_greater = gmc_cars[(gmc_cars['model'] == 'Sierra') & (gmc_cars['price'] > 0)]

print(gmc_greater.count())

#looking at mean median mode std and quartile ranges
gmc_median = gmc_greater['price'].median()
gmc_mode = gmc_greater['price'].mode()

print()
print('Median:', gmc_median)
print ()
print('Mode')
print(gmc_mode)
print()
print(gmc_greater.describe())
# Out:
# Used Vehicle Classification    446
# year                           446
# make                           446
# model                          446
# packages                       446
# price                          446
# mileage                        446
# engine_type                    446
# transmission_type              446
# drivetrain                     446
# color                          446
# vehicle_type                   446
# dtype: int64
#
# Median: 46534.0
#
# Mode
# 0    21500.0
# 1    35563.0
# 2    41500.0
# 3    42500.0
# 4    45294.0
# 5    47774.0
# 6    49500.0
# 7    52405.0
# 8    69872.0
# 9    77777.0
# Name: price, dtype: float64
#
#               price        mileage
# count    446.000000     446.000000
# mean   48220.715247   51771.639013
# std    14970.510675   26752.587135
# min    21500.000000    3091.000000
# 25%    41500.000000   34882.000000
# 50%    46534.000000   54104.000000
# 75%    52405.000000   77916.000000
# max    88495.000000  136300.000000

# %%
#updating gmc sierra with the median 

kbb_cleaned.loc[(kbb_cleaned['make'] == 'GMC') & (kbb_cleaned['model'] == 'Sierra') & (kbb_cleaned['price'] == 0), 'price'] = 46534 

#checking to make sure it updated. 
kbb_cleaned[(kbb_cleaned['make'] == 'GMC') & (kbb_cleaned['model'] == 'Sierra') & (kbb_cleaned['price'] > 0)].count()
# Out:
# Used Vehicle Classification    487
# year                           487
# make                           487
# model                          487
# packages                       487
# price                          487
# mileage                        487
# engine_type                    487
# transmission_type              487
# drivetrain                     487
# color                          487
# vehicle_type                   487
# dtype: int64

# %%
#extracting just Jeep
jeep_cars = kbb_cleaned[kbb_cleaned['make']== 'Jeep']

print(jeep_cars.count())

#seperating out the 0 values
jeep_cars_zero = jeep_cars[jeep_cars['price'] == 0]

#viewing the missing amounts in each type
jeep_cars_zero['model'].value_counts()
# Out:
# Used Vehicle Classification    1080
# year                           1080
# make                           1080
# model                          1080
# packages                       1080
# price                          1080
# mileage                        1080
# engine_type                    1080
# transmission_type              1080
# drivetrain                     1080
# color                          1080
# vehicle_type                   1080
# dtype: int64
# Compass     40
# Cherokee     1
# Name: model, dtype: int64

# %%
#extracting all compass above 0 
jeep_greater = jeep_cars[(jeep_cars['model'] == 'Compass') & (jeep_cars['price'] > 0)]

print(jeep_greater.count())

#looking at mean median mode std and quartile ranges
jeep_median = jeep_greater['price'].median()
jeep_mode = jeep_greater['price'].mode()

print()
print('Median:', jeep_median)
print ()
print('Mode')
print(jeep_mode)
print()
print(jeep_greater.describe())
# Out:
# Used Vehicle Classification    89
# year                           89
# make                           89
# model                          89
# packages                       89
# price                          89
# mileage                        89
# engine_type                    89
# transmission_type              89
# drivetrain                     89
# color                          89
# vehicle_type                   89
# dtype: int64
#
# Median: 22578.0
#
# Mode
# 0    19481.0
# 1    35394.0
# Name: price, dtype: float64
#
#               price       mileage
# count     89.000000     89.000000
# mean   26971.561798  38307.179775
# std     7756.446060  31986.137861
# min    18491.000000   4566.000000
# 25%    19481.000000   4566.000000
# 50%    22578.000000  54082.000000
# 75%    35394.000000  69495.000000
# max    35394.000000  72433.000000

# %%
#updating jeep compass with the median 

kbb_cleaned.loc[(kbb_cleaned['make'] == 'Jeep') & (kbb_cleaned['model'] == 'Compass') & (kbb_cleaned['price'] == 0), 'price'] = 22578

#checking to make sure it updated. 
kbb_cleaned[(kbb_cleaned['make'] == 'Jeep') & (kbb_cleaned['model'] == 'Compass') & (kbb_cleaned['price'] > 0)].count()
# Out:
# Used Vehicle Classification    129
# year                           129
# make                           129
# model                          129
# packages                       129
# price                          129
# mileage                        129
# engine_type                    129
# transmission_type              129
# drivetrain                     129
# color                          129
# vehicle_type                   129
# dtype: int64

# %%
#extracting just Lincoln
lincoln_cars = kbb_cleaned[kbb_cleaned['make']== 'Lincoln']

print(lincoln_cars.count())

#seperating out the 0 values
lincoln_cars_zero = lincoln_cars[lincoln_cars['price'] == 0]

#viewing the missing amounts in each type
lincoln_cars_zero['model'].value_counts()
# Out:
# Used Vehicle Classification    1080
# year                           1080
# make                           1080
# model                          1080
# packages                       1080
# price                          1080
# mileage                        1080
# engine_type                    1080
# transmission_type              1080
# drivetrain                     1080
# color                          1080
# vehicle_type                   1080
# dtype: int64
# Corsair    40
# Name: model, dtype: int64

# %%
#extracting all corsair above 0 
lincoln_greater = lincoln_cars[(lincoln_cars['model'] == 'Corsair') & (lincoln_cars['price'] > 0)]

print(lincoln_greater.count())

#looking at mean median mode std and quartile ranges
lincoln_median = lincoln_greater['price'].median()
lincoln_mode = lincoln_greater['price'].mode()

print()
print('Median:', lincoln_median)
print ()
print('Mode')
print(lincoln_mode)
print()
print(lincoln_greater.describe())
# Out:
# Used Vehicle Classification    103
# year                           103
# make                           103
# model                          103
# packages                       103
# price                          103
# mileage                        103
# engine_type                    103
# transmission_type              103
# drivetrain                     103
# color                          103
# vehicle_type                   103
# dtype: int64
#
# Median: 28985.0
#
# Mode
# 0    28097.0
# 1    28985.0
# Name: price, dtype: float64
#
#               price       mileage
# count    103.000000    103.000000
# mean   29732.378641  33119.242718
# std     3288.545501   8420.188489
# min    26000.000000    499.000000
# 25%    28097.000000  34089.000000
# 50%    28985.000000  34089.000000
# 75%    28985.000000  35185.000000
# max    46500.000000  78571.000000

# %%
#updating lincoln corsair with the median 

kbb_cleaned.loc[(kbb_cleaned['make'] == 'Lincoln') & (kbb_cleaned['model'] == 'Corsair') & (kbb_cleaned['price'] == 0), 'price'] = 28985

#checking to make sure it updated. 
kbb_cleaned[(kbb_cleaned['make'] == 'Lincoln') & (kbb_cleaned['model'] == 'Corsair') & (kbb_cleaned['price'] > 0)].count()
# Out:
# Used Vehicle Classification    143
# year                           143
# make                           143
# model                          143
# packages                       143
# price                          143
# mileage                        143
# engine_type                    143
# transmission_type              143
# drivetrain                     143
# color                          143
# vehicle_type                   143
# dtype: int64

# %%
#checking remaining duplicates again 

# exploring price at 0 by manufacturer
kbb_cleaned[kbb_cleaned['price'] == 0].groupby('make').count()

#the small counts will be left alone this they should not impact the average value as much. I will continue with the 4 last models
# Out:
#                Used Vehicle Classification  year  model  packages  price  \
# make
# Acura                                    1     1      1         1      1
# Audi                                     1     1      1         1      1
# BMW                                      1     1      1         1      1
# Buick                                    1     1      1         1      1
# Ford                                     1     1      1         1      1
# Honda                                    2     2      2         2      2
# Hyundai                                  1     1      1         1      1
# INFINITI                                 1     1      1         1      1
# Jeep                                     1     1      1         1      1
# Kia                                      1     1      1         1      1
# Lexus                                    1     1      1         1      1
# MAZDA                                    1     1      1         1      1
# MINI                                     3     3      3         3      3
# Maserati                                 1     1      1         1      1
# Mercedes-Benz                            1     1      1         1      1
# Mitsubishi                               4     4      4         4      4
# Nissan                                   2     2      2         2      2
# Porsche                                 81    81     81        81     81
# RAM                                     80    80     80        80     80
# Tesla                                   41    41     41        41     41
# Volkswagen                              81    81     81        81     81
#
#                mileage  engine_type  transmission_type  drivetrain  color  \
# make
# Acura                1            1                  1           1      1
# Audi                 1            1                  1           1      1
# BMW                  1            1                  1           1      1
# Buick                1            1                  1           1      1
# Ford                 1            1                  1           1      1
# Honda                2            2                  2           2      2
# Hyundai              1            1                  1           1      1
# INFINITI             1            1                  1           1      1
# Jeep                 1            1                  1           1      1
# Kia                  1            1                  1           1      1
# Lexus                1            1                  1           1      1
# MAZDA                1            1                  1           1      1
# MINI                 3            3                  3           3      3
# Maserati             1            1                  1           1      1
# Mercedes-Benz        1            1                  1           1      1
# Mitsubishi           4            4                  4           4      4
# Nissan               2            2                  2           2      2
# Porsche             81           81                 81          81     81
# RAM                 80           80                 80          80     80
# Tesla               41           41                 41          41     41
# Volkswagen          81           81                 81          81     81
#
#                vehicle_type
# make
# Acura                     1
# Audi                      1
# BMW                       1
# Buick                     1
# Ford                      1
# Honda                     2
# Hyundai                   1
# INFINITI                  1
# Jeep                      1
# Kia                       1
# Lexus                     1
# MAZDA                     1
# MINI                      3
# Maserati                  1
# Mercedes-Benz             1
# Mitsubishi                4
# Nissan                    2
# Porsche                  81
# RAM                      80
# Tesla                    41
# Volkswagen               81

# %%
#extracting just Porsche
porsche_cars = kbb_cleaned[kbb_cleaned['make']== 'Porsche']

print(porsche_cars.count())

#seperating out the 0 values
porsche_cars_zero = porsche_cars[porsche_cars['price'] == 0]

#viewing the missing amounts in each type
porsche_cars_zero['model'].value_counts()
# Out:
# Used Vehicle Classification    1080
# year                           1080
# make                           1080
# model                          1080
# packages                       1080
# price                          1080
# mileage                        1080
# engine_type                    1080
# transmission_type              1080
# drivetrain                     1078
# color                          1080
# vehicle_type                   1080
# dtype: int64
# Macan      40
# Cayenne    40
# Taycan      1
# Name: model, dtype: int64

# %%
#extracting all Macan above 0 
porsche_greater = porsche_cars[(porsche_cars['model'] == 'Macan') & (porsche_cars['price'] > 0)]

print(porsche_greater.count())

#looking at mean median mode std and quartile ranges
porsche_median = porsche_greater['price'].median()
porsche_mode = porsche_greater['price'].mode()

print()
print('Median:', porsche_median)
print ()
print('Mode')
print(porsche_mode)
print()
print(porsche_greater.describe())
# Out:
# Used Vehicle Classification    519
# year                           519
# make                           519
# model                          519
# packages                       519
# price                          519
# mileage                        519
# engine_type                    519
# transmission_type              519
# drivetrain                     519
# color                          519
# vehicle_type                   519
# dtype: int64
#
# Median: 62295.0
#
# Mode
# 0     30980.0
# 1     33000.0
# 2     40997.0
# 3     54995.0
# 4     61738.0
# 5     62295.0
# 6     62772.0
# 7     63294.0
# 8     63500.0
# 9     66439.0
# 10    69993.0
# 11    99000.0
# Name: price, dtype: float64
#
#               price       mileage
# count    519.000000    519.000000
# mean   58549.358382  16234.495183
# std    17203.465558  22046.039613
# min    29499.000000   2427.000000
# 25%    41519.000000   4290.000000
# 50%    62295.000000   5916.000000
# 75%    63500.000000  19547.000000
# max    99000.000000  83190.000000

# %%
#updating macan with the median 

kbb_cleaned.loc[(kbb_cleaned['make'] == 'Porsche') & (kbb_cleaned['model'] == 'Macan') & (kbb_cleaned['price'] == 0), 'price'] = 62295

#checking to make sure it updated. 
kbb_cleaned[(kbb_cleaned['make'] == 'Porsche') & (kbb_cleaned['model'] == 'Macan') & (kbb_cleaned['price'] > 0)].count()
# Out:
# Used Vehicle Classification    559
# year                           559
# make                           559
# model                          559
# packages                       559
# price                          559
# mileage                        559
# engine_type                    559
# transmission_type              559
# drivetrain                     559
# color                          559
# vehicle_type                   559
# dtype: int64

# %%
#extracting all Cayenne above 0 
cayenne_greater = porsche_cars[(porsche_cars['model'] == 'Cayenne') & (porsche_cars['price'] > 0)]

print(cayenne_greater.count())

#looking at mean median mode std and quartile ranges
cayenne_median = cayenne_greater['price'].median()
cayenne_mode = cayenne_greater['price'].mode()

print()
print('Median:', cayenne_median)
print ()
print('Mode')
print(cayenne_mode)
print()
print(cayenne_greater.describe())
# Out:
# Used Vehicle Classification    89
# year                           89
# make                           89
# model                          89
# packages                       89
# price                          89
# mileage                        89
# engine_type                    89
# transmission_type              89
# drivetrain                     89
# color                          89
# vehicle_type                   89
# dtype: int64
#
# Median: 52796.0
#
# Mode
# 0    46190.0
# 1    83110.0
# Name: price, dtype: float64
#
#               price       mileage
# count     89.000000     89.000000
# mean   64108.741573  26804.044944
# std    18222.513596  21493.643289
# min    44430.000000   4712.000000
# 25%    46190.000000   4712.000000
# 50%    52796.000000  46472.000000
# 75%    83110.000000  46472.000000
# max    83110.000000  65707.000000

# %%
#updating macan with the median 

kbb_cleaned.loc[(kbb_cleaned['make'] == 'Porsche') & (kbb_cleaned['model'] == 'Cayenne') & (kbb_cleaned['price'] == 0), 'price'] = 52796

#checking to make sure it updated. 
kbb_cleaned[(kbb_cleaned['make'] == 'Porsche') & (kbb_cleaned['model'] == 'Cayenne') & (kbb_cleaned['price'] > 0)].count()
# Out:
# Used Vehicle Classification    129
# year                           129
# make                           129
# model                          129
# packages                       129
# price                          129
# mileage                        129
# engine_type                    129
# transmission_type              129
# drivetrain                     129
# color                          129
# vehicle_type                   129
# dtype: int64

# %%
#extracting just Ram
ram_cars = kbb_cleaned[kbb_cleaned['make']== 'RAM']

print(ram_cars.count())

#seperating out the 0 values
ram_cars_zero = ram_cars[ram_cars['price'] == 0]

#viewing the missing amounts in each type
ram_cars_zero['model'].value_counts()
# Out:
# Used Vehicle Classification    1080
# year                           1080
# make                           1080
# model                          1080
# packages                       1080
# price                          1080
# mileage                        1080
# engine_type                    1080
# transmission_type              1080
# drivetrain                     1080
# color                          1080
# vehicle_type                   1080
# dtype: int64
# Tradesman    40
# Laram        40
# Name: model, dtype: int64

# %%
#extracting all Tradesman above 0 
ram_greater = ram_cars[(ram_cars['model'] == 'Tradesman') & (ram_cars['price'] > 0)]

print(ram_greater.count())

#looking at mean median mode std and quartile ranges
ram_median = ram_greater['price'].median()
ram_mode = ram_greater['price'].mode()

print()
print('Median:', ram_median)
print ()
print('Mode')
print(ram_mode)
print()
print(ram_greater.describe())
# Out:
# Used Vehicle Classification    92
# year                           92
# make                           92
# model                          92
# packages                       92
# price                          92
# mileage                        92
# engine_type                    92
# transmission_type              92
# drivetrain                     92
# color                          92
# vehicle_type                   92
# dtype: int64
#
# Median: 39894.0
#
# Mode
# 0    29995.0
# 1    39993.0
# Name: price, dtype: float64
#
#               price        mileage
# count     92.000000      92.000000
# mean   35531.380435   39836.130435
# std     5576.407499   15875.265675
# min    28417.000000    3532.000000
# 25%    29995.000000   29942.000000
# 50%    39894.000000   42119.500000
# 75%    39993.000000   46926.000000
# max    53985.000000  107440.000000

# %%
#updating Tradesman with the median 

kbb_cleaned.loc[(kbb_cleaned['make'] == 'RAM') & (kbb_cleaned['model'] == 'Tradesman') & (kbb_cleaned['price'] == 0), 'price'] = 39894

#checking to make sure it updated. 
kbb_cleaned[(kbb_cleaned['make'] == 'RAM') & (kbb_cleaned['model'] == 'Tradesman') & (kbb_cleaned['price'] > 0)].count()
# Out:
# Used Vehicle Classification    132
# year                           132
# make                           132
# model                          132
# packages                       132
# price                          132
# mileage                        132
# engine_type                    132
# transmission_type              132
# drivetrain                     132
# color                          132
# vehicle_type                   132
# dtype: int64

# %%
#extracting all Laram above 0 
laram_greater = ram_cars[(ram_cars['model'] == 'Laram') & (ram_cars['price'] > 0)]

print(laram_greater.count())

#looking at mean median mode std and quartile ranges
laram_median = laram_greater['price'].median()
laram_mode = laram_greater['price'].mode()

print()
print('Median:', laram_median)
print ()
print('Mode')
print(laram_mode)
print()
print(laram_greater.describe())
# Out:
# Used Vehicle Classification    94
# year                           94
# make                           94
# model                          94
# packages                       94
# price                          94
# mileage                        94
# engine_type                    94
# transmission_type              94
# drivetrain                     94
# color                          94
# vehicle_type                   94
# dtype: int64
#
# Median: 58990.0
#
# Mode
# 0    58990.0
# 1    65986.0
# Name: price, dtype: float64
#
#               price        mileage
# count     94.000000      94.000000
# mean   60186.127660   44767.329787
# std     7342.139717   23651.206415
# min    35999.000000       9.000000
# 25%    58990.000000   22960.000000
# 50%    58990.000000   46209.500000
# 75%    65986.000000   65127.000000
# max    67113.000000  110423.000000

# %%
#updating Laram with the median 

kbb_cleaned.loc[(kbb_cleaned['make'] == 'RAM') & (kbb_cleaned['model'] == 'Laram') & (kbb_cleaned['price'] == 0), 'price'] = 58990

#checking to make sure it updated. 
kbb_cleaned[(kbb_cleaned['make'] == 'RAM') & (kbb_cleaned['model'] == 'Laram') & (kbb_cleaned['price'] > 0)].count()
# Out:
# Used Vehicle Classification    134
# year                           134
# make                           134
# model                          134
# packages                       134
# price                          134
# mileage                        134
# engine_type                    134
# transmission_type              134
# drivetrain                     134
# color                          134
# vehicle_type                   134
# dtype: int64

# %%
#extracting just Tesla
tesla_cars = kbb_cleaned[kbb_cleaned['make']== 'Tesla']

print(tesla_cars.count())

#seperating out the 0 values
tesla_cars_zero = tesla_cars[tesla_cars['price'] == 0]

#viewing the missing amounts in each type
tesla_cars_zero['model'].value_counts()
# Out:
# Used Vehicle Classification    1080
# year                           1080
# make                           1080
# model                          1080
# packages                       1080
# price                          1080
# mileage                        1080
# engine_type                    1080
# transmission_type              1080
# drivetrain                     1080
# color                          1080
# vehicle_type                   1080
# dtype: int64
# ModelY    41
# Name: model, dtype: int64

# %%
#extracting all model Y  above 0 
tesla_greater = tesla_cars[(tesla_cars['model'] == 'ModelY') & (tesla_cars['price'] > 0)]

print(tesla_greater.count())

#looking at mean median mode std and quartile ranges
tesla_median = tesla_greater['price'].median()
tesla_mode = tesla_greater['price'].mode()

print()
print('Median:', tesla_median)
print ()
print('Mode')
print(tesla_mode)
print()
print(tesla_greater.describe())
# Out:
# Used Vehicle Classification    231
# year                           231
# make                           231
# model                          231
# packages                       231
# price                          231
# mileage                        231
# engine_type                    231
# transmission_type              231
# drivetrain                     231
# color                          231
# vehicle_type                   231
# dtype: int64
#
# Median: 41999.0
#
# Mode
# 0    45999.0
# Name: price, dtype: float64
#
#               price       mileage
# count    231.000000    231.000000
# mean   42939.826840  36406.584416
# std     3229.496097  14279.657290
# min    37504.000000   5158.000000
# 25%    41000.000000  30590.000000
# 50%    41999.000000  36249.000000
# 75%    45999.000000  38743.000000
# max    54599.000000  62727.000000

# %%
#updating ModelY with the median 

kbb_cleaned.loc[(kbb_cleaned['make'] == 'Tesla') & (kbb_cleaned['model'] == 'ModelY') & (kbb_cleaned['price'] == 0), 'price'] = 41999

#checking to make sure it updated. 
kbb_cleaned[(kbb_cleaned['make'] == 'Tesla') & (kbb_cleaned['model'] == 'ModelY') & (kbb_cleaned['price'] > 0)].count()
# Out:
# Used Vehicle Classification    272
# year                           272
# make                           272
# model                          272
# packages                       272
# price                          272
# mileage                        272
# engine_type                    272
# transmission_type              272
# drivetrain                     272
# color                          272
# vehicle_type                   272
# dtype: int64

# %%
#extracting just Volkswagen
vw_cars = kbb_cleaned[kbb_cleaned['make']== 'Volkswagen']

print(vw_cars.count())

#seperating out the 0 values
vw_cars_zero = vw_cars[vw_cars['price'] == 0]

#viewing the missing amounts in each type
vw_cars_zero['model'].value_counts()
# Out:
# Used Vehicle Classification    1080
# year                           1080
# make                           1080
# model                          1080
# packages                       1080
# price                          1080
# mileage                        1080
# engine_type                    1080
# transmission_type              1080
# drivetrain                     1080
# color                          1080
# vehicle_type                   1080
# dtype: int64
# Jetta     40
# Tiguan    40
# Passat     1
# Name: model, dtype: int64

# %%
#extracting all Jetta above 0 
jetta_greater = vw_cars[(vw_cars['model'] == 'Jetta') & (vw_cars['price'] > 0)]

print(jetta_greater.count())

#looking at mean median mode std and quartile ranges
jetta_median = jetta_greater['price'].median()
jetta_mode = jetta_greater['price'].mode()

print()
print('Median:', jetta_median)
print ()
print('Mode')
print(jetta_mode)
print()
print(jetta_greater.describe())
# Out:
# Used Vehicle Classification    27
# year                           27
# make                           27
# model                          27
# packages                       27
# price                          27
# mileage                        27
# engine_type                    27
# transmission_type              27
# drivetrain                     27
# color                          27
# vehicle_type                   27
# dtype: int64
#
# Median: 20000.0
#
# Mode
# 0    19991.0
# Name: price, dtype: float64
#
#               price       mileage
# count     27.000000     27.000000
# mean   20718.259259  42445.185185
# std     3304.466378  25034.774718
# min    15599.000000   1431.000000
# 25%    18939.000000  20321.000000
# 50%    20000.000000  41567.000000
# 75%    22424.500000  62538.000000
# max    29914.000000  88753.000000

# %% [markdown]
# #### Notes:
#
# The jetta has 67 vehicles in the data set 40 of which have no price. 27 do have a price.
# If I add any value to the jetta this will alter the values significantly. The mode is 19991 and the median is 20,000. the average is 20718. The Standaard deviation is about 3,300 which is not too bad of a range. Lets see the mileage on the missing vehicles.

# %%
jetta_zero = vw_cars_zero[vw_cars_zero['model'] == 'Jetta']
print(jetta_zero)
#looking at it its the same vehicle so I will update the value and drop the duplicates. the median is about the average of with the cars with similar mileage. they range between 19795 and 20,300
# Out:
#       Used Vehicle Classification  year        make  model packages  price  \
# 34501                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 34528                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 34555                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 34582                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 34609                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 34636                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 34663                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 34690                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 34717                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 34744                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 34771                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 34798                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 34825                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 34852                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 34879                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 34906                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 34933                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 34960                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 34987                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35014                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35041                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35068                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35095                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35122                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35149                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35176                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35203                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35230                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35257                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35284                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35311                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35338                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35365                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35392                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35419                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35446                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35473                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35500                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35527                   Certified  2017  Volkswagen  Jetta       SE    0.0
# 35554                   Certified  2017  Volkswagen  Jetta       SE    0.0
#
#        mileage       engine_type transmission_type drivetrain color  \
# 34501  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 34528  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 34555  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 34582  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 34609  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 34636  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 34663  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 34690  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 34717  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 34744  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 34771  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 34798  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 34825  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 34852  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 34879  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 34906  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 34933  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 34960  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 34987  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35014  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35041  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35068  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35095  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35122  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35149  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35176  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35203  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35230  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35257  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35284  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35311  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35338  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35365  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35392  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35419  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35446  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35473  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35500  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35527  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
# 35554  55409.0  4-Cylinder Turbo         Automatic        FWD   Red
#
#       vehicle_type
# 34501        Sedan
# 34528        Sedan
# 34555        Sedan
# 34582        Sedan
# 34609        Sedan
# 34636        Sedan
# 34663        Sedan
# 34690        Sedan
# 34717        Sedan
# 34744        Sedan
# 34771        Sedan
# 34798        Sedan
# 34825        Sedan
# 34852        Sedan
# 34879        Sedan
# 34906        Sedan
# 34933        Sedan
# 34960        Sedan
# 34987        Sedan
# 35014        Sedan
# 35041        Sedan
# 35068        Sedan
# 35095        Sedan
# 35122        Sedan
# 35149        Sedan
# 35176        Sedan
# 35203        Sedan
# 35230        Sedan
# 35257        Sedan
# 35284        Sedan
# 35311        Sedan
# 35338        Sedan
# 35365        Sedan
# 35392        Sedan
# 35419        Sedan
# 35446        Sedan
# 35473        Sedan
# 35500        Sedan
# 35527        Sedan
# 35554        Sedan

# %%
#updating Jetta with the median 

kbb_cleaned.loc[(kbb_cleaned['make'] == 'Volkswagen') & (kbb_cleaned['model'] == 'Jetta') & (kbb_cleaned['price'] == 0), 'price'] = 20000

#dropping the duplicates
kbb_cleaned.loc[(kbb_cleaned['model'] == 'Jetta') & (kbb_cleaned['price'] == 20000)] = kbb_cleaned.loc[(kbb_cleaned['model'] == 'Jetta') & (kbb_cleaned['price'] == 20000)].drop_duplicates()

#checking to make sure it updated. 
kbb_cleaned[(kbb_cleaned['make'] == 'Volkswagen') & (kbb_cleaned['model'] == 'Jetta') & (kbb_cleaned['price'] > 0)].count()
# Out:
# Used Vehicle Classification    28
# year                           28
# make                           28
# model                          28
# packages                       28
# price                          28
# mileage                        28
# engine_type                    28
# transmission_type              28
# drivetrain                     28
# color                          28
# vehicle_type                   28
# dtype: int64

# %%
#extracting all Tiguan above 0 
vw_greater = vw_cars[(vw_cars['model'] == 'Tiguan') & (vw_cars['price'] > 0)]

print(vw_greater.count())

#looking at mean median mode std and quartile ranges
vw_median = vw_greater['price'].median()
vw_mode = vw_greater['price'].mode()

print()
print('Median:', vw_median)
print ()
print('Mode')
print(vw_mode)
print()
print(vw_greater.describe())
# Out:
# Used Vehicle Classification    472
# year                           472
# make                           472
# model                          472
# packages                       472
# price                          472
# mileage                        472
# engine_type                    472
# transmission_type              472
# drivetrain                     472
# color                          472
# vehicle_type                   472
# dtype: int64
#
# Median: 22883.0
#
# Mode
# 0     17768.0
# 1     21056.0
# 2     21715.0
# 3     21810.0
# 4     22345.0
# 5     22883.0
# 6     24989.0
# 7     27987.0
# 8     30157.0
# 9     32986.0
# 10    35093.0
# Name: price, dtype: float64
#
#               price       mileage
# count    472.000000    472.000000
# mean   25256.423729  32515.105932
# std     5199.315576  24023.319817
# min    16195.000000   3928.000000
# 25%    21715.000000   9952.000000
# 50%    22883.000000  24208.000000
# 75%    30157.000000  65594.000000
# max    35093.000000  98907.000000

# %%
#updating Tiguan with the median 

kbb_cleaned.loc[(kbb_cleaned['make'] == 'Volkswagen') & (kbb_cleaned['model'] == 'Tiguan') & (kbb_cleaned['price'] == 0), 'price'] = 22883

#checking to make sure it updated. 
kbb_cleaned[(kbb_cleaned['make'] == 'Volkswagen') & (kbb_cleaned['model'] == 'Tiguan') & (kbb_cleaned['price'] > 0)].count()
# Out:
# Used Vehicle Classification    512
# year                           512
# make                           512
# model                          512
# packages                       512
# price                          512
# mileage                        512
# engine_type                    512
# transmission_type              512
# drivetrain                     512
# color                          512
# vehicle_type                   512
# dtype: int64

# %%
kbb_cleaned.to_csv('kbb_cleaned.csv')

# %% [markdown]
# ### Notes:
#
# #### Now the data is cleaned and in good shape. I will use power bi to build a dashboard for the cleaned dataset. Before I go ahead with the project in Power Bi, I really want to recapture the Ford Maverick since it was dropped from the dataset. I feel like missing this model will be doing a diservice. I am not really concerned about the Transit van since its generally a work van.  I also noticed I did not pull any Volvo vehicles in my original scrape. So i would like to bring volvo in as well.
#
# #### This will result in 2 datasets that I will need to merge together.

# %%
# Base URL for the search results
base_url = "https://www.kbb.com/cars-for-sale/used/ford/maverick/safety-harbor-fl/?endYear=2023&isNewSearch=true&marketExtension=include&numRecords=24&searchRadius=0&sortBy=relevance&startYear=2017&zip=34695&page="

# Number of pages to scrape
num_pages = 2

# Create empty lists to store the scraped data
car_details_list = []

# Loop through each page
for page_number in range(1, num_pages + 1):
    # Construct the URL for the current page
    url = f"{base_url}{page_number}"

    # Send a GET request to the URL
    response = requests.get(url)
    if response.status_code == 200:
        # Parse the HTML content
        html_content = response.content
        soup = BeautifulSoup(html_content, 'html.parser')
        
        # Find and process car listings on this page
        car_listings = soup.find_all('script', {'data-cmp': 'lstgSchema'})
        
            # Process each car listing


        for car_listing in car_listings:
            car_data = json.loads(car_listing.contents[0])
            
            car_details = {
                "name": car_data.get("name", ""),
                "price": car_data.get("offers", {}).get("price", ""),
                "mileage": car_data.get("mileageFromOdometer", {}).get("value", ""),
                "engine_type": car_data.get("vehicleEngine", ""),
                "transmission_type": car_data.get("vehicleTransmission", ""),
                "color": car_data.get("color", ""),
                "drivewheel_configuration": car_data.get("driveWheelConfiguration", "")
            }
            
            car_details_list.append(car_details)

        print(f"Finished scraping page {page_number}")
    else:
        print(f"Failed to retrieve page {page_number}")
    
    # Add a 10-second delay before making the next request
    time.sleep(10)

print("Scraping complete!")

df_maverick = pd.DataFrame(car_details_list)
df_maverick.to_csv("maverick_csv.csv")
# Out:
# Finished scraping page 1
# Finished scraping page 2
# Scraping complete!

# %% [markdown]
# ### Note:
#
# The webscrape picked up 4 cars with no price. Checking the website they say call dealer for price. Since I have a large sample of 53 i will just drop these 4. Before I clean I will webscrape volvo and adjust my time interval for sleep. I will randomize it between 10 and 15 seconds and I will adjust my scrape to skip 0 values.

# %%
import random

# Base URL for the search results
base_url = "https://www.kbb.com/cars-for-sale/used/volvo/safety-harbor-fl/?endYear=2023&isNewSearch=true&marketExtension=include&numRecords=24&searchRadius=0&sortBy=relevance&startYear=2017&zip=34695&page="

# Number of pages to scrape
num_pages = 40

# Create an empty list to store the scraped data
car_details_list = []

# Loop through each page
for page_number in range(1, num_pages + 1):
    # Construct the URL for the current page
    url = f"{base_url}{page_number}"

    # Send a GET request to the URL
    response = requests.get(url)
    if response.status_code == 200:
        # Parse the HTML content
        html_content = response.content
        soup = BeautifulSoup(html_content, 'html.parser')

        # Find and process car listings on this page
        car_listings = soup.find_all('script', {'data-cmp': 'lstgSchema'})

        # Process each car listing
        for car_listing in car_listings:
            car_data = json.loads(car_listing.contents[0])

            # Check if the "price" field is present and not empty
            if "offers" in car_data and "price" in car_data["offers"] and car_data["offers"]["price"]:
                car_details = {
                    "name": car_data.get("name", ""),
                    "price": car_data["offers"]["price"],
                    "mileage": car_data.get("mileageFromOdometer", {}).get("value", ""),
                    "engine_type": car_data.get("vehicleEngine", ""),
                    "transmission_type": car_data.get("vehicleTransmission", ""),
                    "color": car_data.get("color", ""),
                    "drivewheel_configuration": car_data.get("driveWheelConfiguration", "")
                }

                car_details_list.append(car_details)

        print(f"Finished scraping page {page_number}")
    else:
        print(f"Failed to retrieve page {page_number}")

    # Add a random sleep interval between 10 and 15 seconds
    sleep_interval = random.uniform(10, 15)
    print(f"Sleeping for {sleep_interval:.2f} seconds...")
    time.sleep(sleep_interval)

print("Scraping complete!")

df_volvo = pd.DataFrame(car_details_list)
df_volvo.to_csv("volvo_csv.csv")
# Out:
# Finished scraping page 1
# Sleeping for 10.47 seconds...
# Finished scraping page 2
# Sleeping for 14.09 seconds...
# Finished scraping page 3
# Sleeping for 14.91 seconds...
# Finished scraping page 4
# Sleeping for 10.30 seconds...
# Finished scraping page 5
# Sleeping for 13.55 seconds...
# Finished scraping page 6
# Sleeping for 11.07 seconds...
# Finished scraping page 7
# Sleeping for 14.08 seconds...
# Finished scraping page 8
# Sleeping for 11.37 seconds...
# Finished scraping page 9
# Sleeping for 10.29 seconds...
# Finished scraping page 10
# Sleeping for 11.71 seconds...
# Finished scraping page 11
# Sleeping for 10.00 seconds...
# Finished scraping page 12
# Sleeping for 14.32 seconds...
# Finished scraping page 13
# Sleeping for 11.43 seconds...
# Finished scraping page 14
# Sleeping for 11.47 seconds...
# Finished scraping page 15
# Sleeping for 14.99 seconds...
# Finished scraping page 16
# Sleeping for 10.09 seconds...
# Finished scraping page 17
# Sleeping for 11.73 seconds...
# Finished scraping page 18
# Sleeping for 12.02 seconds...
# Finished scraping page 19
# Sleeping for 10.78 seconds...
# Finished scraping page 20
# Sleeping for 13.10 seconds...
# Finished scraping page 21
# Sleeping for 13.44 seconds...
# Finished scraping page 22
# Sleeping for 13.46 seconds...
# Finished scraping page 23
# Sleeping for 14.80 seconds...
# Finished scraping page 24
# Sleeping for 14.61 seconds...
# Finished scraping page 25
# Sleeping for 14.90 seconds...
# Finished scraping page 26
# Sleeping for 13.64 seconds...
# Finished scraping page 27
# Sleeping for 13.04 seconds...
# Finished scraping page 28
# Sleeping for 10.52 seconds...
# Finished scraping page 29
# Sleeping for 10.62 seconds...
# Finished scraping page 30
# Sleeping for 11.30 seconds...
# Finished scraping page 31
# Sleeping for 14.90 seconds...
# Finished scraping page 32
# Sleeping for 10.52 seconds...
# Finished scraping page 33
# Sleeping for 12.58 seconds...
# Finished scraping page 34
# Sleeping for 14.89 seconds...
# Finished scraping page 35
# Sleeping for 13.53 seconds...
# Finished scraping page 36
# Sleeping for 14.78 seconds...
# Finished scraping page 37
# Sleeping for 10.96 seconds...
# Finished scraping page 38
# Sleeping for 12.19 seconds...
# Finished scraping page 39
# Sleeping for 10.07 seconds...
# Finished scraping page 40
# Sleeping for 10.92 seconds...
# Scraping complete!

# %%
#had to restart workbook
df_volvo = pd.read_csv('volvo_csv.csv')
df_maverick = pd.read_csv('maverick_csv.csv')

# %%
df_volvo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1080 non-null   int64
#  1   name                      1080 non-null   object
#  2   price                     1080 non-null   int64
#  3   mileage                   1080 non-null   object
#  4   engine_type               1080 non-null   object
#  5   transmission_type         1080 non-null   object
#  6   color                     1038 non-null   object
#  7   drivewheel_configuration  1080 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 67.6+ KB

# %% [markdown]
# ### Note: Cleaning and reshaping the maverick and volvo dataset to match the kbb_cleaned dataset.

# %%
df_maverick.columns
# Out:
# Index(['Unnamed: 0', 'Used Vehicle Classification', 'year', 'make', 'model',
#        'packages', 'price', 'mileage', 'engine_type', 'transmission_type',
#        'drivetrain', 'color'],
#       dtype='object')

# %%
df_maverick['transmission_type'].value_counts()
# Out:
# Automatic    50
# Name: transmission_type, dtype: int64

# %%
#cleaning transmission
df_maverick['transmission_type'] = df_maverick['transmission_type'].replace({"8-Speed Automatic", "Continuously Variable Automatic"}, "Automatic")
df_maverick['transmission_type'].value_counts()
# Out:
# Automatic    50
# Name: transmission_type, dtype: int64

# %%
df_maverick['color'].value_counts()
# Out:
# Blue       17
# Black       9
# Gray        9
# Unknown     4
# Silver      4
# White       3
# Red         2
# Orange      2
# Name: color, dtype: int64

# %%
#cleaning color column
df_maverick['color'] = df_maverick['color'].replace({"","Unavail"}, "Unknown")
df_maverick['color'].value_counts()
# Out:
# Blue       17
# Black       9
# Gray        9
# Unknown     4
# Silver      4
# White       3
# Red         2
# Orange      2
# Name: color, dtype: int64

# %%
#creating drivetrain 
replacement_dict = {
    "All wheel drive": "AWD",
    "All Wheel Drive": "AWD",
    "2 wheel drive - front": "FWD",
    "2 Wheel Drive - Front": "FWD"
}

df_maverick["drivetrain"] = df_maverick["drivewheel_configuration"].replace(replacement_dict)
df_maverick['drivetrain'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'drivewheel_configuration'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[490], line 9
#       1 #creating drivetrain
#       2 replacement_dict = {
#       3     "All wheel drive": "AWD",
#       4     "All Wheel Drive": "AWD",
#       5     "2 wheel drive - front": "FWD",
#       6     "2 Wheel Drive - Front": "FWD"
#       7 }
# ----> 9 df_maverick["drivetrain"] = df_maverick["drivewheel_configuration"].replace(replacement_dict)
#      10 df_maverick['drivetrain'].value_counts()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'drivewheel_configuration'

# %%
# cleaning mileage column 
df_maverick['mileage'] = df_maverick['mileage'].str.replace(",","")
df_maverick['mileage'] = df_maverick['mileage'].astype(int)

# %%
df_maverick['price'] = df_maverick['price'].astype(int)
df_maverick['price'][df_maverick['price'] == 0]

# %%
#dropping 0 value
dropping = [2,24,29,51]

df_maverick = df_maverick.drop(2)
df_maverick = df_maverick.drop(24)
df_maverick = df_maverick.drop(29)
df_maverick = df_maverick.drop(51)

df_maverick = df_maverick.reset_index(drop=True)

df_maverick.count()

# %%
#unnamed column wont drop with reset index 
df_maverick = df_maverick.drop(columns=["Unnamed: 0"])

# %%
#checking df 
df_maverick

# %%
#extracting vehicle classification 
df_maverick["Used Vehicle Classification"] = df_maverick["name"].str.extract('(Used|Certified)', expand=False)
df_maverick["name"] = df_maverick["name"].str.strip('(Used|Certified)')
df_maverick.head(15)

# %%
#extracting year from name 
df_maverick['year'] = df_maverick['name'].str.extract(r'(\d{4})')
df_maverick['name'] = df_maverick['name'].str.strip("")
df_maverick.head()

# %%
#removing year from name column 
df_maverick['name'] = df_maverick['name'].str.replace(r'(\d{4})', "")
df_maverick['name'] = df_maverick['name'].str.strip()
df_maverick.head()

# %%
#creating make and model column 
df_maverick['make'] = df_maverick['name'].str.split().str[0]
df_maverick['model'] = df_maverick['name'].str.split().str[1]

#stripping make and model and renaming column 
df_maverick['name'] = df_maverick['name'].str.split(n=2).str[2:].str.join(' ')

df_maverick = df_maverick.rename(columns={'name': 'packages'})

maverick_mapping = {"maverick": "Pick up"}

#mapping and checking vehicle type 
df_maverick['vehicle_type'] = df_maverick['model'].map(maverick_mapping)

# %%
#reorganizing the dataframe
df_maverick = df_maverick[['Used Vehicle Classification', 'year','make','model','packages', 'price', 'mileage', 'engine_type', 'transmission_type','drivetrain', 'color']]

# %%
df_maverick['color'] = df_maverick['color'].fillna('Unknown')

# %%
df_maverick

# %%
df_maverick.to_csv("maverick_csv.csv")

# %%
df_volvo.head()
# Out:
#    Unnamed: 0                                               name  price  \
# 0           0                   Used 2022 Volvo XC60 T8 R-Design  55497
# 1           1              Certified 2020 Volvo XC40 T5 Momentum  32968
# 2           2                   Used 2020 Volvo XC60 T6 Momentum  29990
# 3           3                    Used 2018 Volvo S90 T5 Momentum  27991
# 4           4  Used 2018 Volvo XC60 T5 Momentum w/ Vision Pac...  32999
#
#   mileage       engine_type  transmission_type  color drivewheel_configuration
# 0  15,462            Hybrid  8-Speed Automatic  White          All Wheel Drive
# 1  27,709  4-Cylinder Turbo  8-Speed Automatic  Black          All Wheel Drive
# 2  57,215  4-Cylinder Turbo  8-Speed Automatic  Black          All Wheel Drive
# 3  52,303  4-Cylinder Turbo  8-Speed Automatic  Brown          All Wheel Drive
# 4  36,000  4-Cylinder Turbo  8-Speed Automatic  White          All Wheel Drive

# %%
#identifying the transmission types 
df_volvo['transmission_type'].value_counts()
# Out:
# 8-Speed Automatic    624
# Automatic            414
# Single-Speed          42
# Name: transmission_type, dtype: int64

# %%
#consolidating transmission types 
df_volvo['transmission_type'] = df_volvo['transmission_type'].replace({"8-Speed Automatic", "Single-Speed"}, "Automatic")
df_volvo['transmission_type'].value_counts()
# Out:
# Automatic    1080
# Name: transmission_type, dtype: int64

# %%
#checking color column 
df_volvo['color'].value_counts(dropna=False)
# Out:
# White     444
# Blue      210
# Black     180
# Gray       62
# Silver     55
# Red        46
# NaN        42
# Brown      40
# Gold        1
# Name: color, dtype: int64

# %%
#converting 42 Nan to unknown 
df_volvo['color'] = df_volvo['color'].fillna('Unknown')
df_volvo['color'].value_counts(dropna=False)
# Out:
# White      444
# Blue       210
# Black      180
# Gray        62
# Silver      55
# Red         46
# Unknown     42
# Brown       40
# Gold         1
# Name: color, dtype: int64

# %%
df_volvo['drivewheel_configuration'].value_counts(dropna=False)
# Out:
# All Wheel Drive          563
# All wheel drive          378
# 2 Wheel Drive - Front     85
# 2 wheel drive - front     54
# Name: drivewheel_configuration, dtype: int64

# %%
#creating drivetrain 
replacement_dict = {
    "All wheel drive": "AWD",
    "All Wheel Drive": "AWD",
    "2 wheel drive - front": "FWD",
    "2 Wheel Drive - Front": "FWD"
}

df_volvo["drivetrain"] = df_volvo["drivewheel_configuration"].replace(replacement_dict)
df_volvo['drivetrain'].value_counts()
# Out:
# AWD    941
# FWD    139
# Name: drivetrain, dtype: int64

# %%
#removing comma and converting to integer 
df_volvo['mileage'] = df_volvo['mileage'].str.replace(',','')

df_volvo['mileage'] = df_volvo['mileage'].astype(int)

# %%
#checking column 
df_volvo['mileage'].head()
# Out:
# 0    15462
# 1    27709
# 2    57215
# 3    52303
# 4    36000
# Name: mileage, dtype: int32

# %%
#checking for nan values 
df_volvo['mileage'].isna().sum()
# Out:
# 0

# %%
#checking if any Nan values 
df_volvo['price'].isna().sum()
# Out:
# 0

# %%
#exploring engine type for consolidation 
df_volvo['engine_type'].value_counts()
# Out:
# 4-Cylinder Turbo         898
# Hybrid                    86
# Electric                  42
# Plug-in Hybrid            36
# Gas / Electric Hybrid     18
# Name: engine_type, dtype: int64

# %%
#replacing 1 hybrid type 
replacement_dict_engine = {
    "Gas / Electric Hybrid": "Hybrid"
  
}

df_volvo["engine_type"] = df_volvo["engine_type"].replace(replacement_dict_engine)

# %%
#extracting vehicle classification 
df_volvo["Used Vehicle Classification"] = df_volvo["name"].str.extract('(Used|Certified)', expand=False)
df_volvo["name"] = df_volvo["name"].str.strip('(Used|Certified)')
df_volvo.head(15)
# Out:
#     Unnamed: 0                                               name  price  \
# 0            0                        2022 Volvo XC60 T8 R-Design  55497
# 1            1                        2020 Volvo XC40 T5 Momentum  32968
# 2            2                        2020 Volvo XC60 T6 Momentum  29990
# 3            3                         2018 Volvo S90 T5 Momentum  27991
# 4            4       2018 Volvo XC60 T5 Momentum w/ Vision Packag  32999
# 5            5      2022 Volvo XC60 B5 Momentum w/ Climate Packag  37990
# 6            6          2021 Volvo XC90 T8 Inscription Expression  48717
# 7            7   2018 Volvo XC60 T6 Momentum w/ Convenience Pa...  26274
# 8            8                        2019 Volvo XC40 T5 R-Design  26499
# 9            9                        2020 Volvo XC60 T5 Momentum  28999
# 10          10                        2020 Volvo XC60 T6 Momentum  27499
# 11          11                        2022 Volvo XC40 T5 Momentum  27999
# 12          12                     2022 Volvo XC90 T6 Inscription  49499
# 13          13                      2019 Volvo S60 T6 Inscription  29999
# 14          14                  2022 Volvo C40 P8 Recharge Ultima  46000
#
#     mileage       engine_type transmission_type    color  \
# 0     15462            Hybrid         Automatic    White
# 1     27709  4-Cylinder Turbo         Automatic    Black
# 2     57215  4-Cylinder Turbo         Automatic    Black
# 3     52303  4-Cylinder Turbo         Automatic    Brown
# 4     36000  4-Cylinder Turbo         Automatic    White
# 5     11818  4-Cylinder Turbo         Automatic    White
# 6     23783            Hybrid         Automatic    Black
# 7     50729  4-Cylinder Turbo         Automatic     Gray
# 8     60384  4-Cylinder Turbo         Automatic      Red
# 9     27269  4-Cylinder Turbo         Automatic    White
# 10    82126  4-Cylinder Turbo         Automatic    White
# 11    82048  4-Cylinder Turbo         Automatic    White
# 12    16192  4-Cylinder Turbo         Automatic     Blue
# 13    27449  4-Cylinder Turbo         Automatic  Unknown
# 14     9022          Electric         Automatic     Blue
#
#    drivewheel_configuration drivetrain Used Vehicle Classification
# 0           All Wheel Drive        AWD                        Used
# 1           All Wheel Drive        AWD                   Certified
# 2           All Wheel Drive        AWD                        Used
# 3           All Wheel Drive        AWD                        Used
# 4           All Wheel Drive        AWD                        Used
# 5           All Wheel Drive        AWD                        Used
# 6           All Wheel Drive        AWD                        Used
# 7           All Wheel Drive        AWD                        Used
# 8           All Wheel Drive        AWD                        Used
# 9     2 Wheel Drive - Front        FWD                        Used
# 10          All Wheel Drive        AWD                        Used
# 11          All Wheel Drive        AWD                        Used
# 12          All Wheel Drive        AWD                        Used
# 13          All Wheel Drive        AWD                        Used
# 14          All Wheel Drive        AWD                        Used

# %%
#extracting year from name 
df_volvo['year'] = df_volvo['name'].str.extract(r'(\d{4})')
df_volvo['name'] = df_volvo['name'].str.strip("")
df_volvo.head()
# Out:
#    Unnamed: 0                                           name  price  mileage  \
# 0           0                    2022 Volvo XC60 T8 R-Design  55497    15462
# 1           1                    2020 Volvo XC40 T5 Momentum  32968    27709
# 2           2                    2020 Volvo XC60 T6 Momentum  29990    57215
# 3           3                     2018 Volvo S90 T5 Momentum  27991    52303
# 4           4   2018 Volvo XC60 T5 Momentum w/ Vision Packag  32999    36000
#
#         engine_type transmission_type  color drivewheel_configuration  \
# 0            Hybrid         Automatic  White          All Wheel Drive
# 1  4-Cylinder Turbo         Automatic  Black          All Wheel Drive
# 2  4-Cylinder Turbo         Automatic  Black          All Wheel Drive
# 3  4-Cylinder Turbo         Automatic  Brown          All Wheel Drive
# 4  4-Cylinder Turbo         Automatic  White          All Wheel Drive
#
#   drivetrain Used Vehicle Classification  year
# 0        AWD                        Used  2022
# 1        AWD                   Certified  2020
# 2        AWD                        Used  2020
# 3        AWD                        Used  2018
# 4        AWD                        Used  2018

# %%
#removing year from name column 
df_volvo['name'] = df_volvo['name'].str.replace(r'(\d{4})', "")
df_volvo['name'] = df_volvo['name'].str.strip()
df_volvo.head()
# Out:
# C:\Users\marko\AppData\Local\Temp\ipykernel_110380\2959953172.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_volvo['name'] = df_volvo['name'].str.replace(r'(\d{4})', "")
#    Unnamed: 0                                     name  price  mileage  \
# 0           0                   Volvo XC60 T8 R-Design  55497    15462
# 1           1                   Volvo XC40 T5 Momentum  32968    27709
# 2           2                   Volvo XC60 T6 Momentum  29990    57215
# 3           3                    Volvo S90 T5 Momentum  27991    52303
# 4           4  Volvo XC60 T5 Momentum w/ Vision Packag  32999    36000
#
#         engine_type transmission_type  color drivewheel_configuration  \
# 0            Hybrid         Automatic  White          All Wheel Drive
# 1  4-Cylinder Turbo         Automatic  Black          All Wheel Drive
# 2  4-Cylinder Turbo         Automatic  Black          All Wheel Drive
# 3  4-Cylinder Turbo         Automatic  Brown          All Wheel Drive
# 4  4-Cylinder Turbo         Automatic  White          All Wheel Drive
#
#   drivetrain Used Vehicle Classification  year
# 0        AWD                        Used  2022
# 1        AWD                   Certified  2020
# 2        AWD                        Used  2020
# 3        AWD                        Used  2018
# 4        AWD                        Used  2018

# %%
#creating make and model column 
df_volvo['make'] = df_volvo['name'].str.split().str[0]
df_volvo['model'] = df_volvo['name'].str.split().str[1]

#stripping make and model and renaming column 
df_volvo['name'] = df_volvo['name'].str.split(n=2).str[2:].str.join(' ')

df_volvo = df_volvo.rename(columns={'name': 'packages'})

# %%
df_volvo['model'].value_counts()
# Out:
# XC90    393
# XC60    312
# XC40    185
# S90      52
# S60      50
# V60      46
# C40      41
# V90       1
# Name: model, dtype: int64

# %%
volvo_mapping = {"XC90": "SUV", "XC60": "SUV", "XC40":"SUV", "S90": "Sedan", "S60": "Sedan", "V60":"Sedan", "C40": "SUV", "V90": "Sedan"}

#mapping and checking vehicle type 
df_maverick['vehicle_type'] = df_maverick['model'].map(volvo_mapping)

# %%
#reorganizing the dataframe
df_volvo = df_volvo[['Used Vehicle Classification', 'year','make','model','packages', 'price', 'mileage', 'engine_type', 'transmission_type','drivetrain', 'color']]

# %%
df_volvo.head()
# Out:
#   Used Vehicle Classification  year   make model  \
# 0                        Used  2022  Volvo  XC60
# 1                   Certified  2020  Volvo  XC40
# 2                        Used  2020  Volvo  XC60
# 3                        Used  2018  Volvo   S90
# 4                        Used  2018  Volvo  XC60
#
#                        packages  price  mileage       engine_type  \
# 0                   T8 R-Design  55497    15462            Hybrid
# 1                   T5 Momentum  32968    27709  4-Cylinder Turbo
# 2                   T6 Momentum  29990    57215  4-Cylinder Turbo
# 3                   T5 Momentum  27991    52303  4-Cylinder Turbo
# 4  T5 Momentum w/ Vision Packag  32999    36000  4-Cylinder Turbo
#
#   transmission_type drivetrain  color
# 0         Automatic        AWD  White
# 1         Automatic        AWD  Black
# 2         Automatic        AWD  Black
# 3         Automatic        AWD  Brown
# 4         Automatic        AWD  White

# %%
df_volvo.to_csv("volvo_csv.csv")

# %%
kbb_cleaned = pd.read_csv("kbb_cleaned.csv")

df_combined = [kbb_cleaned, df_maverick, df_volvo]

kbb_cleaned_final = pd.concat(df_combined)

# %%
kbb_cleaned_final['make'].value_counts()
# Out:
# Acura            1080
# Jeep             1080
# Toyota           1080
# Tesla            1080
# Subaru           1080
# RAM              1080
# Porsche          1080
# Nissan           1080
# MINI             1080
# Mercedes-Benz    1080
# MAZDA            1080
# Maserati         1080
# Lincoln          1080
# Lexus            1080
# Land Rover       1080
# Alfa Romeo       1080
# Kia              1080
# Jaguar           1080
# Dodge            1080
# Audi             1080
# BMW              1080
# Chevrolet        1080
# Chrysler         1080
# INFINITI         1080
# Volvo            1080
# Genesis          1080
# GMC              1080
# Honda            1080
# Hyundai          1080
# Buick            1077
# Cadillac         1053
# Volkswagen       1041
# Mitsubishi       1041
# Ford             1009
# Name: make, dtype: int64

# %%
kbb_ford_cleaned = kbb_cleaned_final[kbb_cleaned_final['make'] == 'Ford']

kbb_ford_cleaned['model'].value_counts()
# Out:
# F150          363
# Expedition    166
# Mustang       123
# F250           85
# Maverick       50
# Explorer       50
# Fusion         45
# Ranger         44
# F350           44
# Escape         13
# Edge           10
# Bronco         10
# EcoSport        2
# E-450           1
# Focus           1
# Fiesta          1
# Taurus          1
# Name: model, dtype: int64

# %%
kbb_cleaned_final.to_csv("kbb_final_csv.csv")

# %%
kbb['make'].value_counts(dropna=False)
# Drop rows with NaN values in the "make" column
kbb_cleaned = kbb.dropna(subset=['make'])

# %%
kbb_cleaned['make'].value_counts(dropna=False)

# %%
kbb_cleaned.to_csv("kbb_final_csv.csv")
